# %%
import csv
import requests
import time

# Step 1: Read tickers from CSV
with open('tickers.csv', 'r') as f:
    reader = csv.reader(f)
    tickers = [row[0].strip().upper() for row in reader if row]

# Step 2: Output field names
output_fields = [
    "company_ticker", "isin", "company_name", "sector", "industry",
    "industry_code", "industry_description"
]

# Step 3: Open output file and write header
with open('filtered_companies.csv', 'w', newline='', encoding='utf-8') as outfile:
    writer = csv.DictWriter(outfile, fieldnames=output_fields)
    writer.writeheader()

    # Step 4: Query each ticker individually
    for ticker in tickers:
        url = f"https://sasb.ifrs.org/wp-json/sasb/v1/companySearch?s={ticker}"
        headers = {"User-Agent": "Mozilla/5.0"}

        try:
            response = requests.get(url, headers=headers)
            if response.status_code != 200:
                print(f"❌ Failed for {ticker}: HTTP {response.status_code}")
                # Still write an empty row with ticker
                writer.writerow({"company_ticker": ticker})
                continue

            companies = response.json()
            if companies:
                # Write only the first matched company
                company = companies[0]
                row = {key: company.get(key, "") for key in output_fields}
                writer.writerow(row)
                print(f"✔ Saved data for {ticker}")
            else:
                # No company found — write empty row with ticker
                writer.writerow({"company_ticker": ticker})
                print(f"⚠ No data for {ticker}, wrote empty row.")

        except Exception as e:
            print(f"❗ Error processing {ticker}: {e}")
            writer.writerow({"company_ticker": ticker})

        time.sleep(0.5)  # polite delay

print("✅ Done. All data written to 'filtered_companies.csv'")
# Out:
# ✔ Saved data for BHARTI
# ✔ Saved data for ZOMATO
# ✔ Saved data for INFOE
# ✔ Saved data for IDEA
# ✔ Saved data for TCOM
# ✔ Saved data for SUNTV
# ✔ Saved data for AFFLE
# ✔ Saved data for TTLS
# ✔ Saved data for Z
# ✔ Saved data for RAILTEL
# ✔ Saved data for ROUTE
# ✔ Saved data for NETM
# ✔ Saved data for TV18
# ✔ Saved data for EASEMYTR
# ✔ Saved data for JUST
# ✔ Saved data for SARE
# ⚠ No data for TIPSMUSI, wrote empty row.
# ✔ Saved data for NAZARA
# ✔ Saved data for DBCL
# ✔ Saved data for TEAM
# ✔ Saved data for HATH
# ✔ Saved data for NELI
# ✔ Saved data for DITV
# ✔ Saved data for CARTRADE
# ✔ Saved data for PRIF
# ✔ Saved data for MPS
# ⚠ No data for PRAVEG, wrote empty row.
# ✔ Saved data for DEN
# ✔ Saved data for YATRA
# ✔ Saved data for JAGP
# ✔ Saved data for OPIL
# ✔ Saved data for MTNL
# ✔ Saved data for SIGNPOST
# ✔ Saved data for GTPL
# ✔ Saved data for GFL
# ✔ Saved data for MSIL
# ✔ Saved data for TTAN
# ✔ Saved data for TTMT
# ✔ Saved data for BJAUT
# ✔ Saved data for MM
# ✔ Saved data for TRENT
# ✔ Saved data for EIM
# ✔ Saved data for TVSL
# ✔ Saved data for HMCL
# ✔ Saved data for BOS
# ✔ Saved data for IH
# ✔ Saved data for MOTHERSO
# ✔ Saved data for MRCO
# ✔ Saved data for MRF
# ✔ Saved data for NYKAA
# ✔ Saved data for BIL
# ✔ Saved data for KALYANKJ
# ✔ Saved data for SONACOMS
# ✔ Saved data for KPITTECH
# ⚠ No data for UNOMINDA, wrote empty row.
# ✔ Saved data for PAG
# ✔ Saved data for TTMT/A
# ✔ Saved data for METROBRA
# ✔ Saved data for APTY
# ✔ Saved data for JUBI
# ✔ Saved data for MSUMI
# ⚠ No data for ZCVCS, wrote empty row.
# ✔ Saved data for KPR
# ✔ Saved data for EIH
# ✔ Saved data for ENDU
# ✔ Saved data for MANYAVAR
# ✔ Saved data for JBMA
# ✔ Saved data for SWAN
# ✔ Saved data for ABFRL
# ✔ Saved data for RLXF
# ✔ Saved data for TRID
# ✔ Saved data for KJC
# ✔ Saved data for BATA
# ⚠ No data for CIEINDIA, wrote empty row.
# ✔ Saved data for CROMPTON
# ⚠ No data for TVSHLTD, wrote empty row.
# ✔ Saved data for INMART
# ✔ Saved data for WHIRL
# ⚠ No data for ARENM, wrote empty row.
# ⚠ No data for WELSPUNL, wrote empty row.
# ✔ Saved data for HONASA
# ⚠ No data for PVRINOX, wrote empty row.
# ✔ Saved data for AISG
# ✔ Saved data for VTEX
# ✔ Saved data for ALOK
# ✔ Saved data for WESTLIFE
# ✔ Saved data for KOEL
# ✔ Saved data for RW
# ✔ Saved data for JUNIPER
# ✔ Saved data for JKI
# ✔ Saved data for CEAT
# ✔ Saved data for BJE
# ✔ Saved data for LEMONTRE
# ✔ Saved data for SFL
# ✔ Saved data for SAPPHIRE
# ✔ Saved data for MDA
# ✔ Saved data for MMTC
# ✔ Saved data for FML
# ✔ Saved data for DOMS
# ✔ Saved data for TTKPT
# ✔ Saved data for CRAFTSMA
# ⚠ No data for REDTAPE, wrote empty row.
# ✔ Saved data for CRS
# ✔ Saved data for SII
# ✔ Saved data for HAPPYFOR
# ✔ Saved data for SHOP
# ✔ Saved data for MHSC
# ✔ Saved data for MHRL
# ✔ Saved data for TC
# ✔ Saved data for RJEX
# ✔ Saved data for VARROC
# ✔ Saved data for VIP
# ✔ Saved data for EMIL
# ✔ Saved data for ARVND
# ✔ Saved data for ICNT
# ⚠ No data for NIITMTS, wrote empty row.
# ✔ Saved data for GTFL
# ✔ Saved data for CAMPUS
# ⚠ No data for BORORENE, wrote empty row.
# ✔ Saved data for GOCOLORS
# ✔ Saved data for ETHOSLTD
# ✔ Saved data for JINW
# ✔ Saved data for PDSL
# ✔ Saved data for IFBI
# ✔ Saved data for VGM
# ✔ Saved data for ARVINDFA
# ✔ Saved data for SENCO
# ✔ Saved data for SYML
# ✔ Saved data for SEL
# ✔ Saved data for ASKAUTOL
# ✔ Saved data for WONH
# ⚠ No data for SGMART, wrote empty row.
# ✔ Saved data for ITDC
# ✔ Saved data for JMNA
# ✔ Saved data for DYTC
# ✔ Saved data for RBA
# ✔ Saved data for GABR
# ✔ Saved data for ROLEXRIN
# ✔ Saved data for PRICOL
# ✔ Saved data for GEXP
# ✔ Saved data for JTEKT
# ✔ Saved data for VMART
# ✔ Saved data for KEKC
# ✔ Saved data for BOROLTD
# ✔ Saved data for PARKHOTE
# ✔ Saved data for SHMO
# ⚠ No data for IMAGICAA, wrote empty row.
# ✔ Saved data for TJL
# ✔ Saved data for KPDL
# ✔ Saved data for SSW
# ✔ Saved data for SUBR
# ✔ Saved data for LMAX
# ✔ Saved data for BD
# ✔ Saved data for LUX
# ✔ Saved data for HAWK
# ✔ Saved data for SANDHAR
# ✔ Saved data for KDDL
# ✔ Saved data for SSKL
# ✔ Saved data for LANDMARK
# ✔ Saved data for FIEM
# ✔ Saved data for SRTY
# ✔ Saved data for DELTA
# ✔ Saved data for GRV
# ✔ Saved data for DOLLAR
# ⚠ No data for SUNCLAY, wrote empty row.
# ✔ Saved data for BLSE
# ✔ Saved data for SWE
# ⚠ No data for HINDWARE, wrote empty row.
# ✔ Saved data for ATXL
# ✔ Saved data for FLAIR
# ⚠ No data for CARYSIL, wrote empty row.
# ✔ Saved data for FLTX
# ✔ Saved data for DREAMFOL
# ✔ Saved data for NILK
# ✔ Saved data for GDYR
# ✔ Saved data for PCJL
# ✔ Saved data for GNPL
# ✔ Saved data for TAJG
# ✔ Saved data for SOMC
# ✔ Saved data for PGIL
# ✔ Saved data for DIVGIITT
# ✔ Saved data for OAH
# ✔ Saved data for LUMX
# ✔ Saved data for SNGM
# ✔ Saved data for TCNSBR
# ✔ Saved data for OTH
# ✔ Saved data for MUNI
# ✔ Saved data for SIYA
# ✔ Saved data for RAI
# ✔ Saved data for BARBEQUE
# ✔ Saved data for RUPA
# ✔ Saved data for SJS
# ✔ Saved data for PRECAM
# ⚠ No data for FILATFAS, wrote empty row.
# ✔ Saved data for ITC
# ✔ Saved data for HUVR
# ✔ Saved data for DMART
# ✔ Saved data for NEST
# ✔ Saved data for VBL
# ✔ Saved data for GCPL
# ✔ Saved data for BRIT
# ⚠ No data for TATACONS, wrote empty row.
# ✔ Saved data for DABUR
# ⚠ No data for UNITDSPR, wrote empty row.
# ✔ Saved data for CLGT
# ✔ Saved data for PG
# ✔ Saved data for PATANJAL
# ✔ Saved data for UBBL
# ✔ Saved data for AWLTD
# ✔ Saved data for GDSP
# ✔ Saved data for RDCK
# ✔ Saved data for HTSMF
# ✔ Saved data for GILL
# ✔ Saved data for HMN
# ✔ Saved data for DEVYANI
# ✔ Saved data for JYL
# ✔ Saved data for GP
# ✔ Saved data for DCMS
# ✔ Saved data for BIKAJI
# ✔ Saved data for BBTC
# ✔ Saved data for ZYWL
# ✔ Saved data for GOAGRO
# ✔ Saved data for SHRS
# ✔ Saved data for MEDPLUS
# ✔ Saved data for CCLP
# ✔ Saved data for GAEX
# ✔ Saved data for BRCM
# ✔ Saved data for TRE
# ✔ Saved data for AVNT
# ✔ Saved data for BECTORS
# ⚠ No data for LTFOODS, wrote empty row.
# ✔ Saved data for KRB
# ✔ Saved data for VST
# ⚠ No data for HNDFDS, wrote empty row.
# ✔ Saved data for DODLA
# ✔ Saved data for SULA
# ✔ Saved data for GOPAL
# ✔ Saved data for TLNGR
# ✔ Saved data for BJH
# ✔ Saved data for TSTY
# ✔ Saved data for HTFL
# ✔ Saved data for VDI
# ✔ Saved data for BAJAJCON
# ✔ Saved data for BNRI
# ✔ Saved data for PCAI
# ✔ Saved data for DCB
# ✔ Saved data for HMAAGRO
# ✔ Saved data for PARAG
# ✔ Saved data for EVRIN
# ✔ Saved data for MANORAMA
# ✔ Saved data for VSFI
# ✔ Saved data for DIAMOND
# ✔ Saved data for WH
# ✔ Saved data for TTKP
# ✔ Saved data for SDB
# ✔ Saved data for ADFL
# ✔ Saved data for GBSL
# ✔ Saved data for RELIANCE
# ✔ Saved data for ONGC
# ✔ Saved data for IOCL
# ✔ Saved data for BPCL
# ✔ Saved data for HPCL
# ✔ Saved data for OINL
# ✔ Saved data for SUEL
# ✔ Saved data for PLNG
# ✔ Saved data for MRPL
# ✔ Saved data for IREDA
# ✔ Saved data for EXID
# ✔ Saved data for INXW
# ⚠ No data for AEGISLOG, wrote empty row.
# ⚠ No data for WAREERTL, wrote empty row.
# ✔ Saved data for MRL
# ✔ Saved data for HBPS
# ✔ Saved data for SWSOLAR
# ✔ Saved data for KPIG
# ✔ Saved data for TECHNOE
# ✔ Saved data for IWEL
# ✔ Saved data for HARSHA
# ✔ Saved data for INOXGREE
# ✔ Saved data for INA
# ✔ Saved data for GENSOL
# ✔ Saved data for SEAM
# ✔ Saved data for CONF
# ✔ Saved data for TWO
# ✔ Saved data for KPEL
# ✔ Saved data for WESL
# ⚠ No data for DEEPIND, wrote empty row.
# ✔ Saved data for GANDHAR
# ✔ Saved data for RIIL
# ✔ Saved data for HDFCB
# ✔ Saved data for ICICIBC
# ✔ Saved data for SBIN
# ✔ Saved data for LICI
# ✔ Saved data for BAF
# ✔ Saved data for KMB
# ✔ Saved data for AXSB
# ✔ Saved data for BJFIN
# ✔ Saved data for JIOFIN
# ✔ Saved data for SBILIFE
# ✔ Saved data for PNB
# ✔ Saved data for BOB
# ✔ Saved data for HDFCLIFE
# ✔ Saved data for POWF
# ✔ Saved data for IIB
# ✔ Saved data for RECL
# ✔ Saved data for UNBK
# ✔ Saved data for IOB
# ✔ Saved data for CBK
# ✔ Saved data for CIFC
# ✔ Saved data for BJHI
# ⚠ No data for SHFL, wrote empty row.
# ✔ Saved data for IPRU
# ✔ Saved data for IDBI
# ✔ Saved data for ICICIGI
# ✔ Saved data for HDFCAMC
# ✔ Saved data for INBK
# ✔ Saved data for YES
# ✔ Saved data for SBICARD
# ✔ Saved data for UCO
# ✔ Saved data for BOI
# ✔ Saved data for MUTH
# ✔ Saved data for GICRE
# ✔ Saved data for IDFCFB
# ✔ Saved data for CBOI
# ✔ Saved data for SUF
# ✔ Saved data for ABCAP
# ✔ Saved data for BOMH
# ✔ Saved data for PJSB
# ⚠ No data for LTF, wrote empty row.
# ✔ Saved data for AUBANK
# ✔ Saved data for NIACL
# ✔ Saved data for HUDCO
# ✔ Saved data for CRISIL
# ✔ Saved data for FB
# ⚠ No data for POONAWAL, wrote empty row.
# ✔ Saved data for MMFS
# ✔ Saved data for LICHF
# ✔ Saved data for STARHEAL
# ✔ Saved data for NAM
# ✔ Saved data for BANDHAN
# ✔ Saved data for PAYTM
# ⚠ No data for ANGELONE, wrote empty row.
# ✔ Saved data for MOFS
# ✔ Saved data for ISEC
# ✔ Saved data for CREDAG
# ✔ Saved data for FIVESTAR
# ✔ Saved data for PIEL
# ✔ Saved data for IDFC
# ✔ Saved data for MCX
# ✔ Saved data for CGCL
# ✔ Saved data for PNBHOUSI
# ✔ Saved data for APTUS
# ✔ Saved data for JKBK
# ✔ Saved data for KVB
# ✔ Saved data for MGFL
# ✔ Saved data for RBK
# ✔ Saved data for CAMS
# ✔ Saved data for ABSLAMC
# ✔ Saved data for IIFL
# ⚠ No data for SAMMAANC, wrote empty row.
# ⚠ No data for AIIL, wrote empty row.
# ✔ Saved data for EQUITASB
# ✔ Saved data for KFINTECH
# ✔ Saved data for AAVAS
# ✔ Saved data for UTIAM
# ✔ Saved data for CANF
# ✔ Saved data for CUBK
# ✔ Saved data for IFCI
# ✔ Saved data for BENG
# ✔ Saved data for INFIBEAM
# ✔ Saved data for SBFC
# ✔ Saved data for UJJIVANS
# ✔ Saved data for KBL
# ✔ Saved data for SWH
# ✔ Saved data for HOMEFIRS
# ✔ Saved data for TMB
# ✔ Saved data for SIB
# ✔ Saved data for JM
# ✔ Saved data for RELG
# ✔ Saved data for INDIASHL
# ✔ Saved data for SISLTD
# ✔ Saved data for CSBBANK
# ✔ Saved data for SPANDANA
# ✔ Saved data for EDEL
# ✔ Saved data for SGM
# ✔ Saved data for UJJIVAN
# ✔ Saved data for CFIS
# ✔ Saved data for PAISALO
# ✔ Saved data for ICRA
# ✔ Saved data for UTKARSHB
# ✔ Saved data for FUSION
# ✔ Saved data for MASFIN
# ⚠ No data for SINDHUTR, wrote empty row.
# ✔ Saved data for JSFB
# ✔ Saved data for FEDFINA
# ✔ Saved data for PIICL
# ✔ Saved data for IIFLSEC
# ✔ Saved data for DCBB
# ✔ Saved data for MEDIASSI
# ✔ Saved data for ZAGGLE
# ✔ Saved data for MUTHOOTM
# ✔ Saved data for CARE
# ✔ Saved data for ESAFSFB
# ✔ Saved data for PTCIF
# ✔ Saved data for INDOSTAR
# ✔ Saved data for REPCO
# ✔ Saved data for FINOPB
# ✔ Saved data for DHANI
# ✔ Saved data for SATIN
# ⚠ No data for SGFIN, wrote empty row.
# ⚠ No data for MUFIN, wrote empty row.
# ✔ Saved data for VKI
# ✔ Saved data for UGRO
# ✔ Saved data for PGLT
# ✔ Saved data for BFIN
# ✔ Saved data for ARLF
# ✔ Saved data for SUNP
# ✔ Saved data for CIPLA
# ✔ Saved data for DRRD
# ⚠ No data for ZYDUSLIF, wrote empty row.
# ✔ Saved data for MANKIND
# ✔ Saved data for APHS
# ✔ Saved data for DIVI
# ✔ Saved data for TRP
# ✔ Saved data for MAXHEALT
# ✔ Saved data for LPC
# ✔ Saved data for ARBP
# ✔ Saved data for ALKEM
# ✔ Saved data for BOOT
# ✔ Saved data for MEDANTA
# ✔ Saved data for GLXO
# ✔ Saved data for BIOS
# ✔ Saved data for FORH
# ✔ Saved data for IPCA
# ✔ Saved data for GLAND
# ✔ Saved data for SYNG
# ✔ Saved data for AJP
# ✔ Saved data for GNP
# ✔ Saved data for NARH
# ✔ Saved data for JBCP
# ✔ Saved data for LAURUS
# ✔ Saved data for ASTERDM
# ✔ Saved data for ALPM
# ✔ Saved data for PFIZ
# ✔ Saved data for DLPL
# ✔ Saved data for SANL
# ✔ Saved data for SUVENPHA
# ✔ Saved data for PIRPHARM
# ✔ Saved data for NTCPH
# ✔ Saved data for KIMS
# ✔ Saved data for CONCORDB
# ✔ Saved data for PLM
# ✔ Saved data for ASTR
# ✔ Saved data for RAINBOW
# ✔ Saved data for SPADV
# ✔ Saved data for ERIS
# ✔ Saved data for GRAN
# ✔ Saved data for CLPL
# ✔ Saved data for GLS
# ⚠ No data for JUBLPHAR, wrote empty row.
# ✔ Saved data for WPL
# ✔ Saved data for METROHL
# ✔ Saved data for NLL
# ✔ Saved data for JLHL
# ✔ Saved data for PGHL
# ✔ Saved data for STR
# ✔ Saved data for FDCLT
# ✔ Saved data for MRKS
# ✔ Saved data for BLUEJET
# ✔ Saved data for VIJAYA
# ✔ Saved data for ORCP
# ✔ Saved data for HCG
# ✔ Saved data for ENTERO
# ✔ Saved data for KMC
# ✔ Saved data for AMIORG
# ✔ Saved data for SLPA
# ✔ Saved data for ARTD
# ⚠ No data for AARTIPHA, wrote empty row.
# ✔ Saved data for DCAL
# ✔ Saved data for YATHARTH
# ✔ Saved data for UL
# ✔ Saved data for HKCI
# ✔ Saved data for CUPD
# ✔ Saved data for THYROCAR
# ✔ Saved data for INDR
# ✔ Saved data for GTB
# ✔ Saved data for SEQ
# ✔ Saved data for CF
# ✔ Saved data for SUPRIYA
# ✔ Saved data for SHALBY
# ✔ Saved data for INNOVACA
# ✔ Saved data for HCBA
# ✔ Saved data for RPGL
# ✔ Saved data for ARTMSL
# ✔ Saved data for SVLS
# ✔ Saved data for MORE
# ✔ Saved data for ALBC
# ✔ Saved data for ICP
# ✔ Saved data for TMCH
# ✔ Saved data for KRSNAA
# ✔ Saved data for LT
# ✔ Saved data for ADSEZ
# ✔ Saved data for HNAL
# ✔ Saved data for SIEM
# ✔ Saved data for IRFC
# ✔ Saved data for BHE
# ✔ Saved data for INDIGO
# ✔ Saved data for ABB
# ✔ Saved data for HAVL
# ✔ Saved data for BHEL
# ✔ Saved data for KKC
# ✔ Saved data for CGPOWER
# ⚠ No data for INDUSTOW, wrote empty row.
# ✔ Saved data for POLYCAB
# ✔ Saved data for IRCTC
# ✔ Saved data for LTTS
# ✔ Saved data for CCRI
# ✔ Saved data for RVNL
# ✔ Saved data for BHFC
# ✔ Saved data for JSWINFRA
# ✔ Saved data for AL
# ✔ Saved data for TMX
# ✔ Saved data for GMRI
# ✔ Saved data for SCHFL
# ✔ Saved data for APAT
# ✔ Saved data for MAZDOCKS
# ✔ Saved data for AIAE
# ✔ Saved data for VOLT
# ✔ Saved data for IRB
# ✔ Saved data for HWA
# ✔ Saved data for DELHIVER
# ✔ Saved data for BDL
# ✔ Saved data for TICL
# ✔ Saved data for KEII
# ✔ Saved data for ESCORTS
# ✔ Saved data for POWERIND
# ✔ Saved data for APR
# ✔ Saved data for BLSTR
# ✔ Saved data for SF
# ✔ Saved data for COCHIN
# ✔ Saved data for CYL
# ✔ Saved data for TMKN
# ✔ Saved data for NBCC
# ✔ Saved data for CHOLAHLD
# ✔ Saved data for IRCON
# ✔ Saved data for SKF
# ✔ Saved data for ELEQ
# ✔ Saved data for JYOTICNC
# ✔ Saved data for SCHN
# ✔ Saved data for RRKABEL
# ⚠ No data for KPIL, wrote empty row.
# ✔ Saved data for TRIV
# ✔ Saved data for ACCE
# ✔ Saved data for LMW
# ✔ Saved data for RITE
# ✔ Saved data for OLECTRA
# ⚠ No data for JWL, wrote empty row.
# ✔ Saved data for FNXC
# ✔ Saved data for BDE
# ✔ Saved data for NJCC
# ✔ Saved data for VGRD
# ✔ Saved data for GESCO
# ✔ Saved data for JSAW
# ✔ Saved data for DATAPATT
# ✔ Saved data for KSB
# ✔ Saved data for BEML
# ✔ Saved data for HMFC
# ✔ Saved data for BLSIN
# ✔ Saved data for GRINFRA
# ✔ Saved data for RMKF
# ✔ Saved data for TITAGARH
# ✔ Saved data for AMBER
# ✔ Saved data for GRIL
# ✔ Saved data for SPPT
# ✔ Saved data for INGR
# ✔ Saved data for ENGR
# ✔ Saved data for MHS
# ✔ Saved data for PNCL
# ✔ Saved data for INOXINDI
# ✔ Saved data for ELCN
# ✔ Saved data for GPPV
# ✔ Saved data for VAMP
# ✔ Saved data for PRJ
# ✔ Saved data for SCI
# ⚠ No data for EUREKAFO, wrote empty row.
# ✔ Saved data for KKB
# ✔ Saved data for GRSE
# ✔ Saved data for TEGA
# ✔ Saved data for SYRMA
# ✔ Saved data for ESAB
# ✔ Saved data for AZAD
# ✔ Saved data for POWM
# ✔ Saved data for QUESS
# ✔ Saved data for MINF
# ✔ Saved data for ION
# ✔ Saved data for MIDHANI
# ✔ Saved data for HEG
# ✔ Saved data for AGLL
# ✔ Saved data for GPIN
# ✔ Saved data for KNRC
# ✔ Saved data for AHLU
# ✔ Saved data for TVSSCS
# ✔ Saved data for DBL
# ✔ Saved data for IGSEC
# ✔ Saved data for TXMRE
# ✔ Saved data for CMSINFO
# ✔ Saved data for TRPC
# ✔ Saved data for PRINCPIP
# ✔ Saved data for HGINFRA
# ✔ Saved data for SECIS
# ✔ Saved data for MSTCLTD
# ✔ Saved data for ITCE
# ✔ Saved data for CYIENTDL
# ✔ Saved data for TARIL
# ⚠ No data for LLOYDSEN, wrote empty row.
# ✔ Saved data for GMM
# ✔ Saved data for SANSERA
# ✔ Saved data for HCC
# ✔ Saved data for KNM
# ✔ Saved data for HMT
# ✔ Saved data for MTARTECH
# ✔ Saved data for JFI
# ✔ Saved data for GRFL
# ✔ Saved data for VRLL
# ✔ Saved data for JKIL
# ✔ Saved data for VATW
# ✔ Saved data for SJET
# ✔ Saved data for NGE
# ✔ Saved data for TDPS
# ✔ Saved data for KKPC
# ✔ Saved data for TIIL
# ✔ Saved data for PEC
# ✔ Saved data for ASBL
# ✔ Saved data for BNCO
# ✔ Saved data for SG
# ⚠ No data for WELENT, wrote empty row.
# ✔ Saved data for ORIENTEL
# ✔ Saved data for LGBB
# ✔ Saved data for TCIEXP
# ✔ Saved data for VENUSPIP
# ✔ Saved data for SKIPPER
# ✔ Saved data for RMKY
# ✔ Saved data for WPI
# ✔ Saved data for DCXINDIA
# ✔ Saved data for JI
# ✔ Saved data for SALASAR
# ✔ Saved data for ANUP
# ✔ Saved data for SBC
# ✔ Saved data for MAHLOG
# ✔ Saved data for SCTE
# ❗ Error processing BFUT: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=BFUT (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF63C4310>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing VINL: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=VINL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6B15F10>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing VSTT: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=VSTT (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51B2D60>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing SM: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=SM (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF5161FA0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing APOLLO: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=APOLLO (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6C1D040>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing SKPI: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=SKPI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6C268E0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing DIACABS: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=DIACABS (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51B2BB0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing VT: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=VT (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51B2B20>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing NRBBR: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=NRBBR (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF63C4250>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing JCHAC: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=JCHAC (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6BCF3A0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing GMRPUI: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=GMRPUI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6C1D910>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing STYRENIX: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=STYRENIX (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6B5B850>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing BAJEL: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=BAJEL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF63C41F0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing PSPPL: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=PSPPL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6A6E970>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing PITTIENG: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=PITTIENG (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51B27C0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing SHEP: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=SHEP (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51B22E0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing PARAS: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=PARAS (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6C1D3A0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing EXICOM: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=EXICOM (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51B2DC0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing UNIPARTS: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=UNIPARTS (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51B2340>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing SEPC: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=SEPC (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6B15C10>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing MAN: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=MAN (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF63C4670>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing AXET: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=AXET (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6C1DFA0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing PWI: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=PWI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6C1DBE0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing WNDT: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=WNDT (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF63C4310>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing HONDAPWR: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=HONDAPWR (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6B15F10>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing EMSLIMIT: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=EMSLIMIT (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF51615E0>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ❗ Error processing CAPACITE: HTTPSConnectionPool(host='sasb.ifrs.org', port=443): Max retries exceeded with url: /wp-json/sasb/v1/companySearch?s=CAPACITE (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000021BF6C1D490>: Failed to resolve 'sasb.ifrs.org' ([Errno 11001] getaddrinfo failed)"))
# ✔ Saved data for IKIO
# ✔ Saved data for UDS
# ✔ Saved data for MMFG
# ⚠ No data for BALUFORG, wrote empty row.
# ✔ Saved data for TARSONS
# ✔ Saved data for GTLI
# ✔ Saved data for HPLE
# ✔ Saved data for BMD
# ✔ Saved data for IRMENERG
# ✔ Saved data for DCIL
# ✔ Saved data for BWRL
# ✔ Saved data for ADE
# ✔ Saved data for UTCEM
# ✔ Saved data for APNT
# ✔ Saved data for COAL
# ✔ Saved data for JSTL
# ✔ Saved data for TATA
# ✔ Saved data for GRASIM
# ✔ Saved data for PIDI
# ✔ Saved data for ACEM
# ✔ Saved data for HNDL
# ✔ Saved data for HZ
# ✔ Saved data for VEDL
# ✔ Saved data for SRCM
# ✔ Saved data for JSP
# ✔ Saved data for SOIL
# ✔ Saved data for SRF
# ✔ Saved data for TIINDIA
# ✔ Saved data for BRGR
# ✔ Saved data for NMDC
# ✔ Saved data for PI
# ✔ Saved data for JDSL
# ✔ Saved data for SAIL
# ✔ Saved data for LIIL
# ✔ Saved data for SI
# ✔ Saved data for ASTRA
# ✔ Saved data for ACC
# ✔ Saved data for FCT
# ✔ Saved data for DALBHARA
# ✔ Saved data for 3M
# ✔ Saved data for UPLL
# ✔ Saved data for FLUOROCH
# ✔ Saved data for CRIN
# ✔ Saved data for JKCE
# ⚠ No data for LLOYDSME, wrote empty row.
# ✔ Saved data for DN
# ✔ Saved data for NACL
# ✔ Saved data for TTCH
# ✔ Saved data for HCP
# ✔ Saved data for ARTO
# ✔ Saved data for CU
# ✔ Saved data for KIOCL
# ✔ Saved data for BYRCS
# ✔ Saved data for KNPL
# ✔ Saved data for GWN
# ✔ Saved data for RMT
# ✔ Saved data for TRCL
# ✔ Saved data for CSTRL
# ✔ Saved data for CENT
# ✔ Saved data for SUMICHEM
# ✔ Saved data for ATLP
# ✔ Saved data for SHYAMMET
# ✔ Saved data for CELLO
# ⚠ No data for NSLNISP, wrote empty row.
# ✔ Saved data for NFIL
# ✔ Saved data for FNXP
# ✔ Saved data for VO
# ✔ Saved data for JBIL
# ✔ Saved data for HSCH
# ✔ Saved data for BASF
# ✔ Saved data for CPBI
# ✔ Saved data for CLEAN
# ✔ Saved data for CHMB
# ✔ Saved data for WLCO
# ✔ Saved data for FINEORG
# ✔ Saved data for RHIM
# ✔ Saved data for ELSC
# ✔ Saved data for BCORP
# ✔ Saved data for NUVOCO
# ✔ Saved data for GMDC
# ✔ Saved data for AKZO
# ⚠ No data for PTCIL, wrote empty row.
# ✔ Saved data for AETHER
# ✔ Saved data for GODPI
# ✔ Saved data for JKLC
# ⚠ No data for PCBL, wrote empty row.
# ✔ Saved data for USM
# ✔ Saved data for EID
# ✔ Saved data for ANURAS
# ✔ Saved data for AACL
# ✔ Saved data for GNFC
# ✔ Saved data for STRCEM
# ✔ Saved data for PRSMJ
# ✔ Saved data for KHL
# ✔ Saved data for ACI
# ✔ Saved data for GALSURF
# ✔ Saved data for GSFC
# ✔ Saved data for KKF
# ✔ Saved data for RESP
# ✔ Saved data for JUBLINGR
# ✔ Saved data for SEML
# ✔ Saved data for RCF
# ✔ Saved data for CHEMPLAS
# ✔ Saved data for EBECK
# ✔ Saved data for GRAV
# ✔ Saved data for VI
# ✔ Saved data for BLA
# ✔ Saved data for ICEM
# ✔ Saved data for LXCHEM
# ✔ Saved data for DFPC
# ✔ Saved data for GRLM
# ✔ Saved data for INDIGOPN
# ⚠ No data for SANDUMA, wrote empty row.
# ⚠ No data for EPLL, wrote empty row.
# ✔ Saved data for MOIL
# ✔ Saved data for TIME
# ✔ Saved data for SYR
# ✔ Saved data for JKPAPER
# ✔ Saved data for PARADEEP
# ✔ Saved data for KSI
# ✔ Saved data for RINDL
# ✔ Saved data for GALK
# ✔ Saved data for RALI
# ⚠ No data for AGIG, wrote empty row.
# ✔ Saved data for DAGRI
# ✔ Saved data for GALL
# ✔ Saved data for GOLI
# ⚠ No data for EPIGRAL, wrote empty row.
# ✔ Saved data for HEIM
# ✔ Saved data for JPA
# ✔ Saved data for NFL
# ✔ Saved data for GHCL
# ✔ Saved data for SCHI
# ✔ Saved data for NOCIL
# ✔ Saved data for KKIL
# ✔ Saved data for BLCL
# ✔ Saved data for FTXC
# ⚠ No data for GRWRHITE, wrote empty row.
# ✔ Saved data for ORCMNT
# ✔ Saved data for GW
# ✔ Saved data for WCPM
# ✔ Saved data for ADVENZY
# ✔ Saved data for PRIVISCL
# ✔ Saved data for GREENP
# ✔ Saved data for KS
# ✔ Saved data for ROSSARI
# ✔ Saved data for OMDC
# ✔ Saved data for BRSN
# ⚠ No data for LLOYDSET, wrote empty row.
# ✔ Saved data for IMFA
# ✔ Saved data for ASMN
# ✔ Saved data for FISCHER
# ✔ Saved data for SUNF
# ✔ Saved data for LOG
# ⚠ No data for JTLIND, wrote empty row.
# ✔ Saved data for KSCL
# ✔ Saved data for STEC
# ✔ Saved data for NEOGEN
# ✔ Saved data for PKI
# ✔ Saved data for RGW
# ✔ Saved data for UFLX
# ✔ Saved data for SHCR
# ✔ Saved data for MTLM
# ✔ Saved data for MAIT
# ✔ Saved data for SHKL
# ⚠ No data for HLEGLAS, wrote empty row.
# ✔ Saved data for GLIN
# ✔ Saved data for SGC
# ✔ Saved data for SYIL
# ✔ Saved data for ISMT
# ✔ Saved data for MTEP
# ✔ Saved data for AREAL
# ✔ Saved data for TATVA
# ✔ Saved data for APOLP
# ✔ Saved data for XPRO
# ✔ Saved data for PPC
# ✔ Saved data for TMC
# ✔ Saved data for KINGFA
# ✔ Saved data for HOE
# ✔ Saved data for IGLY
# ✔ Saved data for IPL
# ✔ Saved data for SNGI
# ✔ Saved data for APCO
# ✔ Saved data for HUIN
# ✔ Saved data for GOCL
# ✔ Saved data for KCPL
# ✔ Saved data for BEPL
# ✔ Saved data for RASTL
# ✔ Saved data for MUK
# ✔ Saved data for HITECH
# ✔ Saved data for VCL
# ✔ Saved data for ASTEL
# ✔ Saved data for TCPL
# ✔ Saved data for MOL
# ✔ Saved data for MGC
# ✔ Saved data for PNPC
# ✔ Saved data for JDPF
# ✔ Saved data for HIL
# ✔ Saved data for TANF
# ✔ Saved data for IFGLRF
# ⚠ No data for ANHPR, wrote empty row.
# ⚠ No data for UDAICEME, wrote empty row.
# ✔ Saved data for DLFU
# ✔ Saved data for LODHA
# ✔ Saved data for GPL
# ✔ Saved data for OBER
# ✔ Saved data for PHNX
# ✔ Saved data for PEPL
# ✔ Saved data for BRGD
# ✔ Saved data for SIGNATUR
# ✔ Saved data for CHALET
# ✔ Saved data for SOBHA
# ✔ Saved data for ARCP
# ⚠ No data for DBREALTY, wrote empty row.
# ✔ Saved data for NTSD
# ⚠ No data for MAHLIFE, wrote empty row.
# ✔ Saved data for RUSTOMJE
# ⚠ No data for EMBDL, wrote empty row.
# ✔ Saved data for GHFC
# ✔ Saved data for NSE
# ✔ Saved data for SRIN
# ✔ Saved data for HEMIPROP
# ✔ Saved data for PURVA
# ✔ Saved data for SAMHI
# ✔ Saved data for TARC
# ⚠ No data for MAXESTAT, wrote empty row.
# ✔ Saved data for NIRL
# ⚠ No data for ARVSMART, wrote empty row.
# ✔ Saved data for UT
# ✔ Saved data for ASFI
# ✔ Saved data for MNRT
# ✔ Saved data for SHRIRAMP
# ✔ Saved data for TCS
# ✔ Saved data for INFO
# ✔ Saved data for HCLT
# ✔ Saved data for WPRO
# ✔ Saved data for LTIM
# ✔ Saved data for TECHM
# ✔ Saved data for OFSS
# ✔ Saved data for PSYS
# ✔ Saved data for POLICYBZ
# ✔ Saved data for TELX
# ✔ Saved data for MPHL
# ✔ Saved data for DIXON
# ✔ Saved data for TATATECH
# ⚠ No data for COFORGE, wrote empty row.
# ✔ Saved data for ITI
# ✔ Saved data for BSOFT
# ✔ Saved data for SSOF
# ✔ Saved data for KAYNES
# ✔ Saved data for REDI
# ✔ Saved data for INDA
# ✔ Saved data for FSOL
# ✔ Saved data for ZENT
# ✔ Saved data for ECLX
# ✔ Saved data for HAPPSTMN
# ✔ Saved data for TEJASNET
# ✔ Saved data for NEWGEN
# ✔ Saved data for TANLA
# ✔ Saved data for LATENTVI
# ✔ Saved data for MAPMYIND
# ✔ Saved data for NETWEB
# ✔ Saved data for RATEGAIN
# ✔ Saved data for ZEN
# ✔ Saved data for MAST
# ✔ Saved data for EMUDHRA
# ✔ Saved data for ASTM
# ✔ Saved data for AUPS
# ✔ Saved data for MCLOUD
# ✔ Saved data for RSYS
# ✔ Saved data for SOTL
# ✔ Saved data for AVL
# ✔ Saved data for PGEL
# ✔ Saved data for PROTEAN
# ✔ Saved data for BBOX
# ✔ Saved data for BIJL
# ✔ Saved data for CIGN
# ✔ Saved data for HGSL
# ✔ Saved data for AVALON
# ✔ Saved data for NCS
# ✔ Saved data for DATA
# ✔ Saved data for IDEAFORG
# ✔ Saved data for BCG
# ✔ Saved data for SAK
# ✔ Saved data for QUICKHEA
# ✔ Saved data for ACCELYA
# ✔ Saved data for AVTS
# ✔ Saved data for GENE
# ✔ Saved data for SASKEN
# ✔ Saved data for CTE
# ✔ Saved data for RPTECH
# ⚠ No data for RPSGVENT, wrote empty row.
# ✔ Saved data for PRMC
# ✔ Saved data for EXPLEOSO
# ✔ Saved data for NTPC
# ✔ Saved data for ADANIGR
# ✔ Saved data for PWGR
# ✔ Saved data for ADANI
# ✔ Saved data for TPWR
# ✔ Saved data for GAIL
# ⚠ No data for ADANIENS, wrote empty row.
# ✔ Saved data for ATGL
# ✔ Saved data for NHPC
# ✔ Saved data for JSW
# ✔ Saved data for TPW
# ✔ Saved data for SJVN
# ✔ Saved data for GUJGA
# ✔ Saved data for NLC
# ✔ Saved data for IGL
# ✔ Saved data for GETD
# ✔ Saved data for GUJS
# ✔ Saved data for KECI
# ✔ Saved data for CESC
# ✔ Saved data for MAHGL
# ✔ Saved data for IEX
# ✔ Saved data for RPWR
# ✔ Saved data for RELI
# ✔ Saved data for JPVL
# ✔ Saved data for RATI
# ✔ Saved data for NAVA
# ✔ Saved data for PTCIN
# ✔ Saved data for RTPOW
# ✔ Saved data for GIP
# ✅ Done. All data written to 'filtered_companies.csv'

# %%
import csv
import requests
import time

input_file = 'filtered_companies.csv'
output_file = 'filtered_companies_retry.csv'

# API headers
headers = {"User-Agent": "Mozilla/5.0"}

# Fields you're using
output_fields = [
    "company_ticker", "isin", "company_name", "sector", "industry",
    "industry_code", "industry_description"
]

# Read original file
rows = []
with open(input_file, 'r', encoding='utf-8') as infile:
    reader = csv.DictReader(infile)
    for row in reader:
        rows.append(row)

# Update missing rows
for row in rows:
    ticker = row["company_ticker"].strip().upper()

    # If 'isin' is already present, retain data as-is
    if row["isin"].strip():
        print(f"✅ Skipped {ticker} (already filled)")
        continue

    # Retry API call
    url = f"https://sasb.ifrs.org/wp-json/sasb/v1/companySearch?s={ticker}"
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            companies = response.json()
            if companies:
                company = companies[0]
                for key in output_fields:
                    row[key] = company.get(key, "")
                print(f"🔁 Retried and filled data for {ticker}")
            else:
                print(f"⚠ No company found for {ticker}")
        else:
            print(f"❌ HTTP {response.status_code} for {ticker}")
        time.sleep(0.5)
        
    except Exception as e:
        print(f"❗ Error retrying {ticker}: {e}")

# Write updated data to output file
with open(output_file, 'w', newline='', encoding='utf-8') as outfile:
    writer = csv.DictWriter(outfile, fieldnames=output_fields)
    writer.writeheader()
    writer.writerows(rows)

print(f"✅ Retry complete. Updated file written to '{output_file}'")
# Out:
# ✅ Skipped BHARTI (already filled)
# ✅ Skipped ZOMATO (already filled)
# ✅ Skipped INFOE (already filled)
# ✅ Skipped AGS (already filled)
# ✅ Skipped 8071 (already filled)
# ✅ Skipped SUNTV (already filled)
# ✅ Skipped AFFLE (already filled)
# ✅ Skipped TTLS (already filled)
# ✅ Skipped Z (already filled)
# ✅ Skipped RAILTEL (already filled)
# ✅ Skipped NSG (already filled)
# ✅ Skipped 251270 (already filled)
# ✅ Skipped ALAMAR (already filled)
# ✅ Skipped EASEMYTR (already filled)
# ✅ Skipped JUST (already filled)
# ✅ Skipped WRLS (already filled)
# ⚠ No company found for TIPSMUSI
# ✅ Skipped NAZARA (already filled)
# ✅ Skipped DBCL (already filled)
# ✅ Skipped 3662 (already filled)
# ✅ Skipped BRK/A (already filled)
# ✅ Skipped CNLI (already filled)
# ✅ Skipped DITV (already filled)
# ✅ Skipped CARTRADE (already filled)
# ✅ Skipped PRIF (already filled)
# ✅ Skipped ALEXSC (already filled)
# ⚠ No company found for PRAVEG
# ✅ Skipped 138SL (already filled)
# ✅ Skipped YATRA (already filled)
# ✅ Skipped JAGP (already filled)
# ✅ Skipped OPIL (already filled)
# ✅ Skipped MTNL (already filled)
# ✅ Skipped 3996 (already filled)
# ✅ Skipped GTPL (already filled)
# ✅ Skipped DANGFLOU (already filled)
# ✅ Skipped MSIL (already filled)
# ✅ Skipped ATANA (already filled)
# ✅ Skipped TTMT (already filled)
# ✅ Skipped BJAUT (already filled)
# ✅ Skipped MM (already filled)
# ✅ Skipped NTGAZ (already filled)
# ✅ Skipped 6156 (already filled)
# ✅ Skipped TVSL (already filled)
# ✅ Skipped HMCL (already filled)
# ✅ Skipped ADAPRA (already filled)
# ✅ Skipped IH (already filled)
# ✅ Skipped MSS (already filled)
# ✅ Skipped MRCO (already filled)
# ✅ Skipped MRFG3 (already filled)
# ✅ Skipped NYKAA (already filled)
# ✅ Skipped MOBIL (already filled)
# ✅ Skipped KALYANKJ (already filled)
# ✅ Skipped SONACOMS (already filled)
# ✅ Skipped KPITTECH (already filled)
# ⚠ No company found for UNOMINDA
# ✅ Skipped PAGCC (already filled)
# ✅ Skipped TTMT/A (already filled)
# ✅ Skipped METROBRA (already filled)
# ✅ Skipped ANAB (already filled)
# ✅ Skipped ELKRRA (already filled)
# ✅ Skipped MSUMI (already filled)
# ⚠ No company found for ZCVCS
# ✅ Skipped KPR (already filled)
# ✅ Skipped 600538 (already filled)
# ✅ Skipped EGEEN (already filled)
# ✅ Skipped MANYAVAR (already filled)
# ✅ Skipped JBMA (already filled)
# ✅ Skipped ABC (already filled)
# ✅ Skipped ABFRL (already filled)
# ✅ Skipped RLXF (already filled)
# ✅ Skipped JRELTD (already filled)
# ✅ Skipped KJC (already filled)
# ✅ Skipped ABAVP (already filled)
# ⚠ No company found for CIEINDIA
# ✅ Skipped BC (already filled)
# ⚠ No company found for TVSHLTD
# ✅ Skipped INMART (already filled)
# ✅ Skipped 600172 (already filled)
# ⚠ No company found for ARENM
# ⚠ No company found for WELSPUNL
# ✅ Skipped HONASA (already filled)
# ⚠ No company found for PVRINOX
# ✅ Skipped AISG (already filled)
# ✅ Skipped VTEX (already filled)
# ✅ Skipped ALOK (already filled)
# ✅ Skipped WLDL (already filled)
# ✅ Skipped FHW (already filled)
# ✅ Skipped RW (already filled)
# ✅ Skipped JUNIPER (already filled)
# ✅ Skipped JKI (already filled)
# ✅ Skipped CEAT (already filled)
# ✅ Skipped BJE (already filled)
# ✅ Skipped LEMONTRE (already filled)
# ✅ Skipped 159010 (already filled)
# ✅ Skipped ASAME (already filled)
# ✅ Skipped 71M (already filled)
# ✅ Skipped MMTC (already filled)
# ✅ Skipped FML (already filled)
# ✅ Skipped DOMS (already filled)
# ✅ Skipped TTKPT (already filled)
# ✅ Skipped CRAFTSMA (already filled)
# ⚠ No company found for REDTAPE
# ✅ Skipped 2CRSI (already filled)
# ✅ Skipped ALDV (already filled)
# ✅ Skipped HAPPYFOR (already filled)
# ✅ Skipped THDS (already filled)
# ✅ Skipped MHSC (already filled)
# ✅ Skipped MHRL (already filled)
# ✅ Skipped TC (already filled)
# ✅ Skipped RJEX (already filled)
# ✅ Skipped VARROC (already filled)
# ✅ Skipped ENVI (already filled)
# ✅ Skipped CMNT (already filled)
# ✅ Skipped ARVND (already filled)
# ✅ Skipped ENTRA (already filled)
# ⚠ No company found for NIITMTS
# ✅ Skipped GTFL (already filled)
# ✅ Skipped ACC (already filled)
# ⚠ No company found for BORORENE
# ✅ Skipped GOCOLORS (already filled)
# ✅ Skipped ETHOSLTD (already filled)
# ✅ Skipped JINW (already filled)
# ✅ Skipped PDSL (already filled)
# ✅ Skipped IFBI (already filled)
# ✅ Skipped VGM (already filled)
# ✅ Skipped ARVINDFA (already filled)
# ✅ Skipped SENCO (already filled)
# ✅ Skipped SYML (already filled)
# ✅ Skipped 140910 (already filled)
# ✅ Skipped ASKAUTOL (already filled)
# ✅ Skipped WONH (already filled)
# ⚠ No company found for SGMART
# ✅ Skipped ITDC (already filled)
# ✅ Skipped JMNA (already filled)
# ✅ Skipped DYTC (already filled)
# ✅ Skipped 3467 (already filled)
# ✅ Skipped DAD (already filled)
# ✅ Skipped ROLEXRIN (already filled)
# ✅ Skipped PRICOL (already filled)
# ✅ Skipped GEXP (already filled)
# ✅ Skipped 6473 (already filled)
# ✅ Skipped VMART (already filled)
# ✅ Skipped KEKC (already filled)
# ✅ Skipped BOROLTD (already filled)
# ✅ Skipped PARKHOTE (already filled)
# ✅ Skipped AMOR (already filled)
# ⚠ No company found for IMAGICAA
# ✅ Skipped TJL (already filled)
# ✅ Skipped KPDL (already filled)
# ✅ Skipped BRAD (already filled)
# ✅ Skipped SUBR (already filled)
# ✅ Skipped LMAX (already filled)
# ✅ Skipped BD (already filled)
# ✅ Skipped 4609 (already filled)
# ✅ Skipped BKHAU (already filled)
# ✅ Skipped SANDHAR (already filled)
# ✅ Skipped KDDL (already filled)
# ✅ Skipped LIK (already filled)
# ✅ Skipped KTI (already filled)
# ✅ Skipped FIEM (already filled)
# ✅ Skipped SRTY (already filled)
# ✅ Skipped NINE (already filled)
# ✅ Skipped GRV (already filled)
# ✅ Skipped DG (already filled)
# ⚠ No company found for SUNCLAY
# ✅ Skipped BLSE (already filled)
# ✅ Skipped ASAB (already filled)
# ⚠ No company found for HINDWARE
# ✅ Skipped ATXL (already filled)
# ✅ Skipped FLAIR (already filled)
# ⚠ No company found for CARYSIL
# ✅ Skipped FLTX (already filled)
# ✅ Skipped DREAMFOL (already filled)
# ✅ Skipped NILK (already filled)
# ✅ Skipped GDYR (already filled)
# ✅ Skipped PCJL (already filled)
# ✅ Skipped GNPL (already filled)
# ✅ Skipped TAJG (already filled)
# ✅ Skipped SOMC (already filled)
# ✅ Skipped PGIL (already filled)
# ✅ Skipped DIVGIITT (already filled)
# ✅ Skipped OAH (already filled)
# ✅ Skipped LUMX (already filled)
# ✅ Skipped SNGM (already filled)
# ✅ Skipped TCNSBR (already filled)
# ✅ Skipped AOTHAIM (already filled)
# ✅ Skipped ONE (already filled)
# ✅ Skipped ASIY (already filled)
# ✅ Skipped WMS (already filled)
# ✅ Skipped BARBEQUE (already filled)
# ✅ Skipped ADRS-R-A (already filled)
# ✅ Skipped JSNV (already filled)
# ✅ Skipped PRECAM (already filled)
# ⚠ No company found for FILATFAS
# ✅ Skipped ANF (already filled)
# ✅ Skipped HUVR (already filled)
# ✅ Skipped DMART (already filled)
# ✅ Skipped 6381 (already filled)
# ✅ Skipped VBL (already filled)
# ✅ Skipped GCPL (already filled)
# ✅ Skipped ASBE (already filled)
# ⚠ No company found for TATACONS
# ✅ Skipped DABUR (already filled)
# ⚠ No company found for UNITDSPR
# ✅ Skipped CLGT (already filled)
# ✅ Skipped PG (already filled)
# ✅ Skipped PATANJAL (already filled)
# ✅ Skipped DUBA (already filled)
# ✅ Skipped AWLTD (already filled)
# ✅ Skipped GDSP (already filled)
# ✅ Skipped RDCK (already filled)
# ✅ Skipped HTSMF (already filled)
# ✅ Skipped AGILC (already filled)
# ✅ Skipped HMN (already filled)
# ✅ Skipped DEVYANI (already filled)
# ✅ Skipped JYL (already filled)
# ✅ Skipped GP (already filled)
# ✅ Skipped DCMS (already filled)
# ✅ Skipped BIKAJI (already filled)
# ✅ Skipped BBTC (already filled)
# ✅ Skipped ZYWL (already filled)
# ✅ Skipped GOAGRO (already filled)
# ✅ Skipped SHRS (already filled)
# ✅ Skipped MEDPLUS (already filled)
# ✅ Skipped CCLP (already filled)
# ✅ Skipped GAEX (already filled)
# ✅ Skipped BRCM (already filled)
# ✅ Skipped BINHO (already filled)
# ✅ Skipped AVNT (already filled)
# ✅ Skipped BECTORS (already filled)
# ⚠ No company found for LTFOODS
# ✅ Skipped KOR (already filled)
# ✅ Skipped IVE (already filled)
# ⚠ No company found for HNDFDS
# ✅ Skipped DODLA (already filled)
# ✅ Skipped ASK (already filled)
# ✅ Skipped BCOL (already filled)
# ✅ Skipped TLNGR (already filled)
# ✅ Skipped BJH (already filled)
# ✅ Skipped TSTY (already filled)
# ✅ Skipped HTFL (already filled)
# ✅ Skipped 4BO (already filled)
# ✅ Skipped BAJAJCON (already filled)
# ✅ Skipped BNRI (already filled)
# ✅ Skipped PCAI (already filled)
# ✅ Skipped DCB (already filled)
# ✅ Skipped HMAAGRO (already filled)
# ✅ Skipped ADM (already filled)
# ✅ Skipped EVRIN (already filled)
# ✅ Skipped MANORAMA (already filled)
# ✅ Skipped VSFI (already filled)
# ✅ Skipped ALKDI (already filled)
# ✅ Skipped WH (already filled)
# ✅ Skipped TTKP (already filled)
# ✅ Skipped DBOS (already filled)
# ✅ Skipped ADFL (already filled)
# ✅ Skipped GBSL (already filled)
# ✅ Skipped EUPIC (already filled)
# ✅ Skipped 000419 (already filled)
# ✅ Skipped IOCL (already filled)
# ✅ Skipped BPCL (already filled)
# ✅ Skipped HPCL (already filled)
# ✅ Skipped OINL (already filled)
# ✅ Skipped SUEL (already filled)
# ✅ Skipped PLNG (already filled)
# ✅ Skipped MRPL (already filled)
# ✅ Skipped IREDA (already filled)
# ✅ Skipped EXID (already filled)
# ✅ Skipped INXW (already filled)
# ⚠ No company found for AEGISLOG
# ⚠ No company found for WAREERTL
# ✅ Skipped MRL (already filled)
# ✅ Skipped HBPS (already filled)
# ✅ Skipped SWSOLAR (already filled)
# ✅ Skipped KPIG (already filled)
# ✅ Skipped TECHNOE (already filled)
# ✅ Skipped 2159 (already filled)
# ✅ Skipped HARSHA (already filled)
# ✅ Skipped INOXGREE (already filled)
# ✅ Skipped 247 (already filled)
# ✅ Skipped GENSOL (already filled)
# ✅ Skipped 002956 (already filled)
# ✅ Skipped AVOT (already filled)
# ✅ Skipped 002467 (already filled)
# ✅ Skipped KPEL (already filled)
# ✅ Skipped WESL (already filled)
# ⚠ No company found for DEEPIND
# ✅ Skipped GANDHAR (already filled)
# ✅ Skipped RIIL (already filled)
# ✅ Skipped HDFCB (already filled)
# ✅ Skipped ICICIBC (already filled)
# ✅ Skipped SBINS (already filled)
# ✅ Skipped BESS (already filled)
# ✅ Skipped 603489 (already filled)
# ✅ Skipped BERA (already filled)
# ✅ Skipped AXSB (already filled)
# ✅ Skipped BJFIN (already filled)
# ✅ Skipped JIOFIN (already filled)
# ✅ Skipped SBILIFE (already filled)
# ✅ Skipped AHP (already filled)
# ✅ Skipped BOB (already filled)
# ✅ Skipped HDFCLIFE (already filled)
# ✅ Skipped POWF (already filled)
# ✅ Skipped IIB (already filled)
# ✅ Skipped MTBC (already filled)
# ✅ Skipped UNBK (already filled)
# ✅ Skipped BOOM (already filled)
# ✅ Skipped CBK (already filled)
# ✅ Skipped 000996 (already filled)
# ✅ Skipped BJHI (already filled)
# ⚠ No company found for SHFL
# ✅ Skipped AFRIPRUD (already filled)
# ✅ Skipped IDBI (already filled)
# ✅ Skipped ICICIGI (already filled)
# ✅ Skipped HDFCAMC (already filled)
# ✅ Skipped INBK (already filled)
# ✅ Skipped AYES (already filled)
# ✅ Skipped SBICARD (already filled)
# ✅ Skipped ACUC (already filled)
# ✅ Skipped ABTZY (already filled)
# ✅ Skipped BEDM (already filled)
# ✅ Skipped GICRE (already filled)
# ✅ Skipped IDFCFB (already filled)
# ✅ Skipped CBOI (already filled)
# ✅ Skipped 000777 (already filled)
# ✅ Skipped ABCAP (already filled)
# ✅ Skipped BOMH (already filled)
# ✅ Skipped PJSB (already filled)
# ⚠ No company found for LTF
# ✅ Skipped AUBANK (already filled)
# ✅ Skipped NIACL (already filled)
# ✅ Skipped HUDCO (already filled)
# ✅ Skipped CRISIL (already filled)
# ✅ Skipped FB (already filled)
# ⚠ No company found for POONAWAL
# ✅ Skipped MMFS (already filled)
# ✅ Skipped LICHF (already filled)
# ✅ Skipped STARHEAL (already filled)
# ✅ Skipped ABDP (already filled)
# ✅ Skipped BANDHAN (already filled)
# ✅ Skipped PAYTM (already filled)
# ⚠ No company found for ANGELONE
# ✅ Skipped MOFS (already filled)
# ✅ Skipped ISEC (already filled)
# ✅ Skipped CREDAG (already filled)
# ✅ Skipped FIVESTAR (already filled)
# ✅ Skipped PIEL (already filled)
# ✅ Skipped IDFCFB (already filled)
# ✅ Skipped MCX (already filled)
# ✅ Skipped CGCL (already filled)
# ✅ Skipped PNBHOUSI (already filled)
# ✅ Skipped APTUS (already filled)
# ✅ Skipped JKBK (already filled)
# ✅ Skipped KVB (already filled)
# ✅ Skipped MGFL (already filled)
# ✅ Skipped BKBR3 (already filled)
# ✅ Skipped 2662 (already filled)
# ✅ Skipped ABSLAMC (already filled)
# ✅ Skipped IIFL (already filled)
# ⚠ No company found for SAMMAANC
# ⚠ No company found for AIIL
# ✅ Skipped EQUITASB (already filled)
# ✅ Skipped KFINTECH (already filled)
# ✅ Skipped AAVAS (already filled)
# ✅ Skipped UTIAM (already filled)
# ✅ Skipped CANF (already filled)
# ✅ Skipped CUBK (already filled)
# ✅ Skipped IFCI (already filled)
# ✅ Skipped ABG (already filled)
# ✅ Skipped INFIBEAM (already filled)
# ✅ Skipped SBFC (already filled)
# ✅ Skipped UJJIVANS (already filled)
# ✅ Skipped BLZE (already filled)
# ✅ Skipped SWH (already filled)
# ✅ Skipped HOMEFIRS (already filled)
# ✅ Skipped TMB (already filled)
# ✅ Skipped CAIN (already filled)
# ✅ Skipped JM (already filled)
# ✅ Skipped NTGAZ (already filled)
# ✅ Skipped INDIASHL (already filled)
# ✅ Skipped SISLTD (already filled)
# ✅ Skipped CSBBANK (already filled)
# ✅ Skipped SPANDANA (already filled)
# ✅ Skipped BMM (already filled)
# ✅ Skipped GMON (already filled)
# ✅ Skipped UJJIVAN (already filled)
# ✅ Skipped CFIS (already filled)
# ✅ Skipped PAISALO (already filled)
# ✅ Skipped FZICRA (already filled)
# ✅ Skipped UTKARSHB (already filled)
# ✅ Skipped BMEA (already filled)
# ✅ Skipped MASFIN (already filled)
# ⚠ No company found for SINDHUTR
# ✅ Skipped JSFB (already filled)
# ✅ Skipped FEDFINA (already filled)
# ✅ Skipped PIICL (already filled)
# ✅ Skipped IIFLSEC (already filled)
# ✅ Skipped DCBB (already filled)
# ✅ Skipped MEDIASSI (already filled)
# ✅ Skipped ZAGGLE (already filled)
# ✅ Skipped MUTHOOTM (already filled)
# ✅ Skipped ONEM (already filled)
# ✅ Skipped ESAFSFB (already filled)
# ✅ Skipped PTCIF (already filled)
# ✅ Skipped INDOSTAR (already filled)
# ✅ Skipped REPCO (already filled)
# ✅ Skipped FINOPB (already filled)
# ✅ Skipped SANDHA (already filled)
# ✅ Skipped SATIN (already filled)
# ⚠ No company found for SGFIN
# ⚠ No company found for MUFIN
# ✅ Skipped DVLF (already filled)
# ✅ Skipped AUGR (already filled)
# ✅ Skipped PGLT (already filled)
# ✅ Skipped BFIN (already filled)
# ✅ Skipped ARLF (already filled)
# ✅ Skipped SUNP (already filled)
# ✅ Skipped CIPLA (already filled)
# ✅ Skipped DRRD (already filled)
# ⚠ No company found for ZYDUSLIF
# ✅ Skipped MANKIND (already filled)
# ✅ Skipped APHS (already filled)
# ✅ Skipped CDF1U (already filled)
# ✅ Skipped TRP (already filled)
# ✅ Skipped MAXHEALT (already filled)
# ✅ Skipped LPC (already filled)
# ✅ Skipped ARBP (already filled)
# ✅ Skipped ALKEM (already filled)
# ✅ Skipped BOOT (already filled)
# ✅ Skipped MEDANTA (already filled)
# ✅ Skipped GLXO (already filled)
# ✅ Skipped AADI (already filled)
# ✅ Skipped FORH (already filled)
# ✅ Skipped IPCA (already filled)
# ✅ Skipped GLANDRT (already filled)
# ✅ Skipped 3SQ1 (already filled)
# ✅ Skipped AJP (already filled)
# ✅ Skipped GNP (already filled)
# ✅ Skipped NARH (already filled)
# ✅ Skipped JBCP (already filled)
# ✅ Skipped LAURUS (already filled)
# ✅ Skipped ASTERDM (already filled)
# ✅ Skipped ALPM (already filled)
# ✅ Skipped PFE (already filled)
# ✅ Skipped DLPL (already filled)
# ✅ Skipped 300384 (already filled)
# ✅ Skipped SUVENPHA (already filled)
# ✅ Skipped PIRPHARM (already filled)
# ✅ Skipped NTCPH (already filled)
# ✅ Skipped KIMS (already filled)
# ✅ Skipped CONCORDB (already filled)
# ✅ Skipped AFH (already filled)
# ✅ Skipped TDI (already filled)
# ✅ Skipped AIL (already filled)
# ✅ Skipped SPADV (already filled)
# ✅ Skipped ADESE (already filled)
# ✅ Skipped AGR (already filled)
# ✅ Skipped CLPL (already filled)
# ✅ Skipped 078140 (already filled)
# ⚠ No company found for JUBLPHAR
# ✅ Skipped WPLZ11B (already filled)
# ✅ Skipped METROHL (already filled)
# ✅ Skipped NLL (already filled)
# ✅ Skipped JLHL (already filled)
# ✅ Skipped PGHL (already filled)
# ✅ Skipped C69 (already filled)
# ✅ Skipped FDCLT (already filled)
# ✅ Skipped MRKS (already filled)
# ✅ Skipped BLUEJET (already filled)
# ✅ Skipped VIJAYA (already filled)
# ✅ Skipped ORCP (already filled)
# ✅ Skipped HCG (already filled)
# ✅ Skipped CONCESI1 (already filled)
# ✅ Skipped ITMAM (already filled)
# ✅ Skipped AMIORG (already filled)
# ✅ Skipped SLPA (already filled)
# ✅ Skipped ARTD (already filled)
# ⚠ No company found for AARTIPHA
# ✅ Skipped CALL (already filled)
# ✅ Skipped YATHARTH (already filled)
# ✅ Skipped UL (already filled)
# ✅ Skipped HKCI (already filled)
# ✅ Skipped CUPD (already filled)
# ✅ Skipped THYROCAR (already filled)
# ✅ Skipped CNFS (already filled)
# ✅ Skipped GTB (already filled)
# ✅ Skipped MLSEQ (already filled)
# ✅ Skipped CF (already filled)
# ✅ Skipped SUPRIYA (already filled)
# ✅ Skipped SHALBY (already filled)
# ✅ Skipped INNOVACA (already filled)
# ✅ Skipped HCBA (already filled)
# ✅ Skipped RPGL (already filled)
# ✅ Skipped ARTMSL (already filled)
# ✅ Skipped SVLS (already filled)
# ✅ Skipped 090430 (already filled)
# ✅ Skipped ALBC (already filled)
# ✅ Skipped 3577 (already filled)
# ✅ Skipped TMCH (already filled)
# ✅ Skipped KRSNAA (already filled)
# ✅ Skipped LT (already filled)
# ✅ Skipped ADSEZ (already filled)
# ✅ Skipped HNAL (already filled)
# ✅ Skipped SEMC (already filled)
# ✅ Skipped IRFC (already filled)
# ✅ Skipped BHE (already filled)
# ✅ Skipped IDG (already filled)
# ✅ Skipped ABBANK (already filled)
# ✅ Skipped HAVL (already filled)
# ✅ Skipped BHEL (already filled)
# ✅ Skipped ASH (already filled)
# ✅ Skipped CGPOWER (already filled)
# ⚠ No company found for INDUSTOW
# ✅ Skipped POLYCAB (already filled)
# ✅ Skipped IRCTC (already filled)
# ✅ Skipped LTTS (already filled)
# ✅ Skipped CCRI (already filled)
# ✅ Skipped RVNL (already filled)
# ✅ Skipped BHFC (already filled)
# ✅ Skipped JSWINFRA (already filled)
# ✅ Skipped AL (already filled)
# ✅ Skipped TMX (already filled)
# ✅ Skipped GMRI (already filled)
# ✅ Skipped SCHFL (already filled)
# ✅ Skipped APT (already filled)
# ✅ Skipped MAZDOCKS (already filled)
# ✅ Skipped AIAE (already filled)
# ✅ Skipped 508096 (already filled)
# ✅ Skipped AEGIR (already filled)
# ✅ Skipped ATEL (already filled)
# ✅ Skipped DELHIVER (already filled)
# ✅ Skipped BDLAMP (already filled)
# ✅ Skipped BPBL (already filled)
# ✅ Skipped KEII (already filled)
# ✅ Skipped EFS (already filled)
# ✅ Skipped POWERIND (already filled)
# ✅ Skipped PLAP (already filled)
# ✅ Skipped BLSTR (already filled)
# ✅ Skipped SF (already filled)
# ✅ Skipped CMEI (already filled)
# ✅ Skipped CYL (already filled)
# ✅ Skipped TMKN (already filled)
# ✅ Skipped NBCC (already filled)
# ✅ Skipped CHOLAHLD (already filled)
# ✅ Skipped 002167 (already filled)
# ✅ Skipped SEKFK (already filled)
# ✅ Skipped ELEQ (already filled)
# ✅ Skipped JYOTICNC (already filled)
# ✅ Skipped SHNP (already filled)
# ✅ Skipped RRKABEL (already filled)
# ⚠ No company found for KPIL
# ✅ Skipped INDUC (already filled)
# ✅ Skipped ACEL (already filled)
# ✅ Skipped CELLO (already filled)
# ✅ Skipped ACEWIN (already filled)
# ✅ Skipped OLECTRA (already filled)
# ⚠ No company found for JWL
# ✅ Skipped FNXC (already filled)
# ✅ Skipped BDE (already filled)
# ✅ Skipped NJCC (already filled)
# ✅ Skipped VGRD (already filled)
# ✅ Skipped GSC1 (already filled)
# ✅ Skipped JSAW (already filled)
# ✅ Skipped DATAPATT (already filled)
# ✅ Skipped KSB (already filled)
# ✅ Skipped BEML (already filled)
# ✅ Skipped HMFC (already filled)
# ✅ Skipped BLSIN (already filled)
# ✅ Skipped GRINFRA (already filled)
# ✅ Skipped RMKF (already filled)
# ✅ Skipped TWL (already filled)
# ✅ Skipped AMG1L (already filled)
# ✅ Skipped AGL (already filled)
# ✅ Skipped SPPT (already filled)
# ✅ Skipped AIP (already filled)
# ✅ Skipped ENGR (already filled)
# ✅ Skipped MHS (already filled)
# ✅ Skipped PNCL (already filled)
# ✅ Skipped INOXINDI (already filled)
# ✅ Skipped ELCN (already filled)
# ✅ Skipped GPPV (already filled)
# ✅ Skipped VAMP (already filled)
# ✅ Skipped IPRJRA (already filled)
# ✅ Skipped AADI (already filled)
# ⚠ No company found for EUREKAFO
# ✅ Skipped KKB (already filled)
# ✅ Skipped GRSE (already filled)
# ✅ Skipped ITG (already filled)
# ✅ Skipped SYRMA (already filled)
# ✅ Skipped ESAB (already filled)
# ✅ Skipped AZAD (already filled)
# ✅ Skipped POWM (already filled)
# ✅ Skipped QUESS (already filled)
# ✅ Skipped 002578 (already filled)
# ✅ Skipped 8458 (already filled)
# ✅ Skipped MIDHANI (already filled)
# ✅ Skipped CHGG (already filled)
# ✅ Skipped AGLL (already filled)
# ✅ Skipped 688084 (already filled)
# ✅ Skipped KNRC (already filled)
# ✅ Skipped AHLU (already filled)
# ✅ Skipped TVSSCS (already filled)
# ✅ Skipped DBL (already filled)
# ✅ Skipped IGSEC (already filled)
# ✅ Skipped TXMRE (already filled)
# ✅ Skipped CMSINFO (already filled)
# ✅ Skipped TRPC (already filled)
# ✅ Skipped PRINCPIP (already filled)
# ✅ Skipped HGINFRA (already filled)
# ✅ Skipped SECIS (already filled)
# ✅ Skipped MSTCLTD (already filled)
# ✅ Skipped 124500 (already filled)
# ✅ Skipped CYIENTDL (already filled)
# ✅ Skipped SEDAPBC1 (already filled)
# ⚠ No company found for LLOYDSEN
# ✅ Skipped AGMMRA (already filled)
# ✅ Skipped SANSERA (already filled)
# ✅ Skipped 1552 (already filled)
# ✅ Skipped KNM (already filled)
# ✅ Skipped HMT (already filled)
# ✅ Skipped MTARTECH (already filled)
# ✅ Skipped JFI (already filled)
# ✅ Skipped GRFL (already filled)
# ✅ Skipped VRLL (already filled)
# ✅ Skipped JKIL (already filled)
# ✅ Skipped VATW (already filled)
# ✅ Skipped SJET (already filled)
# ✅ Skipped ABE (already filled)
# ✅ Skipped TDPS (already filled)
# ✅ Skipped KKPC (already filled)
# ✅ Skipped TIIL (already filled)
# ✅ Skipped 469480 (already filled)
# ✅ Skipped ASBL (already filled)
# ✅ Skipped BNCO (already filled)
# ✅ Skipped SG (already filled)
# ⚠ No company found for WELENT
# ✅ Skipped ORIENTEL (already filled)
# ✅ Skipped LGBB (already filled)
# ✅ Skipped TCIEXP (already filled)
# ✅ Skipped VENUSPIP (already filled)
# ✅ Skipped SKIPPER (already filled)
# ✅ Skipped RMKY (already filled)
# ✅ Skipped 2809 (already filled)
# ✅ Skipped DCXINDIA (already filled)
# ✅ Skipped JI (already filled)
# ✅ Skipped SECLTD (already filled)
# ✅ Skipped ANUP (already filled)
# ✅ Skipped 2208 (already filled)
# ✅ Skipped MAHLOG (already filled)
# ✅ Skipped SCT (already filled)
# 🔁 Retried and filled data for BFUT
# 🔁 Retried and filled data for VINL
# 🔁 Retried and filled data for VSTT
# 🔁 Retried and filled data for SM
# 🔁 Retried and filled data for APOLLO
# 🔁 Retried and filled data for SKPI
# ⚠ No company found for DIACABS
# 🔁 Retried and filled data for VT
# 🔁 Retried and filled data for NRBBR
# 🔁 Retried and filled data for JCHAC
# ⚠ No company found for GMRPUI
# ⚠ No company found for STYRENIX
# ⚠ No company found for BAJEL
# 🔁 Retried and filled data for PSPPL
# 🔁 Retried and filled data for PITTIENG
# 🔁 Retried and filled data for SHEP
# 🔁 Retried and filled data for PARAS
# 🔁 Retried and filled data for EXICOM
# 🔁 Retried and filled data for UNIPARTS
# 🔁 Retried and filled data for SEPC
# 🔁 Retried and filled data for MAN
# 🔁 Retried and filled data for AXET
# 🔁 Retried and filled data for PWI
# 🔁 Retried and filled data for WNDT
# ⚠ No company found for HONDAPWR
# 🔁 Retried and filled data for EMSLIMIT
# 🔁 Retried and filled data for CAPACITE
# ✅ Skipped IKIO (already filled)
# ✅ Skipped QUDS (already filled)
# ✅ Skipped MMFG (already filled)
# ⚠ No company found for BALUFORG
# ✅ Skipped TARSONS (already filled)
# ✅ Skipped GTLI (already filled)
# ✅ Skipped HPLE (already filled)
# ✅ Skipped ALK (already filled)
# ✅ Skipped IRMENERG (already filled)
# ✅ Skipped DCIL (already filled)
# ✅ Skipped BWRL (already filled)
# ✅ Skipped AAPLUSTR (already filled)
# ✅ Skipped UTCEM (already filled)
# ✅ Skipped APNT (already filled)
# ✅ Skipped AJC (already filled)
# ✅ Skipped JSTL (already filled)
# ✅ Skipped CTTH (already filled)
# ✅ Skipped GRASIM (already filled)
# ✅ Skipped LPD (already filled)
# ✅ Skipped ACEM (already filled)
# ✅ Skipped HNDL (already filled)
# ✅ Skipped HZ (already filled)
# ✅ Skipped VEDL (already filled)
# ✅ Skipped SRCM (already filled)
# ✅ Skipped DJSP (already filled)
# ✅ Skipped ARGO (already filled)
# ✅ Skipped SRF (already filled)
# ✅ Skipped TIINDIA (already filled)
# ✅ Skipped BRGR (already filled)
# ✅ Skipped NMDC (already filled)
# ✅ Skipped PI (already filled)
# ✅ Skipped JDSL (already filled)
# ✅ Skipped ALWASAIL (already filled)
# ✅ Skipped LIIL (already filled)
# ✅ Skipped SI (already filled)
# ✅ Skipped AAGRY (already filled)
# ✅ Skipped ACC (already filled)
# ✅ Skipped BFC (already filled)
# ✅ Skipped DALBHARA (already filled)
# ✅ Skipped 3M (already filled)
# ✅ Skipped UPLL (already filled)
# ✅ Skipped GFLC (already filled)
# ✅ Skipped ACRI (already filled)
# ✅ Skipped DJKC (already filled)
# ⚠ No company found for LLOYDSME
# ✅ Skipped DN (already filled)
# ✅ Skipped 8353 (already filled)
# ✅ Skipped TTCH (already filled)
# ✅ Skipped HCP (already filled)
# ✅ Skipped ARTO (already filled)
# ✅ Skipped CU (already filled)
# ✅ Skipped KIOCL (already filled)
# ✅ Skipped BYRCS (already filled)
# ✅ Skipped KNPL (already filled)
# ✅ Skipped GWN (already filled)
# ✅ Skipped ARMT34 (already filled)
# ✅ Skipped TRCL (already filled)
# ✅ Skipped CSTRL (already filled)
# ✅ Skipped C21 (already filled)
# ✅ Skipped SUMICHEM (already filled)
# ✅ Skipped ATP (already filled)
# ✅ Skipped SHYAMMET (already filled)
# ✅ Skipped CLL (already filled)
# ⚠ No company found for NSLNISP
# ✅ Skipped 6823 (already filled)
# ✅ Skipped FNXP (already filled)
# ✅ Skipped VO (already filled)
# ✅ Skipped JBIL (already filled)
# ✅ Skipped RLD (already filled)
# ✅ Skipped BASF (already filled)
# ✅ Skipped CPBI (already filled)
# ✅ Skipped ACE/F (already filled)
# ✅ Skipped CHMB (already filled)
# ✅ Skipped WLCO (already filled)
# ✅ Skipped FINEORG (already filled)
# ✅ Skipped HIMRRA (already filled)
# ✅ Skipped ELSC (already filled)
# ✅ Skipped BCORP (already filled)
# ✅ Skipped NUVOCO (already filled)
# ✅ Skipped GMDC (already filled)
# ✅ Skipped AKZO (already filled)
# ⚠ No company found for PTCIL
# ✅ Skipped ATHR (already filled)
# ✅ Skipped GODPI (already filled)
# ✅ Skipped JKLC (already filled)
# ⚠ No company found for PCBL
# ✅ Skipped AMG (already filled)
# ✅ Skipped ALEID (already filled)
# ✅ Skipped ANURAS (already filled)
# ✅ Skipped AACL (already filled)
# ✅ Skipped GNFC (already filled)
# ✅ Skipped STRCEM (already filled)
# ✅ Skipped PRSMJ (already filled)
# ✅ Skipped KHL (already filled)
# ✅ Skipped AAL (already filled)
# ✅ Skipped GALSURF (already filled)
# ✅ Skipped GSFC (already filled)
# ✅ Skipped BAAZEEM (already filled)
# ✅ Skipped 9625 (already filled)
# ✅ Skipped JUBLINGR (already filled)
# ✅ Skipped SEML (already filled)
# ✅ Skipped RCF (already filled)
# ✅ Skipped CHEMPLAS (already filled)
# ✅ Skipped EBECK (already filled)
# ✅ Skipped BLGV (already filled)
# ✅ Skipped VI (already filled)
# ✅ Skipped BLZE (already filled)
# ✅ Skipped BZU (already filled)
# ✅ Skipped LXCHEM (already filled)
# ✅ Skipped DFPC (already filled)
# ✅ Skipped GRLM (already filled)
# ✅ Skipped INDIGOPN (already filled)
# ⚠ No company found for SANDUMA
# ⚠ No company found for EPLL
# ✅ Skipped JMOIL (already filled)
# ✅ Skipped ATMCU (already filled)
# ✅ Skipped FSS (already filled)
# ✅ Skipped JKPAPER (already filled)
# ✅ Skipped PPARIVAH (already filled)
# ✅ Skipped AKGRT (already filled)
# ✅ Skipped RINDL (already filled)
# ✅ Skipped GALK (already filled)
# ✅ Skipped 5GN (already filled)
# ⚠ No company found for AGIG
# ✅ Skipped DAGRI (already filled)
# ✅ Skipped AJG (already filled)
# ✅ Skipped GOLI (already filled)
# ⚠ No company found for EPIGRAL
# ✅ Skipped D2B (already filled)
# ✅ Skipped JPA (already filled)
# ✅ Skipped CFLT (already filled)
# ✅ Skipped GHCL (already filled)
# ✅ Skipped BDSN (already filled)
# ✅ Skipped NOCIL (already filled)
# ✅ Skipped KKIL (already filled)
# ✅ Skipped BLCL (already filled)
# ✅ Skipped FTXC (already filled)
# ⚠ No company found for GRWRHITE
# ✅ Skipped ORCMNT (already filled)
# ✅ Skipped GW (already filled)
# ✅ Skipped WCPM (already filled)
# ✅ Skipped ADVENZY (already filled)
# ✅ Skipped PRIVISCL (already filled)
# ✅ Skipped GREENP (already filled)
# ✅ Skipped KS (already filled)
# ✅ Skipped ROSSARI (already filled)
# ✅ Skipped OMDC (already filled)
# ✅ Skipped BRSN (already filled)
# ⚠ No company found for LLOYDSET
# ✅ Skipped IMFA (already filled)
# ✅ Skipped ASMN (already filled)
# ✅ Skipped FCH (already filled)
# ✅ Skipped 5488 (already filled)
# ✅ Skipped YQ (already filled)
# ⚠ No company found for JTLIND
# ✅ Skipped KSCL (already filled)
# ✅ Skipped ATEC (already filled)
# ✅ Skipped NEOGEN (already filled)
# ✅ Skipped PKI (already filled)
# ✅ Skipped BWA (already filled)
# ✅ Skipped UFLX (already filled)
# ✅ Skipped SHCR (already filled)
# ✅ Skipped MTLM (already filled)
# ✅ Skipped LMAT (already filled)
# ✅ Skipped SHKL (already filled)
# ⚠ No company found for HLEGLAS
# ✅ Skipped ANG (already filled)
# ✅ Skipped SGC (already filled)
# ✅ Skipped SYIL (already filled)
# ✅ Skipped ISMT (already filled)
# ✅ Skipped MTEP (already filled)
# ✅ Skipped ARL (already filled)
# ✅ Skipped TATVA (already filled)
# ✅ Skipped APOLP (already filled)
# ✅ Skipped JMACU (already filled)
# ✅ Skipped PPC (already filled)
# ✅ Skipped PTMCD (already filled)
# ✅ Skipped 600143 (already filled)
# ✅ Skipped AXL (already filled)
# ✅ Skipped IGLY (already filled)
# ✅ Skipped APN (already filled)
# ✅ Skipped SNGI (already filled)
# ✅ Skipped APCO (already filled)
# ✅ Skipped 8049 (already filled)
# ✅ Skipped GOCL (already filled)
# ✅ Skipped KCPL (already filled)
# ✅ Skipped BEPL (already filled)
# ✅ Skipped RASTL (already filled)
# ✅ Skipped MASTERPL (already filled)
# ✅ Skipped AH (already filled)
# ✅ Skipped VCL (already filled)
# ✅ Skipped ASTEL (already filled)
# ✅ Skipped TCPL (already filled)
# ✅ Skipped FDMT (already filled)
# ✅ Skipped MGCXD (already filled)
# ✅ Skipped PNPC (already filled)
# ✅ Skipped JDPF (already filled)
# ✅ Skipped 5142 (already filled)
# ✅ Skipped TANF (already filled)
# ✅ Skipped IFGLRF (already filled)
# ⚠ No company found for ANHPR
# ⚠ No company found for UDAICEME
# ✅ Skipped DLFU (already filled)
# ✅ Skipped LODHA (already filled)
# ✅ Skipped CNT (already filled)
# ✅ Skipped HUTT (already filled)
# ✅ Skipped PHNX (already filled)
# ✅ Skipped PEPL (already filled)
# ✅ Skipped BRGD (already filled)
# ✅ Skipped GSS (already filled)
# ✅ Skipped CHALET (already filled)
# ✅ Skipped SOBHA (already filled)
# ✅ Skipped ARCP (already filled)
# ⚠ No company found for DBREALTY
# ✅ Skipped NTSD (already filled)
# ⚠ No company found for MAHLIFE
# ✅ Skipped RUSTOMJE (already filled)
# ⚠ No company found for EMBDL
# ✅ Skipped GHFC (already filled)
# ✅ Skipped ACOS (already filled)
# ✅ Skipped SNNP (already filled)
# ✅ Skipped HEMIPROP (already filled)
# ✅ Skipped PURVA (already filled)
# ✅ Skipped SAMHI (already filled)
# ✅ Skipped ANTAR (already filled)
# ⚠ No company found for MAXESTAT
# ✅ Skipped NIRL (already filled)
# ⚠ No company found for ARVSMART
# ✅ Skipped UT (already filled)
# ✅ Skipped ASFI (already filled)
# ✅ Skipped MNRT (already filled)
# ✅ Skipped SHRIRAMP (already filled)
# ✅ Skipped HLIX (already filled)
# ✅ Skipped III (already filled)
# ✅ Skipped HCLT (already filled)
# ✅ Skipped WPRO (already filled)
# ✅ Skipped ARH (already filled)
# ✅ Skipped 603015 (already filled)
# ✅ Skipped OFSS (already filled)
# ✅ Skipped PSYS (already filled)
# ✅ Skipped POLICYBZ (already filled)
# ✅ Skipped TELX (already filled)
# ✅ Skipped MPHL (already filled)
# ✅ Skipped DIXON (already filled)
# ✅ Skipped TATATECH (already filled)
# ⚠ No company found for COFORGE
# ✅ Skipped VCVCU (already filled)
# ✅ Skipped BSOFT (already filled)
# ✅ Skipped SSOF (already filled)
# ✅ Skipped KAYNES (already filled)
# ✅ Skipped 2051 (already filled)
# ✅ Skipped BIPP (already filled)
# ✅ Skipped FSOL (already filled)
# ✅ Skipped AEZS (already filled)
# ✅ Skipped ECLX (already filled)
# ✅ Skipped HAPPSTMN (already filled)
# ✅ Skipped TEJASNET (already filled)
# ✅ Skipped NEWGEN (already filled)
# ✅ Skipped ELK (already filled)
# ✅ Skipped LATENTVI (already filled)
# ✅ Skipped MAPMYIND (already filled)
# ✅ Skipped NETWEB (already filled)
# ✅ Skipped RATEGAIN (already filled)
# ✅ Skipped 603389 (already filled)
# ✅ Skipped ADDC (already filled)
# ✅ Skipped EMUDHRA (already filled)
# ✅ Skipped ASTM (already filled)
# ✅ Skipped AUPS (already filled)
# ✅ Skipped MCLOUD (already filled)
# ✅ Skipped ATHX (already filled)
# ✅ Skipped SOTL (already filled)
# ✅ Skipped AVL (already filled)
# ✅ Skipped PGEL (already filled)
# ✅ Skipped PROTEAN (already filled)
# ✅ Skipped BBOX (already filled)
# ✅ Skipped BIJL (already filled)
# ✅ Skipped CI (already filled)
# ✅ Skipped HGSL (already filled)
# ✅ Skipped AVACU (already filled)
# ✅ Skipped AFBI (already filled)
# ✅ Skipped 3260 (already filled)
# ✅ Skipped IDEAFORG (already filled)
# ✅ Skipped BCG (already filled)
# ✅ Skipped AAYANRE (already filled)
# ✅ Skipped QUICKHEA (already filled)
# ✅ Skipped ACCELYA (already filled)
# ✅ Skipped AVTS (already filled)
# ✅ Skipped ADAG (already filled)
# ✅ Skipped SASKEN (already filled)
# ✅ Skipped ABE (already filled)
# ✅ Skipped RPTECH (already filled)
# ⚠ No company found for RPSGVENT
# ✅ Skipped PRMC (already filled)
# ✅ Skipped EXPLEOSO (already filled)
# ✅ Skipped NTPCGREE (already filled)
# ✅ Skipped ADANIGR (already filled)
# ✅ Skipped PWGR (already filled)
# ✅ Skipped ADE (already filled)
# ✅ Skipped TPWR (already filled)
# ✅ Skipped ACC/P (already filled)
# ⚠ No company found for ADANIENS
# ✅ Skipped ATGL (already filled)
# ✅ Skipped NHPC (already filled)
# ✅ Skipped JSW (already filled)
# ✅ Skipped TPW (already filled)
# ✅ Skipped SJVN (already filled)
# ✅ Skipped GUJGA (already filled)
# ✅ Skipped NLC (already filled)
# ✅ Skipped BH/A (already filled)
# ✅ Skipped GETD (already filled)
# ✅ Skipped GUJS (already filled)
# ✅ Skipped BRKC (already filled)
# ✅ Skipped CESC (already filled)
# ✅ Skipped MAHGL (already filled)
# ✅ Skipped CDX (already filled)
# ✅ Skipped RPWR (already filled)
# ✅ Skipped ACC (already filled)
# ✅ Skipped JPVL (already filled)
# ✅ Skipped TWLV (already filled)
# ✅ Skipped BONAVB (already filled)
# ✅ Skipped PTCIN (already filled)
# ✅ Skipped RTPOW (already filled)
# ✅ Skipped BGIP3 (already filled)
# ✅ Retry complete. Updated file written to 'filtered_companies_retry.csv'

# %%
import csv
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Input and output paths
input_file = 'filtered_companies_retry.csv'
output_file = 'company_sasb_issues.csv'

# List of all 26 issues
all_issues = [
    "GHG Emissions", "Air Quality", "Energy Management", "Water & Wastewater Management",
    "Waste & Hazardous Materials Management", "Ecological Impacts", "Human Rights & Community Relations",
    "Customer Privacy", "Data Security", "Access & Affordability", "Product Quality & Safety", "Customer Welfare",
    "Selling Practices & Product Labeling", "Labour Practices", "Employee Health & Safety",
    "Employee Engagement, Diversity & Inclusion", "Product Design & Lifecycle Management",
    "Business Model Resilience", "Supply Chain Management", "Materials Sourcing & Efficiency",
    "Physical Impacts of Climate Change", "Business Ethics", "Competitive Behaviour",
    "Management of the Legal & Regulatory Environment", "Critical Incident Risk Management",
    "Systemic Risk Management"
]

# HTTP headers
headers = {"User-Agent": "Mozilla/5.0"}

# Load input companies
df = pd.read_csv(input_file)

# Open output CSV and write header
with open(output_file, 'w', newline='', encoding='utf-8') as f:
    fieldnames = ['Ticker'] + all_issues
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()

    for step, (_, row) in enumerate(df.iterrows(), start=1):
        ticker = row["company_ticker"]
        isin = row["isin"]
        url = f"https://sasb.ifrs.org/standards/materiality-finder/find/?company[0]={isin}"

        print(f"[Step {step}] Fetching for {ticker}...")

        try:
            response = requests.get(url, headers=headers)
            soup = BeautifulSoup(response.text, 'lxml')

            ul = soup.find("ul", class_="relevant-issues-list")
            if not ul:
                print(f"⚠ [Step {step}] No relevant issues list found for {ticker}")
                writer.writerow({"Ticker": ticker})  # Empty row with just ticker
                continue

            # Extract bold issues
            bold_issues = set(strong.get_text(strip=True) for strong in ul.find_all("strong"))

            # Build row data
            result = {"Ticker": ticker}
            for issue in all_issues:
                result[issue] = 1 if issue in bold_issues else ""

            writer.writerow(result)
            print(f"✔ [Step {step}] Written data for {ticker}")

        except Exception as e:
            print(f"❗ [Step {step}] Error for {ticker}: {e}")
            writer.writerow({"Ticker": ticker})  # Write fallback row

        time.sleep(0.5)  # Polite delay

print("✅ Done. Data saved to 'company_sasb_issues.csv'")
# Out:
# [Step 1] Fetching for BHARTI...
# ✔ [Step 1] Written data for BHARTI
# [Step 2] Fetching for ZOMATO...
# ✔ [Step 2] Written data for ZOMATO
# [Step 3] Fetching for INFOE...
# ✔ [Step 3] Written data for INFOE
# [Step 4] Fetching for AGS...
# ✔ [Step 4] Written data for AGS
# [Step 5] Fetching for 8071...
# ✔ [Step 5] Written data for 8071
# [Step 6] Fetching for SUNTV...
# ✔ [Step 6] Written data for SUNTV
# [Step 7] Fetching for AFFLE...
# ✔ [Step 7] Written data for AFFLE
# [Step 8] Fetching for TTLS...
# ✔ [Step 8] Written data for TTLS
# [Step 9] Fetching for Z...
# ✔ [Step 9] Written data for Z
# [Step 10] Fetching for RAILTEL...
# ✔ [Step 10] Written data for RAILTEL
# [Step 11] Fetching for NSG...
# ✔ [Step 11] Written data for NSG
# [Step 12] Fetching for 251270...
# ✔ [Step 12] Written data for 251270
# [Step 13] Fetching for ALAMAR...
# ✔ [Step 13] Written data for ALAMAR
# [Step 14] Fetching for EASEMYTR...
# ✔ [Step 14] Written data for EASEMYTR
# [Step 15] Fetching for JUST...
# ✔ [Step 15] Written data for JUST
# [Step 16] Fetching for WRLS...
# ✔ [Step 16] Written data for WRLS
# [Step 17] Fetching for TIPSMUSI...
# ⚠ [Step 17] No relevant issues list found for TIPSMUSI
# [Step 18] Fetching for NAZARA...
# ✔ [Step 18] Written data for NAZARA
# [Step 19] Fetching for DBCL...
# ✔ [Step 19] Written data for DBCL
# [Step 20] Fetching for 3662...
# ✔ [Step 20] Written data for 3662
# [Step 21] Fetching for BRK/A...
# ✔ [Step 21] Written data for BRK/A
# [Step 22] Fetching for CNLI...
# ✔ [Step 22] Written data for CNLI
# [Step 23] Fetching for DITV...
# ✔ [Step 23] Written data for DITV
# [Step 24] Fetching for CARTRADE...
# ✔ [Step 24] Written data for CARTRADE
# [Step 25] Fetching for PRIF...
# ✔ [Step 25] Written data for PRIF
# [Step 26] Fetching for ALEXSC...
# ✔ [Step 26] Written data for ALEXSC
# [Step 27] Fetching for PRAVEG...
# ⚠ [Step 27] No relevant issues list found for PRAVEG
# [Step 28] Fetching for 138SL...
# ✔ [Step 28] Written data for 138SL
# [Step 29] Fetching for YATRA...
# ✔ [Step 29] Written data for YATRA
# [Step 30] Fetching for JAGP...
# ✔ [Step 30] Written data for JAGP
# [Step 31] Fetching for OPIL...
# ✔ [Step 31] Written data for OPIL
# [Step 32] Fetching for MTNL...
# ✔ [Step 32] Written data for MTNL
# [Step 33] Fetching for 3996...
# ✔ [Step 33] Written data for 3996
# [Step 34] Fetching for GTPL...
# ✔ [Step 34] Written data for GTPL
# [Step 35] Fetching for DANGFLOU...
# ✔ [Step 35] Written data for DANGFLOU
# [Step 36] Fetching for MSIL...
# ✔ [Step 36] Written data for MSIL
# [Step 37] Fetching for ATANA...
# ✔ [Step 37] Written data for ATANA
# [Step 38] Fetching for TTMT...
# ✔ [Step 38] Written data for TTMT
# [Step 39] Fetching for BJAUT...
# ✔ [Step 39] Written data for BJAUT
# [Step 40] Fetching for MM...
# ✔ [Step 40] Written data for MM
# [Step 41] Fetching for NTGAZ...
# ✔ [Step 41] Written data for NTGAZ
# [Step 42] Fetching for 6156...
# ✔ [Step 42] Written data for 6156
# [Step 43] Fetching for TVSL...
# ✔ [Step 43] Written data for TVSL
# [Step 44] Fetching for HMCL...
# ✔ [Step 44] Written data for HMCL
# [Step 45] Fetching for ADAPRA...
# ✔ [Step 45] Written data for ADAPRA
# [Step 46] Fetching for IH...
# ✔ [Step 46] Written data for IH
# [Step 47] Fetching for MSS...
# ✔ [Step 47] Written data for MSS
# [Step 48] Fetching for MRCO...
# ✔ [Step 48] Written data for MRCO
# [Step 49] Fetching for MRFG3...
# ✔ [Step 49] Written data for MRFG3
# [Step 50] Fetching for NYKAA...
# ✔ [Step 50] Written data for NYKAA
# [Step 51] Fetching for MOBIL...
# ✔ [Step 51] Written data for MOBIL
# [Step 52] Fetching for KALYANKJ...
# ✔ [Step 52] Written data for KALYANKJ
# [Step 53] Fetching for SONACOMS...
# ✔ [Step 53] Written data for SONACOMS
# [Step 54] Fetching for KPITTECH...
# ✔ [Step 54] Written data for KPITTECH
# [Step 55] Fetching for UNOMINDA...
# ⚠ [Step 55] No relevant issues list found for UNOMINDA
# [Step 56] Fetching for PAGCC...
# ✔ [Step 56] Written data for PAGCC
# [Step 57] Fetching for TTMT/A...
# ✔ [Step 57] Written data for TTMT/A
# [Step 58] Fetching for METROBRA...
# ✔ [Step 58] Written data for METROBRA
# [Step 59] Fetching for ANAB...
# ✔ [Step 59] Written data for ANAB
# [Step 60] Fetching for ELKRRA...
# ✔ [Step 60] Written data for ELKRRA
# [Step 61] Fetching for MSUMI...
# ✔ [Step 61] Written data for MSUMI
# [Step 62] Fetching for ZCVCS...
# ⚠ [Step 62] No relevant issues list found for ZCVCS
# [Step 63] Fetching for KPR...
# ✔ [Step 63] Written data for KPR
# [Step 64] Fetching for 600538...
# ✔ [Step 64] Written data for 600538
# [Step 65] Fetching for EGEEN...
# ✔ [Step 65] Written data for EGEEN
# [Step 66] Fetching for MANYAVAR...
# ✔ [Step 66] Written data for MANYAVAR
# [Step 67] Fetching for JBMA...
# ✔ [Step 67] Written data for JBMA
# [Step 68] Fetching for ABC...
# ✔ [Step 68] Written data for ABC
# [Step 69] Fetching for ABFRL...
# ✔ [Step 69] Written data for ABFRL
# [Step 70] Fetching for RLXF...
# ✔ [Step 70] Written data for RLXF
# [Step 71] Fetching for JRELTD...
# ✔ [Step 71] Written data for JRELTD
# [Step 72] Fetching for KJC...
# ✔ [Step 72] Written data for KJC
# [Step 73] Fetching for ABAVP...
# ✔ [Step 73] Written data for ABAVP
# [Step 74] Fetching for CIEINDIA...
# ⚠ [Step 74] No relevant issues list found for CIEINDIA
# [Step 75] Fetching for BC...
# ✔ [Step 75] Written data for BC
# [Step 76] Fetching for TVSHLTD...
# ⚠ [Step 76] No relevant issues list found for TVSHLTD
# [Step 77] Fetching for INMART...
# ✔ [Step 77] Written data for INMART
# [Step 78] Fetching for 600172...
# ✔ [Step 78] Written data for 600172
# [Step 79] Fetching for ARENM...
# ⚠ [Step 79] No relevant issues list found for ARENM
# [Step 80] Fetching for WELSPUNL...
# ⚠ [Step 80] No relevant issues list found for WELSPUNL
# [Step 81] Fetching for HONASA...
# ✔ [Step 81] Written data for HONASA
# [Step 82] Fetching for PVRINOX...
# ⚠ [Step 82] No relevant issues list found for PVRINOX
# [Step 83] Fetching for AISG...
# ✔ [Step 83] Written data for AISG
# [Step 84] Fetching for VTEX...
# ✔ [Step 84] Written data for VTEX
# [Step 85] Fetching for ALOK...
# ✔ [Step 85] Written data for ALOK
# [Step 86] Fetching for WLDL...
# ✔ [Step 86] Written data for WLDL
# [Step 87] Fetching for FHW...
# ✔ [Step 87] Written data for FHW
# [Step 88] Fetching for RW...
# ✔ [Step 88] Written data for RW
# [Step 89] Fetching for JUNIPER...
# ✔ [Step 89] Written data for JUNIPER
# [Step 90] Fetching for JKI...
# ✔ [Step 90] Written data for JKI
# [Step 91] Fetching for CEAT...
# ✔ [Step 91] Written data for CEAT
# [Step 92] Fetching for BJE...
# ✔ [Step 92] Written data for BJE
# [Step 93] Fetching for LEMONTRE...
# ✔ [Step 93] Written data for LEMONTRE
# [Step 94] Fetching for 159010...
# ✔ [Step 94] Written data for 159010
# [Step 95] Fetching for ASAME...
# ✔ [Step 95] Written data for ASAME
# [Step 96] Fetching for 71M...
# ✔ [Step 96] Written data for 71M
# [Step 97] Fetching for MMTC...
# ✔ [Step 97] Written data for MMTC
# [Step 98] Fetching for FML...
# ✔ [Step 98] Written data for FML
# [Step 99] Fetching for DOMS...
# ✔ [Step 99] Written data for DOMS
# [Step 100] Fetching for TTKPT...
# ✔ [Step 100] Written data for TTKPT
# [Step 101] Fetching for CRAFTSMA...
# ✔ [Step 101] Written data for CRAFTSMA
# [Step 102] Fetching for REDTAPE...
# ⚠ [Step 102] No relevant issues list found for REDTAPE
# [Step 103] Fetching for 2CRSI...
# ✔ [Step 103] Written data for 2CRSI
# [Step 104] Fetching for ALDV...
# ✔ [Step 104] Written data for ALDV
# [Step 105] Fetching for HAPPYFOR...
# ✔ [Step 105] Written data for HAPPYFOR
# [Step 106] Fetching for THDS...
# ✔ [Step 106] Written data for THDS
# [Step 107] Fetching for MHSC...
# ✔ [Step 107] Written data for MHSC
# [Step 108] Fetching for MHRL...
# ✔ [Step 108] Written data for MHRL
# [Step 109] Fetching for TC...
# ✔ [Step 109] Written data for TC
# [Step 110] Fetching for RJEX...
# ✔ [Step 110] Written data for RJEX
# [Step 111] Fetching for VARROC...
# ✔ [Step 111] Written data for VARROC
# [Step 112] Fetching for ENVI...
# ✔ [Step 112] Written data for ENVI
# [Step 113] Fetching for CMNT...
# ✔ [Step 113] Written data for CMNT
# [Step 114] Fetching for ARVND...
# ✔ [Step 114] Written data for ARVND
# [Step 115] Fetching for ENTRA...
# ✔ [Step 115] Written data for ENTRA
# [Step 116] Fetching for NIITMTS...
# ⚠ [Step 116] No relevant issues list found for NIITMTS
# [Step 117] Fetching for GTFL...
# ✔ [Step 117] Written data for GTFL
# [Step 118] Fetching for ACC...
# ✔ [Step 118] Written data for ACC
# [Step 119] Fetching for BORORENE...
# ⚠ [Step 119] No relevant issues list found for BORORENE
# [Step 120] Fetching for GOCOLORS...
# ✔ [Step 120] Written data for GOCOLORS
# [Step 121] Fetching for ETHOSLTD...
# ✔ [Step 121] Written data for ETHOSLTD
# [Step 122] Fetching for JINW...
# ✔ [Step 122] Written data for JINW
# [Step 123] Fetching for PDSL...
# ✔ [Step 123] Written data for PDSL
# [Step 124] Fetching for IFBI...
# ✔ [Step 124] Written data for IFBI
# [Step 125] Fetching for VGM...
# ✔ [Step 125] Written data for VGM
# [Step 126] Fetching for ARVINDFA...
# ✔ [Step 126] Written data for ARVINDFA
# [Step 127] Fetching for SENCO...
# ✔ [Step 127] Written data for SENCO
# [Step 128] Fetching for SYML...
# ✔ [Step 128] Written data for SYML
# [Step 129] Fetching for 140910...
# ✔ [Step 129] Written data for 140910
# [Step 130] Fetching for ASKAUTOL...
# ✔ [Step 130] Written data for ASKAUTOL
# [Step 131] Fetching for WONH...
# ✔ [Step 131] Written data for WONH
# [Step 132] Fetching for SGMART...
# ⚠ [Step 132] No relevant issues list found for SGMART
# [Step 133] Fetching for ITDC...
# ✔ [Step 133] Written data for ITDC
# [Step 134] Fetching for JMNA...
# ✔ [Step 134] Written data for JMNA
# [Step 135] Fetching for DYTC...
# ✔ [Step 135] Written data for DYTC
# [Step 136] Fetching for 3467...
# ✔ [Step 136] Written data for 3467
# [Step 137] Fetching for DAD...
# ✔ [Step 137] Written data for DAD
# [Step 138] Fetching for ROLEXRIN...
# ✔ [Step 138] Written data for ROLEXRIN
# [Step 139] Fetching for PRICOL...
# ✔ [Step 139] Written data for PRICOL
# [Step 140] Fetching for GEXP...
# ✔ [Step 140] Written data for GEXP
# [Step 141] Fetching for 6473...
# ✔ [Step 141] Written data for 6473
# [Step 142] Fetching for VMART...
# ✔ [Step 142] Written data for VMART
# [Step 143] Fetching for KEKC...
# ✔ [Step 143] Written data for KEKC
# [Step 144] Fetching for BOROLTD...
# ✔ [Step 144] Written data for BOROLTD
# [Step 145] Fetching for PARKHOTE...
# ✔ [Step 145] Written data for PARKHOTE
# [Step 146] Fetching for AMOR...
# ✔ [Step 146] Written data for AMOR
# [Step 147] Fetching for IMAGICAA...
# ⚠ [Step 147] No relevant issues list found for IMAGICAA
# [Step 148] Fetching for TJL...
# ✔ [Step 148] Written data for TJL
# [Step 149] Fetching for KPDL...
# ✔ [Step 149] Written data for KPDL
# [Step 150] Fetching for brad...
# ✔ [Step 150] Written data for brad
# [Step 151] Fetching for SUBR...
# ✔ [Step 151] Written data for SUBR
# [Step 152] Fetching for LMAX...
# ✔ [Step 152] Written data for LMAX
# [Step 153] Fetching for BD...
# ✔ [Step 153] Written data for BD
# [Step 154] Fetching for 4609...
# ✔ [Step 154] Written data for 4609
# [Step 155] Fetching for BKHAU...
# ✔ [Step 155] Written data for BKHAU
# [Step 156] Fetching for SANDHAR...
# ✔ [Step 156] Written data for SANDHAR
# [Step 157] Fetching for KDDL...
# ✔ [Step 157] Written data for KDDL
# [Step 158] Fetching for LIK...
# ✔ [Step 158] Written data for LIK
# [Step 159] Fetching for KTI...
# ✔ [Step 159] Written data for KTI
# [Step 160] Fetching for FIEM...
# ✔ [Step 160] Written data for FIEM
# [Step 161] Fetching for SRTY...
# ✔ [Step 161] Written data for SRTY
# [Step 162] Fetching for NINE...
# ✔ [Step 162] Written data for NINE
# [Step 163] Fetching for GRV...
# ✔ [Step 163] Written data for GRV
# [Step 164] Fetching for DG...
# ✔ [Step 164] Written data for DG
# [Step 165] Fetching for SUNCLAY...
# ⚠ [Step 165] No relevant issues list found for SUNCLAY
# [Step 166] Fetching for BLSE...
# ✔ [Step 166] Written data for BLSE
# [Step 167] Fetching for ASAB...
# ✔ [Step 167] Written data for ASAB
# [Step 168] Fetching for HINDWARE...
# ⚠ [Step 168] No relevant issues list found for HINDWARE
# [Step 169] Fetching for ATXL...
# ✔ [Step 169] Written data for ATXL
# [Step 170] Fetching for FLAIR...
# ✔ [Step 170] Written data for FLAIR
# [Step 171] Fetching for CARYSIL...
# ⚠ [Step 171] No relevant issues list found for CARYSIL
# [Step 172] Fetching for FLTX...
# ✔ [Step 172] Written data for FLTX
# [Step 173] Fetching for DREAMFOL...
# ✔ [Step 173] Written data for DREAMFOL
# [Step 174] Fetching for NILK...
# ✔ [Step 174] Written data for NILK
# [Step 175] Fetching for GDYR...
# ✔ [Step 175] Written data for GDYR
# [Step 176] Fetching for PCJL...
# ✔ [Step 176] Written data for PCJL
# [Step 177] Fetching for GNPL...
# ✔ [Step 177] Written data for GNPL
# [Step 178] Fetching for TAJG...
# ✔ [Step 178] Written data for TAJG
# [Step 179] Fetching for SOMC...
# ✔ [Step 179] Written data for SOMC
# [Step 180] Fetching for PGIL...
# ✔ [Step 180] Written data for PGIL
# [Step 181] Fetching for DIVGIITT...
# ✔ [Step 181] Written data for DIVGIITT
# [Step 182] Fetching for OAH...
# ✔ [Step 182] Written data for OAH
# [Step 183] Fetching for LUMX...
# ✔ [Step 183] Written data for LUMX
# [Step 184] Fetching for SNGM...
# ✔ [Step 184] Written data for SNGM
# [Step 185] Fetching for TCNSBR...
# ✔ [Step 185] Written data for TCNSBR
# [Step 186] Fetching for AOTHAIM...
# ✔ [Step 186] Written data for AOTHAIM
# [Step 187] Fetching for ONE...
# ✔ [Step 187] Written data for ONE
# [Step 188] Fetching for ASIY...
# ✔ [Step 188] Written data for ASIY
# [Step 189] Fetching for WMS...
# ✔ [Step 189] Written data for WMS
# [Step 190] Fetching for BARBEQUE...
# ✔ [Step 190] Written data for BARBEQUE
# [Step 191] Fetching for ADRS-R-A...
# ✔ [Step 191] Written data for ADRS-R-A
# [Step 192] Fetching for JSNV...
# ✔ [Step 192] Written data for JSNV
# [Step 193] Fetching for PRECAM...
# ✔ [Step 193] Written data for PRECAM
# [Step 194] Fetching for FILATFAS...
# ⚠ [Step 194] No relevant issues list found for FILATFAS
# [Step 195] Fetching for ANF...
# ✔ [Step 195] Written data for ANF
# [Step 196] Fetching for HUVR...
# ✔ [Step 196] Written data for HUVR
# [Step 197] Fetching for DMART...
# ✔ [Step 197] Written data for DMART
# [Step 198] Fetching for 6381...
# ✔ [Step 198] Written data for 6381
# [Step 199] Fetching for VBL...
# ✔ [Step 199] Written data for VBL
# [Step 200] Fetching for GCPL...
# ✔ [Step 200] Written data for GCPL
# [Step 201] Fetching for ASBE...
# ✔ [Step 201] Written data for ASBE
# [Step 202] Fetching for TATACONS...
# ⚠ [Step 202] No relevant issues list found for TATACONS
# [Step 203] Fetching for DABUR...
# ✔ [Step 203] Written data for DABUR
# [Step 204] Fetching for UNITDSPR...
# ⚠ [Step 204] No relevant issues list found for UNITDSPR
# [Step 205] Fetching for CLGT...
# ✔ [Step 205] Written data for CLGT
# [Step 206] Fetching for PG...
# ✔ [Step 206] Written data for PG
# [Step 207] Fetching for PATANJAL...
# ✔ [Step 207] Written data for PATANJAL
# [Step 208] Fetching for DUBA...
# ✔ [Step 208] Written data for DUBA
# [Step 209] Fetching for AWLTD...
# ✔ [Step 209] Written data for AWLTD
# [Step 210] Fetching for GDSP...
# ✔ [Step 210] Written data for GDSP
# [Step 211] Fetching for RDCK...
# ✔ [Step 211] Written data for RDCK
# [Step 212] Fetching for HTSMF...
# ✔ [Step 212] Written data for HTSMF
# [Step 213] Fetching for AGILC...
# ✔ [Step 213] Written data for AGILC
# [Step 214] Fetching for HMN...
# ✔ [Step 214] Written data for HMN
# [Step 215] Fetching for DEVYANI...
# ✔ [Step 215] Written data for DEVYANI
# [Step 216] Fetching for JYL...
# ✔ [Step 216] Written data for JYL
# [Step 217] Fetching for GP...
# ✔ [Step 217] Written data for GP
# [Step 218] Fetching for DCMS...
# ✔ [Step 218] Written data for DCMS
# [Step 219] Fetching for BIKAJI...
# ✔ [Step 219] Written data for BIKAJI
# [Step 220] Fetching for BBTC...
# ✔ [Step 220] Written data for BBTC
# [Step 221] Fetching for ZYWL...
# ✔ [Step 221] Written data for ZYWL
# [Step 222] Fetching for GOAGRO...
# ✔ [Step 222] Written data for GOAGRO
# [Step 223] Fetching for SHRS...
# ✔ [Step 223] Written data for SHRS
# [Step 224] Fetching for MEDPLUS...
# ✔ [Step 224] Written data for MEDPLUS
# [Step 225] Fetching for CCLP...
# ✔ [Step 225] Written data for CCLP
# [Step 226] Fetching for GAEX...
# ✔ [Step 226] Written data for GAEX
# [Step 227] Fetching for BRCM...
# ✔ [Step 227] Written data for BRCM
# [Step 228] Fetching for BINHO...
# ✔ [Step 228] Written data for BINHO
# [Step 229] Fetching for AVNT...
# ✔ [Step 229] Written data for AVNT
# [Step 230] Fetching for BECTORS...
# ✔ [Step 230] Written data for BECTORS
# [Step 231] Fetching for LTFOODS...
# ⚠ [Step 231] No relevant issues list found for LTFOODS
# [Step 232] Fetching for KOR...
# ✔ [Step 232] Written data for KOR
# [Step 233] Fetching for IVE...
# ✔ [Step 233] Written data for IVE
# [Step 234] Fetching for HNDFDS...
# ⚠ [Step 234] No relevant issues list found for HNDFDS
# [Step 235] Fetching for DODLA...
# ✔ [Step 235] Written data for DODLA
# [Step 236] Fetching for ASK...
# ✔ [Step 236] Written data for ASK
# [Step 237] Fetching for BCOL...
# ✔ [Step 237] Written data for BCOL
# [Step 238] Fetching for TLNGR...
# ✔ [Step 238] Written data for TLNGR
# [Step 239] Fetching for BJH...
# ✔ [Step 239] Written data for BJH
# [Step 240] Fetching for TSTY...
# ✔ [Step 240] Written data for TSTY
# [Step 241] Fetching for HTFL...
# ✔ [Step 241] Written data for HTFL
# [Step 242] Fetching for 4BO...
# ✔ [Step 242] Written data for 4BO
# [Step 243] Fetching for BAJAJCON...
# ✔ [Step 243] Written data for BAJAJCON
# [Step 244] Fetching for BNRI...
# ✔ [Step 244] Written data for BNRI
# [Step 245] Fetching for PCAI...
# ✔ [Step 245] Written data for PCAI
# [Step 246] Fetching for DCB...
# ✔ [Step 246] Written data for DCB
# [Step 247] Fetching for HMAAGRO...
# ✔ [Step 247] Written data for HMAAGRO
# [Step 248] Fetching for ADM...
# ✔ [Step 248] Written data for ADM
# [Step 249] Fetching for EVRIN...
# ✔ [Step 249] Written data for EVRIN
# [Step 250] Fetching for MANORAMA...
# ✔ [Step 250] Written data for MANORAMA
# [Step 251] Fetching for VSFI...
# ✔ [Step 251] Written data for VSFI
# [Step 252] Fetching for ALKDI...
# ✔ [Step 252] Written data for ALKDI
# [Step 253] Fetching for WH...
# ✔ [Step 253] Written data for WH
# [Step 254] Fetching for TTKP...
# ✔ [Step 254] Written data for TTKP
# [Step 255] Fetching for DBOS...
# ✔ [Step 255] Written data for DBOS
# [Step 256] Fetching for ADFL...
# ✔ [Step 256] Written data for ADFL
# [Step 257] Fetching for GBSL...
# ✔ [Step 257] Written data for GBSL
# [Step 258] Fetching for EUPIC...
# ✔ [Step 258] Written data for EUPIC
# [Step 259] Fetching for 000419...
# ✔ [Step 259] Written data for 000419
# [Step 260] Fetching for IOCL...
# ✔ [Step 260] Written data for IOCL
# [Step 261] Fetching for BPCL...
# ✔ [Step 261] Written data for BPCL
# [Step 262] Fetching for HPCL...
# ✔ [Step 262] Written data for HPCL
# [Step 263] Fetching for OINL...
# ✔ [Step 263] Written data for OINL
# [Step 264] Fetching for SUEL...
# ✔ [Step 264] Written data for SUEL
# [Step 265] Fetching for PLNG...
# ✔ [Step 265] Written data for PLNG
# [Step 266] Fetching for MRPL...
# ✔ [Step 266] Written data for MRPL
# [Step 267] Fetching for IREDA...
# ✔ [Step 267] Written data for IREDA
# [Step 268] Fetching for EXID...
# ✔ [Step 268] Written data for EXID
# [Step 269] Fetching for INXW...
# ✔ [Step 269] Written data for INXW
# [Step 270] Fetching for AEGISLOG...
# ⚠ [Step 270] No relevant issues list found for AEGISLOG
# [Step 271] Fetching for WAREERTL...
# ⚠ [Step 271] No relevant issues list found for WAREERTL
# [Step 272] Fetching for MRL...
# ✔ [Step 272] Written data for MRL
# [Step 273] Fetching for HBPS...
# ✔ [Step 273] Written data for HBPS
# [Step 274] Fetching for SWSOLAR...
# ✔ [Step 274] Written data for SWSOLAR
# [Step 275] Fetching for KPIG...
# ✔ [Step 275] Written data for KPIG
# [Step 276] Fetching for TECHNOE...
# ✔ [Step 276] Written data for TECHNOE
# [Step 277] Fetching for 2159...
# ✔ [Step 277] Written data for 2159
# [Step 278] Fetching for HARSHA...
# ✔ [Step 278] Written data for HARSHA
# [Step 279] Fetching for INOXGREE...
# ✔ [Step 279] Written data for INOXGREE
# [Step 280] Fetching for 247...
# ✔ [Step 280] Written data for 247
# [Step 281] Fetching for GENSOL...
# ✔ [Step 281] Written data for GENSOL
# [Step 282] Fetching for 002956...
# ✔ [Step 282] Written data for 002956
# [Step 283] Fetching for AVOT...
# ✔ [Step 283] Written data for AVOT
# [Step 284] Fetching for 002467...
# ✔ [Step 284] Written data for 002467
# [Step 285] Fetching for KPEL...
# ✔ [Step 285] Written data for KPEL
# [Step 286] Fetching for WESL...
# ✔ [Step 286] Written data for WESL
# [Step 287] Fetching for DEEPIND...
# ⚠ [Step 287] No relevant issues list found for DEEPIND
# [Step 288] Fetching for GANDHAR...
# ✔ [Step 288] Written data for GANDHAR
# [Step 289] Fetching for RIIL...
# ✔ [Step 289] Written data for RIIL
# [Step 290] Fetching for HDFCB...
# ✔ [Step 290] Written data for HDFCB
# [Step 291] Fetching for ICICIBC...
# ✔ [Step 291] Written data for ICICIBC
# [Step 292] Fetching for SBINS...
# ✔ [Step 292] Written data for SBINS
# [Step 293] Fetching for BESS...
# ✔ [Step 293] Written data for BESS
# [Step 294] Fetching for 603489...
# ✔ [Step 294] Written data for 603489
# [Step 295] Fetching for BERA...
# ✔ [Step 295] Written data for BERA
# [Step 296] Fetching for AXSB...
# ✔ [Step 296] Written data for AXSB
# [Step 297] Fetching for BJFIN...
# ✔ [Step 297] Written data for BJFIN
# [Step 298] Fetching for JIOFIN...
# ✔ [Step 298] Written data for JIOFIN
# [Step 299] Fetching for SBILIFE...
# ✔ [Step 299] Written data for SBILIFE
# [Step 300] Fetching for AHP...
# ✔ [Step 300] Written data for AHP
# [Step 301] Fetching for BOB...
# ✔ [Step 301] Written data for BOB
# [Step 302] Fetching for HDFCLIFE...
# ✔ [Step 302] Written data for HDFCLIFE
# [Step 303] Fetching for POWF...
# ✔ [Step 303] Written data for POWF
# [Step 304] Fetching for IIB...
# ✔ [Step 304] Written data for IIB
# [Step 305] Fetching for MTBC...
# ✔ [Step 305] Written data for MTBC
# [Step 306] Fetching for UNBK...
# ✔ [Step 306] Written data for UNBK
# [Step 307] Fetching for BOOM...
# ✔ [Step 307] Written data for BOOM
# [Step 308] Fetching for CBK...
# ✔ [Step 308] Written data for CBK
# [Step 309] Fetching for 000996...
# ✔ [Step 309] Written data for 000996
# [Step 310] Fetching for BJHI...
# ✔ [Step 310] Written data for BJHI
# [Step 311] Fetching for SHFL...
# ⚠ [Step 311] No relevant issues list found for SHFL
# [Step 312] Fetching for AFRIPRUD...
# ✔ [Step 312] Written data for AFRIPRUD
# [Step 313] Fetching for IDBI...
# ✔ [Step 313] Written data for IDBI
# [Step 314] Fetching for ICICIGI...
# ✔ [Step 314] Written data for ICICIGI
# [Step 315] Fetching for HDFCAMC...
# ✔ [Step 315] Written data for HDFCAMC
# [Step 316] Fetching for INBK...
# ✔ [Step 316] Written data for INBK
# [Step 317] Fetching for AYES...
# ✔ [Step 317] Written data for AYES
# [Step 318] Fetching for SBICARD...
# ✔ [Step 318] Written data for SBICARD
# [Step 319] Fetching for ACUC...
# ✔ [Step 319] Written data for ACUC
# [Step 320] Fetching for ABTZY...
# ✔ [Step 320] Written data for ABTZY
# [Step 321] Fetching for BEDM...
# ✔ [Step 321] Written data for BEDM
# [Step 322] Fetching for GICRE...
# ✔ [Step 322] Written data for GICRE
# [Step 323] Fetching for IDFCFB...
# ✔ [Step 323] Written data for IDFCFB
# [Step 324] Fetching for CBOI...
# ✔ [Step 324] Written data for CBOI
# [Step 325] Fetching for 000777...
# ✔ [Step 325] Written data for 000777
# [Step 326] Fetching for ABCAP...
# ✔ [Step 326] Written data for ABCAP
# [Step 327] Fetching for BOMH...
# ✔ [Step 327] Written data for BOMH
# [Step 328] Fetching for PJSB...
# ✔ [Step 328] Written data for PJSB
# [Step 329] Fetching for LTF...
# ⚠ [Step 329] No relevant issues list found for LTF
# [Step 330] Fetching for AUBANK...
# ✔ [Step 330] Written data for AUBANK
# [Step 331] Fetching for NIACL...
# ✔ [Step 331] Written data for NIACL
# [Step 332] Fetching for HUDCO...
# ✔ [Step 332] Written data for HUDCO
# [Step 333] Fetching for CRISIL...
# ✔ [Step 333] Written data for CRISIL
# [Step 334] Fetching for FB...
# ✔ [Step 334] Written data for FB
# [Step 335] Fetching for POONAWAL...
# ⚠ [Step 335] No relevant issues list found for POONAWAL
# [Step 336] Fetching for MMFS...
# ✔ [Step 336] Written data for MMFS
# [Step 337] Fetching for LICHF...
# ✔ [Step 337] Written data for LICHF
# [Step 338] Fetching for STARHEAL...
# ✔ [Step 338] Written data for STARHEAL
# [Step 339] Fetching for ABDP...
# ✔ [Step 339] Written data for ABDP
# [Step 340] Fetching for BANDHAN...
# ✔ [Step 340] Written data for BANDHAN
# [Step 341] Fetching for PAYTM...
# ✔ [Step 341] Written data for PAYTM
# [Step 342] Fetching for ANGELONE...
# ⚠ [Step 342] No relevant issues list found for ANGELONE
# [Step 343] Fetching for MOFS...
# ✔ [Step 343] Written data for MOFS
# [Step 344] Fetching for ISEC...
# ✔ [Step 344] Written data for ISEC
# [Step 345] Fetching for CREDAG...
# ✔ [Step 345] Written data for CREDAG
# [Step 346] Fetching for FIVESTAR...
# ✔ [Step 346] Written data for FIVESTAR
# [Step 347] Fetching for PIEL...
# ✔ [Step 347] Written data for PIEL
# [Step 348] Fetching for IDFCFB...
# ✔ [Step 348] Written data for IDFCFB
# [Step 349] Fetching for MCX...
# ✔ [Step 349] Written data for MCX
# [Step 350] Fetching for CGCL...
# ✔ [Step 350] Written data for CGCL
# [Step 351] Fetching for PNBHOUSI...
# ✔ [Step 351] Written data for PNBHOUSI
# [Step 352] Fetching for APTUS...
# ✔ [Step 352] Written data for APTUS
# [Step 353] Fetching for JKBK...
# ✔ [Step 353] Written data for JKBK
# [Step 354] Fetching for KVB...
# ✔ [Step 354] Written data for KVB
# [Step 355] Fetching for MGFL...
# ✔ [Step 355] Written data for MGFL
# [Step 356] Fetching for BKBR3...
# ✔ [Step 356] Written data for BKBR3
# [Step 357] Fetching for 2662...
# ✔ [Step 357] Written data for 2662
# [Step 358] Fetching for ABSLAMC...
# ✔ [Step 358] Written data for ABSLAMC
# [Step 359] Fetching for IIFL...
# ✔ [Step 359] Written data for IIFL
# [Step 360] Fetching for SAMMAANC...
# ⚠ [Step 360] No relevant issues list found for SAMMAANC
# [Step 361] Fetching for AIIL...
# ⚠ [Step 361] No relevant issues list found for AIIL
# [Step 362] Fetching for EQUITASB...
# ✔ [Step 362] Written data for EQUITASB
# [Step 363] Fetching for KFINTECH...
# ✔ [Step 363] Written data for KFINTECH
# [Step 364] Fetching for AAVAS...
# ✔ [Step 364] Written data for AAVAS
# [Step 365] Fetching for UTIAM...
# ✔ [Step 365] Written data for UTIAM
# [Step 366] Fetching for CANF...
# ✔ [Step 366] Written data for CANF
# [Step 367] Fetching for CUBK...
# ✔ [Step 367] Written data for CUBK
# [Step 368] Fetching for IFCI...
# ✔ [Step 368] Written data for IFCI
# [Step 369] Fetching for ABG...
# ✔ [Step 369] Written data for ABG
# [Step 370] Fetching for INFIBEAM...
# ✔ [Step 370] Written data for INFIBEAM
# [Step 371] Fetching for SBFC...
# ✔ [Step 371] Written data for SBFC
# [Step 372] Fetching for UJJIVANS...
# ✔ [Step 372] Written data for UJJIVANS
# [Step 373] Fetching for BLZE...
# ✔ [Step 373] Written data for BLZE
# [Step 374] Fetching for SWH...
# ✔ [Step 374] Written data for SWH
# [Step 375] Fetching for HOMEFIRS...
# ✔ [Step 375] Written data for HOMEFIRS
# [Step 376] Fetching for TMB...
# ✔ [Step 376] Written data for TMB
# [Step 377] Fetching for CAIN...
# ✔ [Step 377] Written data for CAIN
# [Step 378] Fetching for JM...
# ✔ [Step 378] Written data for JM
# [Step 379] Fetching for NTGAZ...
# ✔ [Step 379] Written data for NTGAZ
# [Step 380] Fetching for INDIASHL...
# ✔ [Step 380] Written data for INDIASHL
# [Step 381] Fetching for SISLTD...
# ✔ [Step 381] Written data for SISLTD
# [Step 382] Fetching for CSBBANK...
# ✔ [Step 382] Written data for CSBBANK
# [Step 383] Fetching for SPANDANA...
# ✔ [Step 383] Written data for SPANDANA
# [Step 384] Fetching for BMM...
# ✔ [Step 384] Written data for BMM
# [Step 385] Fetching for GMON...
# ✔ [Step 385] Written data for GMON
# [Step 386] Fetching for UJJIVAN...
# ✔ [Step 386] Written data for UJJIVAN
# [Step 387] Fetching for CFIS...
# ✔ [Step 387] Written data for CFIS
# [Step 388] Fetching for PAISALO...
# ✔ [Step 388] Written data for PAISALO
# [Step 389] Fetching for FZICRA...
# ✔ [Step 389] Written data for FZICRA
# [Step 390] Fetching for UTKARSHB...
# ✔ [Step 390] Written data for UTKARSHB
# [Step 391] Fetching for BMEA...
# ✔ [Step 391] Written data for BMEA
# [Step 392] Fetching for MASFIN...
# ✔ [Step 392] Written data for MASFIN
# [Step 393] Fetching for SINDHUTR...
# ⚠ [Step 393] No relevant issues list found for SINDHUTR
# [Step 394] Fetching for JSFB...
# ✔ [Step 394] Written data for JSFB
# [Step 395] Fetching for FEDFINA...
# ✔ [Step 395] Written data for FEDFINA
# [Step 396] Fetching for PIICL...
# ✔ [Step 396] Written data for PIICL
# [Step 397] Fetching for IIFLSEC...
# ✔ [Step 397] Written data for IIFLSEC
# [Step 398] Fetching for DCBB...
# ✔ [Step 398] Written data for DCBB
# [Step 399] Fetching for MEDIASSI...
# ✔ [Step 399] Written data for MEDIASSI
# [Step 400] Fetching for ZAGGLE...
# ✔ [Step 400] Written data for ZAGGLE
# [Step 401] Fetching for MUTHOOTM...
# ✔ [Step 401] Written data for MUTHOOTM
# [Step 402] Fetching for ONEM...
# ✔ [Step 402] Written data for ONEM
# [Step 403] Fetching for ESAFSFB...
# ✔ [Step 403] Written data for ESAFSFB
# [Step 404] Fetching for PTCIF...
# ✔ [Step 404] Written data for PTCIF
# [Step 405] Fetching for INDOSTAR...
# ✔ [Step 405] Written data for INDOSTAR
# [Step 406] Fetching for REPCO...
# ✔ [Step 406] Written data for REPCO
# [Step 407] Fetching for FINOPB...
# ✔ [Step 407] Written data for FINOPB
# [Step 408] Fetching for SANDHA...
# ✔ [Step 408] Written data for SANDHA
# [Step 409] Fetching for SATIN...
# ✔ [Step 409] Written data for SATIN
# [Step 410] Fetching for SGFIN...
# ⚠ [Step 410] No relevant issues list found for SGFIN
# [Step 411] Fetching for MUFIN...
# ⚠ [Step 411] No relevant issues list found for MUFIN
# [Step 412] Fetching for DVLF...
# ✔ [Step 412] Written data for DVLF
# [Step 413] Fetching for AUGR...
# ✔ [Step 413] Written data for AUGR
# [Step 414] Fetching for PGLT...
# ✔ [Step 414] Written data for PGLT
# [Step 415] Fetching for BFIN...
# ✔ [Step 415] Written data for BFIN
# [Step 416] Fetching for ARLF...
# ✔ [Step 416] Written data for ARLF
# [Step 417] Fetching for SUNP...
# ✔ [Step 417] Written data for SUNP
# [Step 418] Fetching for CIPLA...
# ✔ [Step 418] Written data for CIPLA
# [Step 419] Fetching for DRRD...
# ✔ [Step 419] Written data for DRRD
# [Step 420] Fetching for ZYDUSLIF...
# ⚠ [Step 420] No relevant issues list found for ZYDUSLIF
# [Step 421] Fetching for MANKIND...
# ✔ [Step 421] Written data for MANKIND
# [Step 422] Fetching for APHS...
# ✔ [Step 422] Written data for APHS
# [Step 423] Fetching for CDF1U...
# ✔ [Step 423] Written data for CDF1U
# [Step 424] Fetching for TRP...
# ✔ [Step 424] Written data for TRP
# [Step 425] Fetching for MAXHEALT...
# ✔ [Step 425] Written data for MAXHEALT
# [Step 426] Fetching for LPC...
# ✔ [Step 426] Written data for LPC
# [Step 427] Fetching for ARBP...
# ✔ [Step 427] Written data for ARBP
# [Step 428] Fetching for ALKEM...
# ✔ [Step 428] Written data for ALKEM
# [Step 429] Fetching for BOOT...
# ✔ [Step 429] Written data for BOOT
# [Step 430] Fetching for MEDANTA...
# ✔ [Step 430] Written data for MEDANTA
# [Step 431] Fetching for GLXO...
# ✔ [Step 431] Written data for GLXO
# [Step 432] Fetching for AADI...
# ✔ [Step 432] Written data for AADI
# [Step 433] Fetching for FORH...
# ✔ [Step 433] Written data for FORH
# [Step 434] Fetching for IPCA...
# ✔ [Step 434] Written data for IPCA
# [Step 435] Fetching for GLANDRT...
# ✔ [Step 435] Written data for GLANDRT
# [Step 436] Fetching for 3SQ1...
# ✔ [Step 436] Written data for 3SQ1
# [Step 437] Fetching for AJP...
# ✔ [Step 437] Written data for AJP
# [Step 438] Fetching for GNP...
# ✔ [Step 438] Written data for GNP
# [Step 439] Fetching for NARH...
# ✔ [Step 439] Written data for NARH
# [Step 440] Fetching for JBCP...
# ✔ [Step 440] Written data for JBCP
# [Step 441] Fetching for LAURUS...
# ✔ [Step 441] Written data for LAURUS
# [Step 442] Fetching for ASTERDM...
# ✔ [Step 442] Written data for ASTERDM
# [Step 443] Fetching for ALPM...
# ✔ [Step 443] Written data for ALPM
# [Step 444] Fetching for PFE...
# ✔ [Step 444] Written data for PFE
# [Step 445] Fetching for DLPL...
# ✔ [Step 445] Written data for DLPL
# [Step 446] Fetching for 300384...
# ✔ [Step 446] Written data for 300384
# [Step 447] Fetching for SUVENPHA...
# ✔ [Step 447] Written data for SUVENPHA
# [Step 448] Fetching for PIRPHARM...
# ✔ [Step 448] Written data for PIRPHARM
# [Step 449] Fetching for NTCPH...
# ✔ [Step 449] Written data for NTCPH
# [Step 450] Fetching for KIMS...
# ✔ [Step 450] Written data for KIMS
# [Step 451] Fetching for CONCORDB...
# ✔ [Step 451] Written data for CONCORDB
# [Step 452] Fetching for AFH...
# ✔ [Step 452] Written data for AFH
# [Step 453] Fetching for TDI...
# ✔ [Step 453] Written data for TDI
# [Step 454] Fetching for AIL...
# ✔ [Step 454] Written data for AIL
# [Step 455] Fetching for SPADV...
# ✔ [Step 455] Written data for SPADV
# [Step 456] Fetching for ADESE...
# ✔ [Step 456] Written data for ADESE
# [Step 457] Fetching for AGR...
# ✔ [Step 457] Written data for AGR
# [Step 458] Fetching for CLPL...
# ✔ [Step 458] Written data for CLPL
# [Step 459] Fetching for 078140...
# ✔ [Step 459] Written data for 078140
# [Step 460] Fetching for JUBLPHAR...
# ⚠ [Step 460] No relevant issues list found for JUBLPHAR
# [Step 461] Fetching for WPLZ11B...
# ✔ [Step 461] Written data for WPLZ11B
# [Step 462] Fetching for METROHL...
# ✔ [Step 462] Written data for METROHL
# [Step 463] Fetching for NLL...
# ✔ [Step 463] Written data for NLL
# [Step 464] Fetching for JLHL...
# ✔ [Step 464] Written data for JLHL
# [Step 465] Fetching for PGHL...
# ✔ [Step 465] Written data for PGHL
# [Step 466] Fetching for C69...
# ✔ [Step 466] Written data for C69
# [Step 467] Fetching for FDCLT...
# ✔ [Step 467] Written data for FDCLT
# [Step 468] Fetching for MRKS...
# ✔ [Step 468] Written data for MRKS
# [Step 469] Fetching for BLUEJET...
# ✔ [Step 469] Written data for BLUEJET
# [Step 470] Fetching for VIJAYA...
# ✔ [Step 470] Written data for VIJAYA
# [Step 471] Fetching for ORCP...
# ✔ [Step 471] Written data for ORCP
# [Step 472] Fetching for HCG...
# ✔ [Step 472] Written data for HCG
# [Step 473] Fetching for CONCESI1...
# ✔ [Step 473] Written data for CONCESI1
# [Step 474] Fetching for ITMAM...
# ✔ [Step 474] Written data for ITMAM
# [Step 475] Fetching for AMIORG...
# ✔ [Step 475] Written data for AMIORG
# [Step 476] Fetching for SLPA...
# ✔ [Step 476] Written data for SLPA
# [Step 477] Fetching for ARTD...
# ✔ [Step 477] Written data for ARTD
# [Step 478] Fetching for AARTIPHA...
# ⚠ [Step 478] No relevant issues list found for AARTIPHA
# [Step 479] Fetching for CALL...
# ✔ [Step 479] Written data for CALL
# [Step 480] Fetching for YATHARTH...
# ✔ [Step 480] Written data for YATHARTH
# [Step 481] Fetching for UL...
# ✔ [Step 481] Written data for UL
# [Step 482] Fetching for HKCI...
# ✔ [Step 482] Written data for HKCI
# [Step 483] Fetching for CUPD...
# ✔ [Step 483] Written data for CUPD
# [Step 484] Fetching for THYROCAR...
# ✔ [Step 484] Written data for THYROCAR
# [Step 485] Fetching for CNFS...
# ✔ [Step 485] Written data for CNFS
# [Step 486] Fetching for GTB...
# ✔ [Step 486] Written data for GTB
# [Step 487] Fetching for MLSEQ...
# ✔ [Step 487] Written data for MLSEQ
# [Step 488] Fetching for CF...
# ✔ [Step 488] Written data for CF
# [Step 489] Fetching for SUPRIYA...
# ✔ [Step 489] Written data for SUPRIYA
# [Step 490] Fetching for SHALBY...
# ✔ [Step 490] Written data for SHALBY
# [Step 491] Fetching for INNOVACA...
# ✔ [Step 491] Written data for INNOVACA
# [Step 492] Fetching for HCBA...
# ✔ [Step 492] Written data for HCBA
# [Step 493] Fetching for RPGL...
# ✔ [Step 493] Written data for RPGL
# [Step 494] Fetching for ARTMSL...
# ✔ [Step 494] Written data for ARTMSL
# [Step 495] Fetching for SVLS...
# ✔ [Step 495] Written data for SVLS
# [Step 496] Fetching for 090430...
# ✔ [Step 496] Written data for 090430
# [Step 497] Fetching for ALBC...
# ✔ [Step 497] Written data for ALBC
# [Step 498] Fetching for 3577...
# ✔ [Step 498] Written data for 3577
# [Step 499] Fetching for TMCH...
# ✔ [Step 499] Written data for TMCH
# [Step 500] Fetching for KRSNAA...
# ✔ [Step 500] Written data for KRSNAA
# [Step 501] Fetching for LT...
# ✔ [Step 501] Written data for LT
# [Step 502] Fetching for ADSEZ...
# ✔ [Step 502] Written data for ADSEZ
# [Step 503] Fetching for HNAL...
# ✔ [Step 503] Written data for HNAL
# [Step 504] Fetching for SEMC...
# ✔ [Step 504] Written data for SEMC
# [Step 505] Fetching for IRFC...
# ✔ [Step 505] Written data for IRFC
# [Step 506] Fetching for BHE...
# ✔ [Step 506] Written data for BHE
# [Step 507] Fetching for IDG...
# ✔ [Step 507] Written data for IDG
# [Step 508] Fetching for ABBANK...
# ✔ [Step 508] Written data for ABBANK
# [Step 509] Fetching for HAVL...
# ✔ [Step 509] Written data for HAVL
# [Step 510] Fetching for BHEL...
# ✔ [Step 510] Written data for BHEL
# [Step 511] Fetching for ASH...
# ✔ [Step 511] Written data for ASH
# [Step 512] Fetching for CGPOWER...
# ✔ [Step 512] Written data for CGPOWER
# [Step 513] Fetching for INDUSTOW...
# ⚠ [Step 513] No relevant issues list found for INDUSTOW
# [Step 514] Fetching for POLYCAB...
# ✔ [Step 514] Written data for POLYCAB
# [Step 515] Fetching for IRCTC...
# ✔ [Step 515] Written data for IRCTC
# [Step 516] Fetching for LTTS...
# ✔ [Step 516] Written data for LTTS
# [Step 517] Fetching for CCRI...
# ✔ [Step 517] Written data for CCRI
# [Step 518] Fetching for RVNL...
# ✔ [Step 518] Written data for RVNL
# [Step 519] Fetching for BHFC...
# ✔ [Step 519] Written data for BHFC
# [Step 520] Fetching for JSWINFRA...
# ✔ [Step 520] Written data for JSWINFRA
# [Step 521] Fetching for AL...
# ✔ [Step 521] Written data for AL
# [Step 522] Fetching for TMX...
# ✔ [Step 522] Written data for TMX
# [Step 523] Fetching for GMRI...
# ✔ [Step 523] Written data for GMRI
# [Step 524] Fetching for SCHFL...
# ✔ [Step 524] Written data for SCHFL
# [Step 525] Fetching for APT...
# ✔ [Step 525] Written data for APT
# [Step 526] Fetching for MAZDOCKS...
# ✔ [Step 526] Written data for MAZDOCKS
# [Step 527] Fetching for AIAE...
# ✔ [Step 527] Written data for AIAE
# [Step 528] Fetching for 508096...
# ✔ [Step 528] Written data for 508096
# [Step 529] Fetching for AEGIR...
# ✔ [Step 529] Written data for AEGIR
# [Step 530] Fetching for ATEL...
# ✔ [Step 530] Written data for ATEL
# [Step 531] Fetching for DELHIVER...
# ✔ [Step 531] Written data for DELHIVER
# [Step 532] Fetching for BDLAMP...
# ✔ [Step 532] Written data for BDLAMP
# [Step 533] Fetching for BPBL...
# ✔ [Step 533] Written data for BPBL
# [Step 534] Fetching for KEII...
# ✔ [Step 534] Written data for KEII
# [Step 535] Fetching for EFS...
# ✔ [Step 535] Written data for EFS
# [Step 536] Fetching for POWERIND...
# ✔ [Step 536] Written data for POWERIND
# [Step 537] Fetching for PLAP...
# ✔ [Step 537] Written data for PLAP
# [Step 538] Fetching for BLSTR...
# ✔ [Step 538] Written data for BLSTR
# [Step 539] Fetching for SF...
# ✔ [Step 539] Written data for SF
# [Step 540] Fetching for CMEI...
# ✔ [Step 540] Written data for CMEI
# [Step 541] Fetching for CYL...
# ✔ [Step 541] Written data for CYL
# [Step 542] Fetching for TMKN...
# ✔ [Step 542] Written data for TMKN
# [Step 543] Fetching for NBCC...
# ✔ [Step 543] Written data for NBCC
# [Step 544] Fetching for CHOLAHLD...
# ✔ [Step 544] Written data for CHOLAHLD
# [Step 545] Fetching for 002167...
# ✔ [Step 545] Written data for 002167
# [Step 546] Fetching for SEKFK...
# ✔ [Step 546] Written data for SEKFK
# [Step 547] Fetching for ELEQ...
# ✔ [Step 547] Written data for ELEQ
# [Step 548] Fetching for JYOTICNC...
# ✔ [Step 548] Written data for JYOTICNC
# [Step 549] Fetching for SHNP...
# ✔ [Step 549] Written data for SHNP
# [Step 550] Fetching for RRKABEL...
# ✔ [Step 550] Written data for RRKABEL
# [Step 551] Fetching for KPIL...
# ⚠ [Step 551] No relevant issues list found for KPIL
# [Step 552] Fetching for INDUC...
# ✔ [Step 552] Written data for INDUC
# [Step 553] Fetching for ACEL...
# ✔ [Step 553] Written data for ACEL
# [Step 554] Fetching for CELLO...
# ✔ [Step 554] Written data for CELLO
# [Step 555] Fetching for ACEWIN...
# ✔ [Step 555] Written data for ACEWIN
# [Step 556] Fetching for OLECTRA...
# ✔ [Step 556] Written data for OLECTRA
# [Step 557] Fetching for JWL...
# ⚠ [Step 557] No relevant issues list found for JWL
# [Step 558] Fetching for FNXC...
# ✔ [Step 558] Written data for FNXC
# [Step 559] Fetching for BDE...
# ✔ [Step 559] Written data for BDE
# [Step 560] Fetching for NJCC...
# ✔ [Step 560] Written data for NJCC
# [Step 561] Fetching for VGRD...
# ✔ [Step 561] Written data for VGRD
# [Step 562] Fetching for GSC1...
# ✔ [Step 562] Written data for GSC1
# [Step 563] Fetching for JSAW...
# ✔ [Step 563] Written data for JSAW
# [Step 564] Fetching for DATAPATT...
# ✔ [Step 564] Written data for DATAPATT
# [Step 565] Fetching for KSB...
# ✔ [Step 565] Written data for KSB
# [Step 566] Fetching for BEML...
# ✔ [Step 566] Written data for BEML
# [Step 567] Fetching for HMFC...
# ✔ [Step 567] Written data for HMFC
# [Step 568] Fetching for BLSIN...
# ✔ [Step 568] Written data for BLSIN
# [Step 569] Fetching for GRINFRA...
# ✔ [Step 569] Written data for GRINFRA
# [Step 570] Fetching for RMKF...
# ✔ [Step 570] Written data for RMKF
# [Step 571] Fetching for TWL...
# ✔ [Step 571] Written data for TWL
# [Step 572] Fetching for AMG1L...
# ✔ [Step 572] Written data for AMG1L
# [Step 573] Fetching for AGL...
# ✔ [Step 573] Written data for AGL
# [Step 574] Fetching for SPPT...
# ✔ [Step 574] Written data for SPPT
# [Step 575] Fetching for AIP...
# ✔ [Step 575] Written data for AIP
# [Step 576] Fetching for ENGR...
# ✔ [Step 576] Written data for ENGR
# [Step 577] Fetching for MHS...
# ✔ [Step 577] Written data for MHS
# [Step 578] Fetching for PNCL...
# ✔ [Step 578] Written data for PNCL
# [Step 579] Fetching for INOXINDI...
# ✔ [Step 579] Written data for INOXINDI
# [Step 580] Fetching for ELCN...
# ✔ [Step 580] Written data for ELCN
# [Step 581] Fetching for GPPV...
# ✔ [Step 581] Written data for GPPV
# [Step 582] Fetching for VAMP...
# ✔ [Step 582] Written data for VAMP
# [Step 583] Fetching for IPRJRA...
# ✔ [Step 583] Written data for IPRJRA
# [Step 584] Fetching for AADI...
# ✔ [Step 584] Written data for AADI
# [Step 585] Fetching for EUREKAFO...
# ⚠ [Step 585] No relevant issues list found for EUREKAFO
# [Step 586] Fetching for KKB...
# ✔ [Step 586] Written data for KKB
# [Step 587] Fetching for GRSE...
# ✔ [Step 587] Written data for GRSE
# [Step 588] Fetching for ITG...
# ✔ [Step 588] Written data for ITG
# [Step 589] Fetching for SYRMA...
# ✔ [Step 589] Written data for SYRMA
# [Step 590] Fetching for ESAB...
# ✔ [Step 590] Written data for ESAB
# [Step 591] Fetching for AZAD...
# ✔ [Step 591] Written data for AZAD
# [Step 592] Fetching for POWM...
# ✔ [Step 592] Written data for POWM
# [Step 593] Fetching for QUESS...
# ✔ [Step 593] Written data for QUESS
# [Step 594] Fetching for 002578...
# ✔ [Step 594] Written data for 002578
# [Step 595] Fetching for 8458...
# ✔ [Step 595] Written data for 8458
# [Step 596] Fetching for MIDHANI...
# ✔ [Step 596] Written data for MIDHANI
# [Step 597] Fetching for CHGG...
# ✔ [Step 597] Written data for CHGG
# [Step 598] Fetching for AGLL...
# ✔ [Step 598] Written data for AGLL
# [Step 599] Fetching for 688084...
# ✔ [Step 599] Written data for 688084
# [Step 600] Fetching for KNRC...
# ✔ [Step 600] Written data for KNRC
# [Step 601] Fetching for AHLU...
# ✔ [Step 601] Written data for AHLU
# [Step 602] Fetching for TVSSCS...
# ✔ [Step 602] Written data for TVSSCS
# [Step 603] Fetching for DBL...
# ✔ [Step 603] Written data for DBL
# [Step 604] Fetching for IGSEC...
# ✔ [Step 604] Written data for IGSEC
# [Step 605] Fetching for TXMRE...
# ✔ [Step 605] Written data for TXMRE
# [Step 606] Fetching for CMSINFO...
# ✔ [Step 606] Written data for CMSINFO
# [Step 607] Fetching for TRPC...
# ✔ [Step 607] Written data for TRPC
# [Step 608] Fetching for PRINCPIP...
# ✔ [Step 608] Written data for PRINCPIP
# [Step 609] Fetching for HGINFRA...
# ✔ [Step 609] Written data for HGINFRA
# [Step 610] Fetching for SECIS...
# ✔ [Step 610] Written data for SECIS
# [Step 611] Fetching for MSTCLTD...
# ✔ [Step 611] Written data for MSTCLTD
# [Step 612] Fetching for 124500...
# ✔ [Step 612] Written data for 124500
# [Step 613] Fetching for CYIENTDL...
# ✔ [Step 613] Written data for CYIENTDL
# [Step 614] Fetching for SEDAPBC1...
# ✔ [Step 614] Written data for SEDAPBC1
# [Step 615] Fetching for LLOYDSEN...
# ⚠ [Step 615] No relevant issues list found for LLOYDSEN
# [Step 616] Fetching for AGMMRA...
# ✔ [Step 616] Written data for AGMMRA
# [Step 617] Fetching for SANSERA...
# ✔ [Step 617] Written data for SANSERA
# [Step 618] Fetching for 1552...
# ✔ [Step 618] Written data for 1552
# [Step 619] Fetching for KNM...
# ✔ [Step 619] Written data for KNM
# [Step 620] Fetching for HMT...
# ✔ [Step 620] Written data for HMT
# [Step 621] Fetching for MTARTECH...
# ✔ [Step 621] Written data for MTARTECH
# [Step 622] Fetching for JFI...
# ✔ [Step 622] Written data for JFI
# [Step 623] Fetching for GRFL...
# ✔ [Step 623] Written data for GRFL
# [Step 624] Fetching for VRLL...
# ✔ [Step 624] Written data for VRLL
# [Step 625] Fetching for JKIL...
# ✔ [Step 625] Written data for JKIL
# [Step 626] Fetching for VATW...
# ✔ [Step 626] Written data for VATW
# [Step 627] Fetching for SJET...
# ✔ [Step 627] Written data for SJET
# [Step 628] Fetching for ABE...
# ✔ [Step 628] Written data for ABE
# [Step 629] Fetching for TDPS...
# ✔ [Step 629] Written data for TDPS
# [Step 630] Fetching for KKPC...
# ✔ [Step 630] Written data for KKPC
# [Step 631] Fetching for TIIL...
# ✔ [Step 631] Written data for TIIL
# [Step 632] Fetching for 469480...
# ✔ [Step 632] Written data for 469480
# [Step 633] Fetching for ASBL...
# ✔ [Step 633] Written data for ASBL
# [Step 634] Fetching for BNCO...
# ✔ [Step 634] Written data for BNCO
# [Step 635] Fetching for SG...
# ✔ [Step 635] Written data for SG
# [Step 636] Fetching for WELENT...
# ⚠ [Step 636] No relevant issues list found for WELENT
# [Step 637] Fetching for ORIENTEL...
# ✔ [Step 637] Written data for ORIENTEL
# [Step 638] Fetching for LGBB...
# ✔ [Step 638] Written data for LGBB
# [Step 639] Fetching for TCIEXP...
# ✔ [Step 639] Written data for TCIEXP
# [Step 640] Fetching for VENUSPIP...
# ✔ [Step 640] Written data for VENUSPIP
# [Step 641] Fetching for SKIPPER...
# ✔ [Step 641] Written data for SKIPPER
# [Step 642] Fetching for RMKY...
# ✔ [Step 642] Written data for RMKY
# [Step 643] Fetching for 2809...
# ✔ [Step 643] Written data for 2809
# [Step 644] Fetching for DCXINDIA...
# ✔ [Step 644] Written data for DCXINDIA
# [Step 645] Fetching for JI...
# ✔ [Step 645] Written data for JI
# [Step 646] Fetching for SECLTD...
# ✔ [Step 646] Written data for SECLTD
# [Step 647] Fetching for ANUP...
# ✔ [Step 647] Written data for ANUP
# [Step 648] Fetching for 2208...
# ✔ [Step 648] Written data for 2208
# [Step 649] Fetching for MAHLOG...
# ✔ [Step 649] Written data for MAHLOG
# [Step 650] Fetching for SCT...
# ✔ [Step 650] Written data for SCT
# [Step 651] Fetching for BFUT...
# ✔ [Step 651] Written data for BFUT
# [Step 652] Fetching for VINL...
# ✔ [Step 652] Written data for VINL
# [Step 653] Fetching for VSTT...
# ✔ [Step 653] Written data for VSTT
# [Step 654] Fetching for SM...
# ✔ [Step 654] Written data for SM
# [Step 655] Fetching for APAT...
# ✔ [Step 655] Written data for APAT
# [Step 656] Fetching for SKPI...
# ✔ [Step 656] Written data for SKPI
# [Step 657] Fetching for DIACABS...
# ⚠ [Step 657] No relevant issues list found for DIACABS
# [Step 658] Fetching for VT...
# ✔ [Step 658] Written data for VT
# [Step 659] Fetching for NRBBR...
# ✔ [Step 659] Written data for NRBBR
# [Step 660] Fetching for JCHAC...
# ✔ [Step 660] Written data for JCHAC
# [Step 661] Fetching for GMRPUI...
# ⚠ [Step 661] No relevant issues list found for GMRPUI
# [Step 662] Fetching for STYRENIX...
# ⚠ [Step 662] No relevant issues list found for STYRENIX
# [Step 663] Fetching for BAJEL...
# ⚠ [Step 663] No relevant issues list found for BAJEL
# [Step 664] Fetching for PSPPL...
# ✔ [Step 664] Written data for PSPPL
# [Step 665] Fetching for PITTIENG...
# ✔ [Step 665] Written data for PITTIENG
# [Step 666] Fetching for CSP...
# ✔ [Step 666] Written data for CSP
# [Step 667] Fetching for PARAS...
# ✔ [Step 667] Written data for PARAS
# [Step 668] Fetching for EXICOM...
# ✔ [Step 668] Written data for EXICOM
# [Step 669] Fetching for UNIPARTS...
# ✔ [Step 669] Written data for UNIPARTS
# [Step 670] Fetching for SEPC...
# ✔ [Step 670] Written data for SEPC
# [Step 671] Fetching for FPWM...
# ✔ [Step 671] Written data for FPWM
# [Step 672] Fetching for AXET...
# ✔ [Step 672] Written data for AXET
# [Step 673] Fetching for EPWN...
# ✔ [Step 673] Written data for EPWN
# [Step 674] Fetching for WNDT...
# ✔ [Step 674] Written data for WNDT
# [Step 675] Fetching for HONDAPWR...
# ⚠ [Step 675] No relevant issues list found for HONDAPWR
# [Step 676] Fetching for EMSLIMIT...
# ✔ [Step 676] Written data for EMSLIMIT
# [Step 677] Fetching for CAPACITE...
# ✔ [Step 677] Written data for CAPACITE
# [Step 678] Fetching for IKIO...
# ✔ [Step 678] Written data for IKIO
# [Step 679] Fetching for QUDS...
# ✔ [Step 679] Written data for QUDS
# [Step 680] Fetching for MMFG...
# ✔ [Step 680] Written data for MMFG
# [Step 681] Fetching for BALUFORG...
# ⚠ [Step 681] No relevant issues list found for BALUFORG
# [Step 682] Fetching for TARSONS...
# ✔ [Step 682] Written data for TARSONS
# [Step 683] Fetching for GTLI...
# ✔ [Step 683] Written data for GTLI
# [Step 684] Fetching for HPLE...
# ✔ [Step 684] Written data for HPLE
# [Step 685] Fetching for ALK...
# ✔ [Step 685] Written data for ALK
# [Step 686] Fetching for IRMENERG...
# ✔ [Step 686] Written data for IRMENERG
# [Step 687] Fetching for DCIL...
# ✔ [Step 687] Written data for DCIL
# [Step 688] Fetching for BWRL...
# ...
# [Step 773] Fetching for GALSURF...
# ✔ [Step 773] Written data for GALSURF
# [Step 774] Fetching for GSFC...
# ✔ [Step 774] Written data for GSFC
# [Step 775] Fetching for BAAZEEM...
# ✔ [Step 775] Written data for BAAZEEM
# [Step 776] Fetching for 9625...
# ✔ [Step 776] Written data for 9625
# [Step 777] Fetching for JUBLINGR...
# ✔ [Step 777] Written data for JUBLINGR
# [Step 778] Fetching for SEML...
# ✔ [Step 778] Written data for SEML
# [Step 779] Fetching for RCF...
# ✔ [Step 779] Written data for RCF
# [Step 780] Fetching for CHEMPLAS...
# ✔ [Step 780] Written data for CHEMPLAS
# [Step 781] Fetching for EBECK...
# ✔ [Step 781] Written data for EBECK
# [Step 782] Fetching for BLGV...
# ✔ [Step 782] Written data for BLGV
# [Step 783] Fetching for VI...
# ✔ [Step 783] Written data for VI
# [Step 784] Fetching for BLZE...
# ✔ [Step 784] Written data for BLZE
# [Step 785] Fetching for BZU...
# ✔ [Step 785] Written data for BZU
# [Step 786] Fetching for LXCHEM...
# ✔ [Step 786] Written data for LXCHEM
# [Step 787] Fetching for DFPC...
# ✔ [Step 787] Written data for DFPC
# [Step 788] Fetching for GRLM...
# ✔ [Step 788] Written data for GRLM
# [Step 789] Fetching for INDIGOPN...
# ✔ [Step 789] Written data for INDIGOPN
# [Step 790] Fetching for SANDUMA...
# ⚠ [Step 790] No relevant issues list found for SANDUMA
# [Step 791] Fetching for EPLL...
# ⚠ [Step 791] No relevant issues list found for EPLL
# [Step 792] Fetching for JMOIL...
# ✔ [Step 792] Written data for JMOIL
# [Step 793] Fetching for ATMCU...
# ✔ [Step 793] Written data for ATMCU
# [Step 794] Fetching for FSS...
# ✔ [Step 794] Written data for FSS
# [Step 795] Fetching for JKPAPER...
# ✔ [Step 795] Written data for JKPAPER
# [Step 796] Fetching for PPARIVAH...
# ✔ [Step 796] Written data for PPARIVAH
# [Step 797] Fetching for AKGRT...
# ✔ [Step 797] Written data for AKGRT
# [Step 798] Fetching for RINDL...
# ✔ [Step 798] Written data for RINDL
# [Step 799] Fetching for GALK...
# ✔ [Step 799] Written data for GALK
# [Step 800] Fetching for 5GN...
# ✔ [Step 800] Written data for 5GN
# [Step 801] Fetching for AGIG...
# ⚠ [Step 801] No relevant issues list found for AGIG
# [Step 802] Fetching for DAGRI...
# ✔ [Step 802] Written data for DAGRI
# [Step 803] Fetching for AJG...
# ✔ [Step 803] Written data for AJG
# [Step 804] Fetching for GOLI...
# ✔ [Step 804] Written data for GOLI
# [Step 805] Fetching for EPIGRAL...
# ⚠ [Step 805] No relevant issues list found for EPIGRAL
# [Step 806] Fetching for D2B...
# ✔ [Step 806] Written data for D2B
# [Step 807] Fetching for JPA...
# ✔ [Step 807] Written data for JPA
# [Step 808] Fetching for CFLT...
# ✔ [Step 808] Written data for CFLT
# [Step 809] Fetching for GHCL...
# ✔ [Step 809] Written data for GHCL
# [Step 810] Fetching for BDSN...
# ✔ [Step 810] Written data for BDSN
# [Step 811] Fetching for NOCIL...
# ✔ [Step 811] Written data for NOCIL
# [Step 812] Fetching for KKIL...
# ✔ [Step 812] Written data for KKIL
# [Step 813] Fetching for BLCL...
# ✔ [Step 813] Written data for BLCL
# [Step 814] Fetching for FTXC...
# ✔ [Step 814] Written data for FTXC
# [Step 815] Fetching for GRWRHITE...
# ⚠ [Step 815] No relevant issues list found for GRWRHITE
# [Step 816] Fetching for ORCMNT...
# ✔ [Step 816] Written data for ORCMNT
# [Step 817] Fetching for GW...
# ✔ [Step 817] Written data for GW
# [Step 818] Fetching for WCPM...
# ✔ [Step 818] Written data for WCPM
# [Step 819] Fetching for ADVENZY...
# ✔ [Step 819] Written data for ADVENZY
# [Step 820] Fetching for PRIVISCL...
# ✔ [Step 820] Written data for PRIVISCL
# [Step 821] Fetching for GREENP...
# ✔ [Step 821] Written data for GREENP
# [Step 822] Fetching for KS...
# ✔ [Step 822] Written data for KS
# [Step 823] Fetching for ROSSARI...
# ✔ [Step 823] Written data for ROSSARI
# [Step 824] Fetching for OMDC...
# ✔ [Step 824] Written data for OMDC
# [Step 825] Fetching for BRSN...
# ✔ [Step 825] Written data for BRSN
# [Step 826] Fetching for LLOYDSET...
# ⚠ [Step 826] No relevant issues list found for LLOYDSET
# [Step 827] Fetching for IMFA...
# ✔ [Step 827] Written data for IMFA
# [Step 828] Fetching for ASMN...
# ✔ [Step 828] Written data for ASMN
# [Step 829] Fetching for FCH...
# ✔ [Step 829] Written data for FCH
# [Step 830] Fetching for 5488...
# ✔ [Step 830] Written data for 5488
# [Step 831] Fetching for YQ...
# ✔ [Step 831] Written data for YQ
# [Step 832] Fetching for JTLIND...
# ⚠ [Step 832] No relevant issues list found for JTLIND
# [Step 833] Fetching for KSCL...
# ✔ [Step 833] Written data for KSCL
# [Step 834] Fetching for ATEC...
# ✔ [Step 834] Written data for ATEC
# [Step 835] Fetching for NEOGEN...
# ✔ [Step 835] Written data for NEOGEN
# [Step 836] Fetching for PKI...
# ✔ [Step 836] Written data for PKI
# [Step 837] Fetching for BWA...
# ✔ [Step 837] Written data for BWA
# [Step 838] Fetching for UFLX...
# ✔ [Step 838] Written data for UFLX
# [Step 839] Fetching for SHCR...
# ✔ [Step 839] Written data for SHCR
# [Step 840] Fetching for MTLM...
# ✔ [Step 840] Written data for MTLM
# [Step 841] Fetching for LMAT...
# ✔ [Step 841] Written data for LMAT
# [Step 842] Fetching for SHKL...
# ✔ [Step 842] Written data for SHKL
# [Step 843] Fetching for HLEGLAS...
# ⚠ [Step 843] No relevant issues list found for HLEGLAS
# [Step 844] Fetching for ANG...
# ✔ [Step 844] Written data for ANG
# [Step 845] Fetching for SGC...
# ✔ [Step 845] Written data for SGC
# [Step 846] Fetching for SYIL...
# ✔ [Step 846] Written data for SYIL
# [Step 847] Fetching for ISMT...
# ✔ [Step 847] Written data for ISMT
# [Step 848] Fetching for MTEP...
# ✔ [Step 848] Written data for MTEP
# [Step 849] Fetching for ARL...
# ✔ [Step 849] Written data for ARL
# [Step 850] Fetching for TATVA...
# ✔ [Step 850] Written data for TATVA
# [Step 851] Fetching for APOLP...
# ✔ [Step 851] Written data for APOLP
# [Step 852] Fetching for JMACU...
# ✔ [Step 852] Written data for JMACU
# [Step 853] Fetching for PPC...
# ✔ [Step 853] Written data for PPC
# [Step 854] Fetching for PTMCD...
# ✔ [Step 854] Written data for PTMCD
# [Step 855] Fetching for 600143...
# ✔ [Step 855] Written data for 600143
# [Step 856] Fetching for AXL...
# ✔ [Step 856] Written data for AXL
# [Step 857] Fetching for IGLY...
# ✔ [Step 857] Written data for IGLY
# [Step 858] Fetching for APN...
# ✔ [Step 858] Written data for APN
# [Step 859] Fetching for SNGI...
# ✔ [Step 859] Written data for SNGI
# [Step 860] Fetching for APCO...
# ✔ [Step 860] Written data for APCO
# [Step 861] Fetching for 8049...
# ✔ [Step 861] Written data for 8049
# [Step 862] Fetching for GOCL...
# ✔ [Step 862] Written data for GOCL
# [Step 863] Fetching for KCPL...
# ✔ [Step 863] Written data for KCPL
# [Step 864] Fetching for BEPL...
# ✔ [Step 864] Written data for BEPL
# [Step 865] Fetching for RASTL...
# ✔ [Step 865] Written data for RASTL
# [Step 866] Fetching for MASTERPL...
# ✔ [Step 866] Written data for MASTERPL
# [Step 867] Fetching for AH...
# ✔ [Step 867] Written data for AH
# [Step 868] Fetching for VCL...
# ✔ [Step 868] Written data for VCL
# [Step 869] Fetching for ASTEL...
# ✔ [Step 869] Written data for ASTEL
# [Step 870] Fetching for TCPL...
# ✔ [Step 870] Written data for TCPL
# [Step 871] Fetching for FDMT...
# ✔ [Step 871] Written data for FDMT
# [Step 872] Fetching for MGCXD...
# ✔ [Step 872] Written data for MGCXD
# [Step 873] Fetching for PNPC...
# ✔ [Step 873] Written data for PNPC
# [Step 874] Fetching for JDPF...
# ✔ [Step 874] Written data for JDPF
# [Step 875] Fetching for 5142...
# ✔ [Step 875] Written data for 5142
# [Step 876] Fetching for TANF...
# ✔ [Step 876] Written data for TANF
# [Step 877] Fetching for IFGLRF...
# ✔ [Step 877] Written data for IFGLRF
# [Step 878] Fetching for ANHPR...
# ⚠ [Step 878] No relevant issues list found for ANHPR
# [Step 879] Fetching for UDAICEME...
# ⚠ [Step 879] No relevant issues list found for UDAICEME
# [Step 880] Fetching for DLFU...
# ✔ [Step 880] Written data for DLFU
# [Step 881] Fetching for LODHA...
# ✔ [Step 881] Written data for LODHA
# [Step 882] Fetching for CNT...
# ✔ [Step 882] Written data for CNT
# [Step 883] Fetching for HUTT...
# ✔ [Step 883] Written data for HUTT
# [Step 884] Fetching for PHNX...
# ✔ [Step 884] Written data for PHNX
# [Step 885] Fetching for PEPL...
# ✔ [Step 885] Written data for PEPL
# [Step 886] Fetching for BRGD...
# ✔ [Step 886] Written data for BRGD
# [Step 887] Fetching for GSS...
# ✔ [Step 887] Written data for GSS
# [Step 888] Fetching for CHALET...
# ✔ [Step 888] Written data for CHALET
# [Step 889] Fetching for SOBHA...
# ✔ [Step 889] Written data for SOBHA
# [Step 890] Fetching for ARCP...
# ✔ [Step 890] Written data for ARCP
# [Step 891] Fetching for DBREALTY...
# ⚠ [Step 891] No relevant issues list found for DBREALTY
# [Step 892] Fetching for NTSD...
# ✔ [Step 892] Written data for NTSD
# [Step 893] Fetching for MAHLIFE...
# ⚠ [Step 893] No relevant issues list found for MAHLIFE
# [Step 894] Fetching for RUSTOMJE...
# ✔ [Step 894] Written data for RUSTOMJE
# [Step 895] Fetching for EMBDL...
# ⚠ [Step 895] No relevant issues list found for EMBDL
# [Step 896] Fetching for GHFC...
# ✔ [Step 896] Written data for GHFC
# [Step 897] Fetching for ACOS...
# ✔ [Step 897] Written data for ACOS
# [Step 898] Fetching for SNNP...
# ✔ [Step 898] Written data for SNNP
# [Step 899] Fetching for HEMIPROP...
# ✔ [Step 899] Written data for HEMIPROP
# [Step 900] Fetching for PURVA...
# ✔ [Step 900] Written data for PURVA
# [Step 901] Fetching for SAMHI...
# ✔ [Step 901] Written data for SAMHI
# [Step 902] Fetching for ANTAR...
# ✔ [Step 902] Written data for ANTAR
# [Step 903] Fetching for MAXESTAT...
# ⚠ [Step 903] No relevant issues list found for MAXESTAT
# [Step 904] Fetching for NIRL...
# ✔ [Step 904] Written data for NIRL
# [Step 905] Fetching for ARVSMART...
# ⚠ [Step 905] No relevant issues list found for ARVSMART
# [Step 906] Fetching for UT...
# ✔ [Step 906] Written data for UT
# [Step 907] Fetching for ASFI...
# ✔ [Step 907] Written data for ASFI
# [Step 908] Fetching for MNRT...
# ✔ [Step 908] Written data for MNRT
# [Step 909] Fetching for SHRIRAMP...
# ✔ [Step 909] Written data for SHRIRAMP
# [Step 910] Fetching for HLIX...
# ✔ [Step 910] Written data for HLIX
# [Step 911] Fetching for III...
# ✔ [Step 911] Written data for III
# [Step 912] Fetching for HCLT...
# ✔ [Step 912] Written data for HCLT
# [Step 913] Fetching for WPRO...
# ✔ [Step 913] Written data for WPRO
# [Step 914] Fetching for ARH...
# ✔ [Step 914] Written data for ARH
# [Step 915] Fetching for 603015...
# ✔ [Step 915] Written data for 603015
# [Step 916] Fetching for OFSS...
# ✔ [Step 916] Written data for OFSS
# [Step 917] Fetching for PSYS...
# ✔ [Step 917] Written data for PSYS
# [Step 918] Fetching for POLICYBZ...
# ✔ [Step 918] Written data for POLICYBZ
# [Step 919] Fetching for TELX...
# ✔ [Step 919] Written data for TELX
# [Step 920] Fetching for MPHL...
# ✔ [Step 920] Written data for MPHL
# [Step 921] Fetching for DIXON...
# ✔ [Step 921] Written data for DIXON
# [Step 922] Fetching for TATATECH...
# ✔ [Step 922] Written data for TATATECH
# [Step 923] Fetching for COFORGE...
# ⚠ [Step 923] No relevant issues list found for COFORGE
# [Step 924] Fetching for VCVCU...
# ✔ [Step 924] Written data for VCVCU
# [Step 925] Fetching for BSOFT...
# ✔ [Step 925] Written data for BSOFT
# [Step 926] Fetching for SSOF...
# ✔ [Step 926] Written data for SSOF
# [Step 927] Fetching for KAYNES...
# ✔ [Step 927] Written data for KAYNES
# [Step 928] Fetching for 2051...
# ✔ [Step 928] Written data for 2051
# [Step 929] Fetching for BIPP...
# ✔ [Step 929] Written data for BIPP
# [Step 930] Fetching for FSOL...
# ✔ [Step 930] Written data for FSOL
# [Step 931] Fetching for AEZS...
# ✔ [Step 931] Written data for AEZS
# [Step 932] Fetching for ECLX...
# ✔ [Step 932] Written data for ECLX
# [Step 933] Fetching for HAPPSTMN...
# ✔ [Step 933] Written data for HAPPSTMN
# [Step 934] Fetching for TEJASNET...
# ✔ [Step 934] Written data for TEJASNET
# [Step 935] Fetching for NEWGEN...
# ✔ [Step 935] Written data for NEWGEN
# [Step 936] Fetching for ELK...
# ✔ [Step 936] Written data for ELK
# [Step 937] Fetching for LATENTVI...
# ✔ [Step 937] Written data for LATENTVI
# [Step 938] Fetching for MAPMYIND...
# ✔ [Step 938] Written data for MAPMYIND
# [Step 939] Fetching for NETWEB...
# ✔ [Step 939] Written data for NETWEB
# [Step 940] Fetching for RATEGAIN...
# ✔ [Step 940] Written data for RATEGAIN
# [Step 941] Fetching for 603389...
# ✔ [Step 941] Written data for 603389
# [Step 942] Fetching for ADDC...
# ✔ [Step 942] Written data for ADDC
# [Step 943] Fetching for EMUDHRA...
# ✔ [Step 943] Written data for EMUDHRA
# [Step 944] Fetching for ASTM...
# ✔ [Step 944] Written data for ASTM
# [Step 945] Fetching for AUPS...
# ✔ [Step 945] Written data for AUPS
# [Step 946] Fetching for MCLOUD...
# ✔ [Step 946] Written data for MCLOUD
# [Step 947] Fetching for ATHX...
# ✔ [Step 947] Written data for ATHX
# [Step 948] Fetching for SOTL...
# ✔ [Step 948] Written data for SOTL
# [Step 949] Fetching for AVL...
# ✔ [Step 949] Written data for AVL
# [Step 950] Fetching for PGEL...
# ✔ [Step 950] Written data for PGEL
# [Step 951] Fetching for PROTEAN...
# ✔ [Step 951] Written data for PROTEAN
# [Step 952] Fetching for BBOX...
# ✔ [Step 952] Written data for BBOX
# [Step 953] Fetching for BIJL...
# ✔ [Step 953] Written data for BIJL
# [Step 954] Fetching for CI...
# ✔ [Step 954] Written data for CI
# [Step 955] Fetching for HGSL...
# ✔ [Step 955] Written data for HGSL
# [Step 956] Fetching for AVACU...
# ✔ [Step 956] Written data for AVACU
# [Step 957] Fetching for AFBI...
# ✔ [Step 957] Written data for AFBI
# [Step 958] Fetching for 3260...
# ✔ [Step 958] Written data for 3260
# [Step 959] Fetching for IDEAFORG...
# ✔ [Step 959] Written data for IDEAFORG
# [Step 960] Fetching for BCG...
# ✔ [Step 960] Written data for BCG
# [Step 961] Fetching for AAYANRE...
# ✔ [Step 961] Written data for AAYANRE
# [Step 962] Fetching for QUICKHEA...
# ✔ [Step 962] Written data for QUICKHEA
# [Step 963] Fetching for ACCELYA...
# ✔ [Step 963] Written data for ACCELYA
# [Step 964] Fetching for AVTS...
# ✔ [Step 964] Written data for AVTS
# [Step 965] Fetching for ADAG...
# ✔ [Step 965] Written data for ADAG
# [Step 966] Fetching for SASKEN...
# ✔ [Step 966] Written data for SASKEN
# [Step 967] Fetching for ABE...
# ✔ [Step 967] Written data for ABE
# [Step 968] Fetching for RPTECH...
# ✔ [Step 968] Written data for RPTECH
# [Step 969] Fetching for RPSGVENT...
# ⚠ [Step 969] No relevant issues list found for RPSGVENT
# [Step 970] Fetching for PRMC...
# ✔ [Step 970] Written data for PRMC
# [Step 971] Fetching for EXPLEOSO...
# ✔ [Step 971] Written data for EXPLEOSO
# [Step 972] Fetching for NTPCGREE...
# ✔ [Step 972] Written data for NTPCGREE
# [Step 973] Fetching for ADANIGR...
# ✔ [Step 973] Written data for ADANIGR
# [Step 974] Fetching for PWGR...
# ✔ [Step 974] Written data for PWGR
# [Step 975] Fetching for ADE...
# ✔ [Step 975] Written data for ADE
# [Step 976] Fetching for TPWR...
# ✔ [Step 976] Written data for TPWR
# [Step 977] Fetching for ACC/P...
# ✔ [Step 977] Written data for ACC/P
# [Step 978] Fetching for ADANIENS...
# ⚠ [Step 978] No relevant issues list found for ADANIENS
# [Step 979] Fetching for ATGL...
# ✔ [Step 979] Written data for ATGL
# [Step 980] Fetching for NHPC...
# ✔ [Step 980] Written data for NHPC
# [Step 981] Fetching for JSW...
# ✔ [Step 981] Written data for JSW
# [Step 982] Fetching for TPW...
# ✔ [Step 982] Written data for TPW
# [Step 983] Fetching for SJVN...
# ✔ [Step 983] Written data for SJVN
# [Step 984] Fetching for GUJGA...
# ✔ [Step 984] Written data for GUJGA
# [Step 985] Fetching for NLC...
# ✔ [Step 985] Written data for NLC
# [Step 986] Fetching for BH/A...
# ✔ [Step 986] Written data for BH/A
# [Step 987] Fetching for GETD...
# ✔ [Step 987] Written data for GETD
# [Step 988] Fetching for GUJS...
# ✔ [Step 988] Written data for GUJS
# [Step 989] Fetching for BRKC...
# ✔ [Step 989] Written data for BRKC
# [Step 990] Fetching for CESC...
# ✔ [Step 990] Written data for CESC
# [Step 991] Fetching for MAHGL...
# ✔ [Step 991] Written data for MAHGL
# [Step 992] Fetching for CDX...
# ✔ [Step 992] Written data for CDX
# [Step 993] Fetching for RPWR...
# ✔ [Step 993] Written data for RPWR
# [Step 994] Fetching for ACC...
# ✔ [Step 994] Written data for ACC
# [Step 995] Fetching for JPVL...
# ✔ [Step 995] Written data for JPVL
# [Step 996] Fetching for TWLV...
# ✔ [Step 996] Written data for TWLV
# [Step 997] Fetching for BONAVB...
# ✔ [Step 997] Written data for BONAVB
# [Step 998] Fetching for PTCIN...
# ✔ [Step 998] Written data for PTCIN
# [Step 999] Fetching for RTPOW...
# ✔ [Step 999] Written data for RTPOW
# [Step 1000] Fetching for BGIP3...
# ✔ [Step 1000] Written data for BGIP3
# ✅ Done. Data saved to 'company_sasb_issues.csv'

# %%
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\uday om\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\Uday Om\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
# Requirement already satisfied: et-xmlfile in c:\users\uday om\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill

# Input and output files
csv_file = "company_sasb_issues.csv"
excel_file = "company_sasb_issues_highlighted.xlsx"

# Load the CSV file
df = pd.read_csv(csv_file)

# Get list of SASB issue columns (all except 'Ticker')
sasb_columns = df.columns.tolist()[1:]

# Save initial Excel file
df.to_excel(excel_file, index=False)

# Load workbook for styling
wb = load_workbook(excel_file)
ws = wb.active

# Define yellow fill
yellow_fill = PatternFill(start_color="FFFF00", end_color="FFFF00", fill_type="solid")

# Iterate over DataFrame rows
for idx, row in df.iterrows():
    # Check if all SASB columns are empty
    if row[sasb_columns].isnull().all() or (row[sasb_columns] == "").all():
        excel_row = idx + 2  # Add 2 because Excel is 1-based and row 1 is header
        for col_idx in range(1, len(df.columns) + 1):
            ws.cell(row=excel_row, column=col_idx).fill = yellow_fill

# Save styled Excel file
wb.save(excel_file)
print(f"✅ Highlighted rows saved in '{excel_file}'")
# Out:
# ✅ Highlighted rows saved in 'company_sasb_issues_highlighted.xlsx'

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill

# Files
xlsx_file = "company_sasb_issues_highlighted.xlsx"
csv_file = "tickers.csv"
output_file = "company_sasb_issues_mismatch_highlighted.xlsx"

# Load tickers.csv (list of expected tickers)
with open(csv_file, 'r') as f:
    expected_tickers = [line.strip().upper() for line in f if line.strip()]

# Load Excel file (tickers to validate)
df_excel = pd.read_excel(xlsx_file)
actual_tickers = df_excel["Ticker"].astype(str).str.upper().tolist()

# Load workbook for styling
wb = load_workbook(xlsx_file)
ws = wb.active

# Define light red fill
red_fill = PatternFill(start_color="FFCCCC", end_color="FFCCCC", fill_type="solid")

# Compare tickers one by one
for idx, (expected, actual) in enumerate(zip(expected_tickers, actual_tickers), start=2):  # Excel row index starts at 2
    if expected != actual:
        for col in range(1, len(df_excel.columns) + 1):
            ws.cell(row=idx, column=col).fill = red_fill
        print(f"❌ Mismatch at row {idx}: expected '{expected}', found '{actual}'")
    else:
        print(f"✔ Match at row {idx}: {expected}")

# Save to new Excel file
wb.save(output_file)
print(f"\n✅ Done. Mismatched rows saved to '{output_file}'")
# Out:
# ✔ Match at row 2: BHARTI
# ✔ Match at row 3: ZOMATO
# ✔ Match at row 4: INFOE
# ❌ Mismatch at row 5: expected 'IDEA', found 'AGS'
# ❌ Mismatch at row 6: expected 'TCOM', found '8071'
# ✔ Match at row 7: SUNTV
# ✔ Match at row 8: AFFLE
# ✔ Match at row 9: TTLS
# ✔ Match at row 10: Z
# ✔ Match at row 11: RAILTEL
# ❌ Mismatch at row 12: expected 'ROUTE', found 'NSG'
# ❌ Mismatch at row 13: expected 'NETM', found '251270'
# ❌ Mismatch at row 14: expected 'TV18', found 'ALAMAR'
# ✔ Match at row 15: EASEMYTR
# ✔ Match at row 16: JUST
# ❌ Mismatch at row 17: expected 'SARE', found 'WRLS'
# ✔ Match at row 18: TIPSMUSI
# ✔ Match at row 19: NAZARA
# ✔ Match at row 20: DBCL
# ❌ Mismatch at row 21: expected 'TEAM', found '3662'
# ❌ Mismatch at row 22: expected 'HATH', found 'BRK/A'
# ❌ Mismatch at row 23: expected 'NELI', found 'CNLI'
# ✔ Match at row 24: DITV
# ✔ Match at row 25: CARTRADE
# ✔ Match at row 26: PRIF
# ❌ Mismatch at row 27: expected 'MPS', found 'ALEXSC'
# ✔ Match at row 28: PRAVEG
# ❌ Mismatch at row 29: expected 'DEN', found '138SL'
# ✔ Match at row 30: YATRA
# ✔ Match at row 31: JAGP
# ✔ Match at row 32: OPIL
# ✔ Match at row 33: MTNL
# ❌ Mismatch at row 34: expected 'SIGNPOST', found '3996'
# ✔ Match at row 35: GTPL
# ❌ Mismatch at row 36: expected 'GFL', found 'DANGFLOU'
# ✔ Match at row 37: MSIL
# ❌ Mismatch at row 38: expected 'TTAN', found 'ATANA'
# ✔ Match at row 39: TTMT
# ✔ Match at row 40: BJAUT
# ✔ Match at row 41: MM
# ❌ Mismatch at row 42: expected 'TRENT', found 'NTGAZ'
# ❌ Mismatch at row 43: expected 'EIM', found '6156'
# ✔ Match at row 44: TVSL
# ✔ Match at row 45: HMCL
# ❌ Mismatch at row 46: expected 'BOS', found 'ADAPRA'
# ✔ Match at row 47: IH
# ❌ Mismatch at row 48: expected 'MOTHERSO', found 'MSS'
# ✔ Match at row 49: MRCO
# ❌ Mismatch at row 50: expected 'MRF', found 'MRFG3'
# ✔ Match at row 51: NYKAA
# ❌ Mismatch at row 52: expected 'BIL', found 'MOBIL'
# ✔ Match at row 53: KALYANKJ
# ✔ Match at row 54: SONACOMS
# ✔ Match at row 55: KPITTECH
# ✔ Match at row 56: UNOMINDA
# ❌ Mismatch at row 57: expected 'PAG', found 'PAGCC'
# ✔ Match at row 58: TTMT/A
# ✔ Match at row 59: METROBRA
# ❌ Mismatch at row 60: expected 'APTY', found 'ANAB'
# ❌ Mismatch at row 61: expected 'JUBI', found 'ELKRRA'
# ✔ Match at row 62: MSUMI
# ✔ Match at row 63: ZCVCS
# ✔ Match at row 64: KPR
# ❌ Mismatch at row 65: expected 'EIH', found '600538'
# ❌ Mismatch at row 66: expected 'ENDU', found 'EGEEN'
# ✔ Match at row 67: MANYAVAR
# ✔ Match at row 68: JBMA
# ❌ Mismatch at row 69: expected 'SWAN', found 'ABC'
# ✔ Match at row 70: ABFRL
# ✔ Match at row 71: RLXF
# ❌ Mismatch at row 72: expected 'TRID', found 'JRELTD'
# ✔ Match at row 73: KJC
# ❌ Mismatch at row 74: expected 'BATA', found 'ABAVP'
# ✔ Match at row 75: CIEINDIA
# ❌ Mismatch at row 76: expected 'CROMPTON', found 'BC'
# ✔ Match at row 77: TVSHLTD
# ✔ Match at row 78: INMART
# ❌ Mismatch at row 79: expected 'WHIRL', found '600172'
# ✔ Match at row 80: ARENM
# ✔ Match at row 81: WELSPUNL
# ✔ Match at row 82: HONASA
# ✔ Match at row 83: PVRINOX
# ✔ Match at row 84: AISG
# ✔ Match at row 85: VTEX
# ✔ Match at row 86: ALOK
# ❌ Mismatch at row 87: expected 'WESTLIFE', found 'WLDL'
# ❌ Mismatch at row 88: expected 'KOEL', found 'FHW'
# ✔ Match at row 89: RW
# ✔ Match at row 90: JUNIPER
# ✔ Match at row 91: JKI
# ✔ Match at row 92: CEAT
# ✔ Match at row 93: BJE
# ✔ Match at row 94: LEMONTRE
# ❌ Mismatch at row 95: expected 'SFL', found '159010'
# ❌ Mismatch at row 96: expected 'SAPPHIRE', found 'ASAME'
# ❌ Mismatch at row 97: expected 'MDA', found '71M'
# ✔ Match at row 98: MMTC
# ✔ Match at row 99: FML
# ✔ Match at row 100: DOMS
# ✔ Match at row 101: TTKPT
# ✔ Match at row 102: CRAFTSMA
# ✔ Match at row 103: REDTAPE
# ❌ Mismatch at row 104: expected 'CRS', found '2CRSI'
# ❌ Mismatch at row 105: expected 'SII', found 'ALDV'
# ✔ Match at row 106: HAPPYFOR
# ❌ Mismatch at row 107: expected 'SHOP', found 'THDS'
# ✔ Match at row 108: MHSC
# ✔ Match at row 109: MHRL
# ✔ Match at row 110: TC
# ✔ Match at row 111: RJEX
# ✔ Match at row 112: VARROC
# ❌ Mismatch at row 113: expected 'VIP', found 'ENVI'
# ❌ Mismatch at row 114: expected 'EMIL', found 'CMNT'
# ✔ Match at row 115: ARVND
# ❌ Mismatch at row 116: expected 'ICNT', found 'ENTRA'
# ✔ Match at row 117: NIITMTS
# ✔ Match at row 118: GTFL
# ❌ Mismatch at row 119: expected 'CAMPUS', found 'ACC'
# ✔ Match at row 120: BORORENE
# ✔ Match at row 121: GOCOLORS
# ✔ Match at row 122: ETHOSLTD
# ✔ Match at row 123: JINW
# ✔ Match at row 124: PDSL
# ✔ Match at row 125: IFBI
# ✔ Match at row 126: VGM
# ✔ Match at row 127: ARVINDFA
# ✔ Match at row 128: SENCO
# ✔ Match at row 129: SYML
# ❌ Mismatch at row 130: expected 'SEL', found '140910'
# ✔ Match at row 131: ASKAUTOL
# ✔ Match at row 132: WONH
# ✔ Match at row 133: SGMART
# ✔ Match at row 134: ITDC
# ✔ Match at row 135: JMNA
# ✔ Match at row 136: DYTC
# ❌ Mismatch at row 137: expected 'RBA', found '3467'
# ❌ Mismatch at row 138: expected 'GABR', found 'DAD'
# ✔ Match at row 139: ROLEXRIN
# ✔ Match at row 140: PRICOL
# ✔ Match at row 141: GEXP
# ❌ Mismatch at row 142: expected 'JTEKT', found '6473'
# ✔ Match at row 143: VMART
# ✔ Match at row 144: KEKC
# ✔ Match at row 145: BOROLTD
# ✔ Match at row 146: PARKHOTE
# ❌ Mismatch at row 147: expected 'SHMO', found 'AMOR'
# ✔ Match at row 148: IMAGICAA
# ✔ Match at row 149: TJL
# ✔ Match at row 150: KPDL
# ❌ Mismatch at row 151: expected 'SSW', found 'BRAD'
# ✔ Match at row 152: SUBR
# ✔ Match at row 153: LMAX
# ✔ Match at row 154: BD
# ❌ Mismatch at row 155: expected 'LUX', found '4609'
# ❌ Mismatch at row 156: expected 'HAWK', found 'BKHAU'
# ✔ Match at row 157: SANDHAR
# ✔ Match at row 158: KDDL
# ❌ Mismatch at row 159: expected 'SSKL', found 'LIK'
# ❌ Mismatch at row 160: expected 'LANDMARK', found 'KTI'
# ✔ Match at row 161: FIEM
# ✔ Match at row 162: SRTY
# ❌ Mismatch at row 163: expected 'DELTA', found 'NINE'
# ✔ Match at row 164: GRV
# ❌ Mismatch at row 165: expected 'DOLLAR', found 'DG'
# ✔ Match at row 166: SUNCLAY
# ✔ Match at row 167: BLSE
# ❌ Mismatch at row 168: expected 'SWE', found 'ASAB'
# ✔ Match at row 169: HINDWARE
# ✔ Match at row 170: ATXL
# ✔ Match at row 171: FLAIR
# ✔ Match at row 172: CARYSIL
# ✔ Match at row 173: FLTX
# ✔ Match at row 174: DREAMFOL
# ✔ Match at row 175: NILK
# ✔ Match at row 176: GDYR
# ✔ Match at row 177: PCJL
# ✔ Match at row 178: GNPL
# ✔ Match at row 179: TAJG
# ✔ Match at row 180: SOMC
# ✔ Match at row 181: PGIL
# ✔ Match at row 182: DIVGIITT
# ✔ Match at row 183: OAH
# ✔ Match at row 184: LUMX
# ✔ Match at row 185: SNGM
# ✔ Match at row 186: TCNSBR
# ❌ Mismatch at row 187: expected 'OTH', found 'AOTHAIM'
# ❌ Mismatch at row 188: expected 'MUNI', found 'ONE'
# ❌ Mismatch at row 189: expected 'SIYA', found 'ASIY'
# ❌ Mismatch at row 190: expected 'RAI', found 'WMS'
# ✔ Match at row 191: BARBEQUE
# ❌ Mismatch at row 192: expected 'RUPA', found 'ADRS-R-A'
# ❌ Mismatch at row 193: expected 'SJS', found 'JSNV'
# ✔ Match at row 194: PRECAM
# ✔ Match at row 195: FILATFAS
# ❌ Mismatch at row 196: expected 'ITC', found 'ANF'
# ✔ Match at row 197: HUVR
# ✔ Match at row 198: DMART
# ❌ Mismatch at row 199: expected 'NEST', found '6381'
# ✔ Match at row 200: VBL
# ✔ Match at row 201: GCPL
# ❌ Mismatch at row 202: expected 'BRIT', found 'ASBE'
# ✔ Match at row 203: TATACONS
# ✔ Match at row 204: DABUR
# ✔ Match at row 205: UNITDSPR
# ✔ Match at row 206: CLGT
# ✔ Match at row 207: PG
# ✔ Match at row 208: PATANJAL
# ❌ Mismatch at row 209: expected 'UBBL', found 'DUBA'
# ✔ Match at row 210: AWLTD
# ✔ Match at row 211: GDSP
# ✔ Match at row 212: RDCK
# ✔ Match at row 213: HTSMF
# ❌ Mismatch at row 214: expected 'GILL', found 'AGILC'
# ✔ Match at row 215: HMN
# ✔ Match at row 216: DEVYANI
# ✔ Match at row 217: JYL
# ✔ Match at row 218: GP
# ✔ Match at row 219: DCMS
# ✔ Match at row 220: BIKAJI
# ✔ Match at row 221: BBTC
# ✔ Match at row 222: ZYWL
# ✔ Match at row 223: GOAGRO
# ✔ Match at row 224: SHRS
# ✔ Match at row 225: MEDPLUS
# ✔ Match at row 226: CCLP
# ✔ Match at row 227: GAEX
# ✔ Match at row 228: BRCM
# ❌ Mismatch at row 229: expected 'TRE', found 'BINHO'
# ✔ Match at row 230: AVNT
# ✔ Match at row 231: BECTORS
# ✔ Match at row 232: LTFOODS
# ❌ Mismatch at row 233: expected 'KRB', found 'KOR'
# ❌ Mismatch at row 234: expected 'VST', found 'IVE'
# ✔ Match at row 235: HNDFDS
# ✔ Match at row 236: DODLA
# ❌ Mismatch at row 237: expected 'SULA', found 'ASK'
# ❌ Mismatch at row 238: expected 'GOPAL', found 'BCOL'
# ✔ Match at row 239: TLNGR
# ✔ Match at row 240: BJH
# ✔ Match at row 241: TSTY
# ✔ Match at row 242: HTFL
# ❌ Mismatch at row 243: expected 'VDI', found '4BO'
# ✔ Match at row 244: BAJAJCON
# ✔ Match at row 245: BNRI
# ✔ Match at row 246: PCAI
# ✔ Match at row 247: DCB
# ✔ Match at row 248: HMAAGRO
# ❌ Mismatch at row 249: expected 'PARAG', found 'ADM'
# ✔ Match at row 250: EVRIN
# ✔ Match at row 251: MANORAMA
# ✔ Match at row 252: VSFI
# ❌ Mismatch at row 253: expected 'DIAMOND', found 'ALKDI'
# ✔ Match at row 254: WH
# ✔ Match at row 255: TTKP
# ❌ Mismatch at row 256: expected 'SDB', found 'DBOS'
# ✔ Match at row 257: ADFL
# ✔ Match at row 258: GBSL
# ❌ Mismatch at row 259: expected 'RELIANCE', found 'EUPIC'
# ❌ Mismatch at row 260: expected 'ONGC', found '000419'
# ✔ Match at row 261: IOCL
# ✔ Match at row 262: BPCL
# ✔ Match at row 263: HPCL
# ✔ Match at row 264: OINL
# ✔ Match at row 265: SUEL
# ✔ Match at row 266: PLNG
# ✔ Match at row 267: MRPL
# ✔ Match at row 268: IREDA
# ✔ Match at row 269: EXID
# ✔ Match at row 270: INXW
# ✔ Match at row 271: AEGISLOG
# ✔ Match at row 272: WAREERTL
# ✔ Match at row 273: MRL
# ✔ Match at row 274: HBPS
# ✔ Match at row 275: SWSOLAR
# ✔ Match at row 276: KPIG
# ✔ Match at row 277: TECHNOE
# ❌ Mismatch at row 278: expected 'IWEL', found '2159'
# ✔ Match at row 279: HARSHA
# ✔ Match at row 280: INOXGREE
# ❌ Mismatch at row 281: expected 'INA', found '247'
# ✔ Match at row 282: GENSOL
# ❌ Mismatch at row 283: expected 'SEAM', found '002956'
# ❌ Mismatch at row 284: expected 'CONF', found 'AVOT'
# ❌ Mismatch at row 285: expected 'TWO', found '002467'
# ✔ Match at row 286: KPEL
# ✔ Match at row 287: WESL
# ✔ Match at row 288: DEEPIND
# ✔ Match at row 289: GANDHAR
# ✔ Match at row 290: RIIL
# ✔ Match at row 291: HDFCB
# ✔ Match at row 292: ICICIBC
# ❌ Mismatch at row 293: expected 'SBIN', found 'SBINS'
# ❌ Mismatch at row 294: expected 'LICI', found 'BESS'
# ❌ Mismatch at row 295: expected 'BAF', found '603489'
# ❌ Mismatch at row 296: expected 'KMB', found 'BERA'
# ✔ Match at row 297: AXSB
# ✔ Match at row 298: BJFIN
# ✔ Match at row 299: JIOFIN
# ✔ Match at row 300: SBILIFE
# ❌ Mismatch at row 301: expected 'PNB', found 'AHP'
# ✔ Match at row 302: BOB
# ✔ Match at row 303: HDFCLIFE
# ✔ Match at row 304: POWF
# ✔ Match at row 305: IIB
# ❌ Mismatch at row 306: expected 'RECL', found 'MTBC'
# ✔ Match at row 307: UNBK
# ❌ Mismatch at row 308: expected 'IOB', found 'BOOM'
# ✔ Match at row 309: CBK
# ❌ Mismatch at row 310: expected 'CIFC', found '000996'
# ✔ Match at row 311: BJHI
# ✔ Match at row 312: SHFL
# ❌ Mismatch at row 313: expected 'IPRU', found 'AFRIPRUD'
# ✔ Match at row 314: IDBI
# ✔ Match at row 315: ICICIGI
# ✔ Match at row 316: HDFCAMC
# ✔ Match at row 317: INBK
# ❌ Mismatch at row 318: expected 'YES', found 'AYES'
# ✔ Match at row 319: SBICARD
# ❌ Mismatch at row 320: expected 'UCO', found 'ACUC'
# ❌ Mismatch at row 321: expected 'BOI', found 'ABTZY'
# ❌ Mismatch at row 322: expected 'MUTH', found 'BEDM'
# ✔ Match at row 323: GICRE
# ✔ Match at row 324: IDFCFB
# ✔ Match at row 325: CBOI
# ❌ Mismatch at row 326: expected 'SUF', found '000777'
# ✔ Match at row 327: ABCAP
# ✔ Match at row 328: BOMH
# ✔ Match at row 329: PJSB
# ✔ Match at row 330: LTF
# ✔ Match at row 331: AUBANK
# ✔ Match at row 332: NIACL
# ✔ Match at row 333: HUDCO
# ✔ Match at row 334: CRISIL
# ✔ Match at row 335: FB
# ✔ Match at row 336: POONAWAL
# ✔ Match at row 337: MMFS
# ✔ Match at row 338: LICHF
# ✔ Match at row 339: STARHEAL
# ❌ Mismatch at row 340: expected 'NAM', found 'ABDP'
# ✔ Match at row 341: BANDHAN
# ✔ Match at row 342: PAYTM
# ✔ Match at row 343: ANGELONE
# ✔ Match at row 344: MOFS
# ✔ Match at row 345: ISEC
# ✔ Match at row 346: CREDAG
# ✔ Match at row 347: FIVESTAR
# ✔ Match at row 348: PIEL
# ❌ Mismatch at row 349: expected 'IDFC', found 'IDFCFB'
# ✔ Match at row 350: MCX
# ✔ Match at row 351: CGCL
# ✔ Match at row 352: PNBHOUSI
# ✔ Match at row 353: APTUS
# ✔ Match at row 354: JKBK
# ✔ Match at row 355: KVB
# ✔ Match at row 356: MGFL
# ❌ Mismatch at row 357: expected 'RBK', found 'BKBR3'
# ❌ Mismatch at row 358: expected 'CAMS', found '2662'
# ✔ Match at row 359: ABSLAMC
# ✔ Match at row 360: IIFL
# ✔ Match at row 361: SAMMAANC
# ✔ Match at row 362: AIIL
# ✔ Match at row 363: EQUITASB
# ✔ Match at row 364: KFINTECH
# ✔ Match at row 365: AAVAS
# ✔ Match at row 366: UTIAM
# ✔ Match at row 367: CANF
# ✔ Match at row 368: CUBK
# ✔ Match at row 369: IFCI
# ❌ Mismatch at row 370: expected 'BENG', found 'ABG'
# ✔ Match at row 371: INFIBEAM
# ✔ Match at row 372: SBFC
# ✔ Match at row 373: UJJIVANS
# ❌ Mismatch at row 374: expected 'KBL', found 'BLZE'
# ✔ Match at row 375: SWH
# ✔ Match at row 376: HOMEFIRS
# ✔ Match at row 377: TMB
# ❌ Mismatch at row 378: expected 'SIB', found 'CAIN'
# ✔ Match at row 379: JM
# ❌ Mismatch at row 380: expected 'RELG', found 'NTGAZ'
# ✔ Match at row 381: INDIASHL
# ✔ Match at row 382: SISLTD
# ✔ Match at row 383: CSBBANK
# ✔ Match at row 384: SPANDANA
# ❌ Mismatch at row 385: expected 'EDEL', found 'BMM'
# ❌ Mismatch at row 386: expected 'SGM', found 'GMON'
# ✔ Match at row 387: UJJIVAN
# ✔ Match at row 388: CFIS
# ✔ Match at row 389: PAISALO
# ❌ Mismatch at row 390: expected 'ICRA', found 'FZICRA'
# ✔ Match at row 391: UTKARSHB
# ❌ Mismatch at row 392: expected 'FUSION', found 'BMEA'
# ✔ Match at row 393: MASFIN
# ✔ Match at row 394: SINDHUTR
# ✔ Match at row 395: JSFB
# ✔ Match at row 396: FEDFINA
# ✔ Match at row 397: PIICL
# ✔ Match at row 398: IIFLSEC
# ✔ Match at row 399: DCBB
# ✔ Match at row 400: MEDIASSI
# ✔ Match at row 401: ZAGGLE
# ✔ Match at row 402: MUTHOOTM
# ❌ Mismatch at row 403: expected 'CARE', found 'ONEM'
# ✔ Match at row 404: ESAFSFB
# ✔ Match at row 405: PTCIF
# ✔ Match at row 406: INDOSTAR
# ✔ Match at row 407: REPCO
# ✔ Match at row 408: FINOPB
# ❌ Mismatch at row 409: expected 'DHANI', found 'SANDHA'
# ✔ Match at row 410: SATIN
# ✔ Match at row 411: SGFIN
# ✔ Match at row 412: MUFIN
# ❌ Mismatch at row 413: expected 'VKI', found 'DVLF'
# ❌ Mismatch at row 414: expected 'UGRO', found 'AUGR'
# ✔ Match at row 415: PGLT
# ✔ Match at row 416: BFIN
# ✔ Match at row 417: ARLF
# ✔ Match at row 418: SUNP
# ✔ Match at row 419: CIPLA
# ✔ Match at row 420: DRRD
# ✔ Match at row 421: ZYDUSLIF
# ✔ Match at row 422: MANKIND
# ✔ Match at row 423: APHS
# ❌ Mismatch at row 424: expected 'DIVI', found 'CDF1U'
# ✔ Match at row 425: TRP
# ✔ Match at row 426: MAXHEALT
# ✔ Match at row 427: LPC
# ✔ Match at row 428: ARBP
# ✔ Match at row 429: ALKEM
# ✔ Match at row 430: BOOT
# ✔ Match at row 431: MEDANTA
# ✔ Match at row 432: GLXO
# ❌ Mismatch at row 433: expected 'BIOS', found 'AADI'
# ✔ Match at row 434: FORH
# ✔ Match at row 435: IPCA
# ❌ Mismatch at row 436: expected 'GLAND', found 'GLANDRT'
# ❌ Mismatch at row 437: expected 'SYNG', found '3SQ1'
# ✔ Match at row 438: AJP
# ✔ Match at row 439: GNP
# ✔ Match at row 440: NARH
# ✔ Match at row 441: JBCP
# ✔ Match at row 442: LAURUS
# ✔ Match at row 443: ASTERDM
# ✔ Match at row 444: ALPM
# ❌ Mismatch at row 445: expected 'PFIZ', found 'PFE'
# ✔ Match at row 446: DLPL
# ❌ Mismatch at row 447: expected 'SANL', found '300384'
# ✔ Match at row 448: SUVENPHA
# ✔ Match at row 449: PIRPHARM
# ✔ Match at row 450: NTCPH
# ✔ Match at row 451: KIMS
# ✔ Match at row 452: CONCORDB
# ❌ Mismatch at row 453: expected 'PLM', found 'AFH'
# ❌ Mismatch at row 454: expected 'ASTR', found 'TDI'
# ❌ Mismatch at row 455: expected 'RAINBOW', found 'AIL'
# ✔ Match at row 456: SPADV
# ❌ Mismatch at row 457: expected 'ERIS', found 'ADESE'
# ❌ Mismatch at row 458: expected 'GRAN', found 'AGR'
# ✔ Match at row 459: CLPL
# ❌ Mismatch at row 460: expected 'GLS', found '078140'
# ✔ Match at row 461: JUBLPHAR
# ❌ Mismatch at row 462: expected 'WPL', found 'WPLZ11B'
# ✔ Match at row 463: METROHL
# ✔ Match at row 464: NLL
# ✔ Match at row 465: JLHL
# ✔ Match at row 466: PGHL
# ❌ Mismatch at row 467: expected 'STR', found 'C69'
# ✔ Match at row 468: FDCLT
# ✔ Match at row 469: MRKS
# ✔ Match at row 470: BLUEJET
# ✔ Match at row 471: VIJAYA
# ✔ Match at row 472: ORCP
# ✔ Match at row 473: HCG
# ❌ Mismatch at row 474: expected 'ENTERO', found 'CONCESI1'
# ❌ Mismatch at row 475: expected 'KMC', found 'ITMAM'
# ✔ Match at row 476: AMIORG
# ✔ Match at row 477: SLPA
# ✔ Match at row 478: ARTD
# ✔ Match at row 479: AARTIPHA
# ❌ Mismatch at row 480: expected 'DCAL', found 'CALL'
# ✔ Match at row 481: YATHARTH
# ✔ Match at row 482: UL
# ✔ Match at row 483: HKCI
# ✔ Match at row 484: CUPD
# ✔ Match at row 485: THYROCAR
# ❌ Mismatch at row 486: expected 'INDR', found 'CNFS'
# ✔ Match at row 487: GTB
# ❌ Mismatch at row 488: expected 'SEQ', found 'MLSEQ'
# ✔ Match at row 489: CF
# ✔ Match at row 490: SUPRIYA
# ✔ Match at row 491: SHALBY
# ✔ Match at row 492: INNOVACA
# ✔ Match at row 493: HCBA
# ✔ Match at row 494: RPGL
# ✔ Match at row 495: ARTMSL
# ✔ Match at row 496: SVLS
# ❌ Mismatch at row 497: expected 'MORE', found '090430'
# ✔ Match at row 498: ALBC
# ❌ Mismatch at row 499: expected 'ICP', found '3577'
# ✔ Match at row 500: TMCH
# ✔ Match at row 501: KRSNAA
# ✔ Match at row 502: LT
# ✔ Match at row 503: ADSEZ
# ✔ Match at row 504: HNAL
# ❌ Mismatch at row 505: expected 'SIEM', found 'SEMC'
# ✔ Match at row 506: IRFC
# ✔ Match at row 507: BHE
# ❌ Mismatch at row 508: expected 'INDIGO', found 'IDG'
# ❌ Mismatch at row 509: expected 'ABB', found 'ABBANK'
# ✔ Match at row 510: HAVL
# ✔ Match at row 511: BHEL
# ❌ Mismatch at row 512: expected 'KKC', found 'ASH'
# ✔ Match at row 513: CGPOWER
# ✔ Match at row 514: INDUSTOW
# ✔ Match at row 515: POLYCAB
# ✔ Match at row 516: IRCTC
# ✔ Match at row 517: LTTS
# ✔ Match at row 518: CCRI
# ✔ Match at row 519: RVNL
# ✔ Match at row 520: BHFC
# ✔ Match at row 521: JSWINFRA
# ✔ Match at row 522: AL
# ✔ Match at row 523: TMX
# ✔ Match at row 524: GMRI
# ✔ Match at row 525: SCHFL
# ❌ Mismatch at row 526: expected 'APAT', found 'APT'
# ✔ Match at row 527: MAZDOCKS
# ✔ Match at row 528: AIAE
# ❌ Mismatch at row 529: expected 'VOLT', found '508096'
# ❌ Mismatch at row 530: expected 'IRB', found 'AEGIR'
# ❌ Mismatch at row 531: expected 'HWA', found 'ATEL'
# ✔ Match at row 532: DELHIVER
# ❌ Mismatch at row 533: expected 'BDL', found 'BDLAMP'
# ❌ Mismatch at row 534: expected 'TICL', found 'BPBL'
# ✔ Match at row 535: KEII
# ❌ Mismatch at row 536: expected 'ESCORTS', found 'EFS'
# ✔ Match at row 537: POWERIND
# ❌ Mismatch at row 538: expected 'APR', found 'PLAP'
# ✔ Match at row 539: BLSTR
# ✔ Match at row 540: SF
# ❌ Mismatch at row 541: expected 'COCHIN', found 'CMEI'
# ✔ Match at row 542: CYL
# ✔ Match at row 543: TMKN
# ✔ Match at row 544: NBCC
# ✔ Match at row 545: CHOLAHLD
# ❌ Mismatch at row 546: expected 'IRCON', found '002167'
# ❌ Mismatch at row 547: expected 'SKF', found 'SEKFK'
# ✔ Match at row 548: ELEQ
# ✔ Match at row 549: JYOTICNC
# ❌ Mismatch at row 550: expected 'SCHN', found 'SHNP'
# ✔ Match at row 551: RRKABEL
# ✔ Match at row 552: KPIL
# ❌ Mismatch at row 553: expected 'TRIV', found 'INDUC'
# ❌ Mismatch at row 554: expected 'ACCE', found 'ACEL'
# ❌ Mismatch at row 555: expected 'LMW', found 'CELLO'
# ❌ Mismatch at row 556: expected 'RITE', found 'ACEWIN'
# ✔ Match at row 557: OLECTRA
# ✔ Match at row 558: JWL
# ✔ Match at row 559: FNXC
# ✔ Match at row 560: BDE
# ✔ Match at row 561: NJCC
# ✔ Match at row 562: VGRD
# ❌ Mismatch at row 563: expected 'GESCO', found 'GSC1'
# ✔ Match at row 564: JSAW
# ✔ Match at row 565: DATAPATT
# ✔ Match at row 566: KSB
# ✔ Match at row 567: BEML
# ✔ Match at row 568: HMFC
# ✔ Match at row 569: BLSIN
# ✔ Match at row 570: GRINFRA
# ✔ Match at row 571: RMKF
# ❌ Mismatch at row 572: expected 'TITAGARH', found 'TWL'
# ❌ Mismatch at row 573: expected 'AMBER', found 'AMG1L'
# ❌ Mismatch at row 574: expected 'GRIL', found 'AGL'
# ✔ Match at row 575: SPPT
# ❌ Mismatch at row 576: expected 'INGR', found 'AIP'
# ✔ Match at row 577: ENGR
# ✔ Match at row 578: MHS
# ✔ Match at row 579: PNCL
# ✔ Match at row 580: INOXINDI
# ✔ Match at row 581: ELCN
# ✔ Match at row 582: GPPV
# ✔ Match at row 583: VAMP
# ❌ Mismatch at row 584: expected 'PRJ', found 'IPRJRA'
# ❌ Mismatch at row 585: expected 'SCI', found 'AADI'
# ✔ Match at row 586: EUREKAFO
# ✔ Match at row 587: KKB
# ✔ Match at row 588: GRSE
# ❌ Mismatch at row 589: expected 'TEGA', found 'ITG'
# ✔ Match at row 590: SYRMA
# ✔ Match at row 591: ESAB
# ✔ Match at row 592: AZAD
# ✔ Match at row 593: POWM
# ✔ Match at row 594: QUESS
# ❌ Mismatch at row 595: expected 'MINF', found '002578'
# ❌ Mismatch at row 596: expected 'ION', found '8458'
# ✔ Match at row 597: MIDHANI
# ❌ Mismatch at row 598: expected 'HEG', found 'CHGG'
# ✔ Match at row 599: AGLL
# ❌ Mismatch at row 600: expected 'GPIN', found '688084'
# ✔ Match at row 601: KNRC
# ✔ Match at row 602: AHLU
# ✔ Match at row 603: TVSSCS
# ✔ Match at row 604: DBL
# ✔ Match at row 605: IGSEC
# ✔ Match at row 606: TXMRE
# ✔ Match at row 607: CMSINFO
# ✔ Match at row 608: TRPC
# ✔ Match at row 609: PRINCPIP
# ✔ Match at row 610: HGINFRA
# ✔ Match at row 611: SECIS
# ✔ Match at row 612: MSTCLTD
# ❌ Mismatch at row 613: expected 'ITCE', found '124500'
# ✔ Match at row 614: CYIENTDL
# ❌ Mismatch at row 615: expected 'TARIL', found 'SEDAPBC1'
# ✔ Match at row 616: LLOYDSEN
# ❌ Mismatch at row 617: expected 'GMM', found 'AGMMRA'
# ✔ Match at row 618: SANSERA
# ❌ Mismatch at row 619: expected 'HCC', found '1552'
# ✔ Match at row 620: KNM
# ✔ Match at row 621: HMT
# ✔ Match at row 622: MTARTECH
# ✔ Match at row 623: JFI
# ✔ Match at row 624: GRFL
# ✔ Match at row 625: VRLL
# ✔ Match at row 626: JKIL
# ✔ Match at row 627: VATW
# ✔ Match at row 628: SJET
# ❌ Mismatch at row 629: expected 'NGE', found 'ABE'
# ✔ Match at row 630: TDPS
# ✔ Match at row 631: KKPC
# ✔ Match at row 632: TIIL
# ❌ Mismatch at row 633: expected 'PEC', found '469480'
# ✔ Match at row 634: ASBL
# ✔ Match at row 635: BNCO
# ✔ Match at row 636: SG
# ✔ Match at row 637: WELENT
# ✔ Match at row 638: ORIENTEL
# ✔ Match at row 639: LGBB
# ✔ Match at row 640: TCIEXP
# ✔ Match at row 641: VENUSPIP
# ✔ Match at row 642: SKIPPER
# ✔ Match at row 643: RMKY
# ❌ Mismatch at row 644: expected 'WPI', found '2809'
# ✔ Match at row 645: DCXINDIA
# ✔ Match at row 646: JI
# ❌ Mismatch at row 647: expected 'SALASAR', found 'SECLTD'
# ✔ Match at row 648: ANUP
# ❌ Mismatch at row 649: expected 'SBC', found '2208'
# ✔ Match at row 650: MAHLOG
# ❌ Mismatch at row 651: expected 'SCTE', found 'SCT'
# ✔ Match at row 652: BFUT
# ✔ Match at row 653: VINL
# ✔ Match at row 654: VSTT
# ✔ Match at row 655: SM
# ❌ Mismatch at row 656: expected 'APOLLO', found 'APAT'
# ✔ Match at row 657: SKPI
# ✔ Match at row 658: DIACABS
# ✔ Match at row 659: VT
# ✔ Match at row 660: NRBBR
# ✔ Match at row 661: JCHAC
# ✔ Match at row 662: GMRPUI
# ✔ Match at row 663: STYRENIX
# ✔ Match at row 664: BAJEL
# ✔ Match at row 665: PSPPL
# ✔ Match at row 666: PITTIENG
# ❌ Mismatch at row 667: expected 'SHEP', found 'CSP'
# ✔ Match at row 668: PARAS
# ✔ Match at row 669: EXICOM
# ✔ Match at row 670: UNIPARTS
# ✔ Match at row 671: SEPC
# ❌ Mismatch at row 672: expected 'MAN', found 'FPWM'
# ✔ Match at row 673: AXET
# ❌ Mismatch at row 674: expected 'PWI', found 'EPWN'
# ✔ Match at row 675: WNDT
# ✔ Match at row 676: HONDAPWR
# ✔ Match at row 677: EMSLIMIT
# ✔ Match at row 678: CAPACITE
# ✔ Match at row 679: IKIO
# ❌ Mismatch at row 680: expected 'UDS', found 'QUDS'
# ✔ Match at row 681: MMFG
# ✔ Match at row 682: BALUFORG
# ✔ Match at row 683: TARSONS
# ✔ Match at row 684: GTLI
# ✔ Match at row 685: HPLE
# ❌ Mismatch at row 686: expected 'BMD', found 'ALK'
# ✔ Match at row 687: IRMENERG
# ✔ Match at row 688: DCIL
# ✔ Match at row 689: BWRL
# ❌ Mismatch at row 690: expected 'ADE', found 'AAPLUSTR'
# ✔ Match at row 691: UTCEM
# ✔ Match at row 692: APNT
# ❌ Mismatch at row 693: expected 'COAL', found 'AJC'
# ✔ Match at row 694: JSTL
# ❌ Mismatch at row 695: expected 'TATA', found 'CTTH'
# ✔ Match at row 696: GRASIM
# ❌ Mismatch at row 697: expected 'PIDI', found 'LPD'
# ✔ Match at row 698: ACEM
# ✔ Match at row 699: HNDL
# ✔ Match at row 700: HZ
# ✔ Match at row 701: VEDL
# ✔ Match at row 702: SRCM
# ❌ Mismatch at row 703: expected 'JSP', found 'DJSP'
# ❌ Mismatch at row 704: expected 'SOIL', found 'ARGO'
# ✔ Match at row 705: SRF
# ✔ Match at row 706: TIINDIA
# ✔ Match at row 707: BRGR
# ✔ Match at row 708: NMDC
# ✔ Match at row 709: PI
# ✔ Match at row 710: JDSL
# ❌ Mismatch at row 711: expected 'SAIL', found 'ALWASAIL'
# ✔ Match at row 712: LIIL
# ✔ Match at row 713: SI
# ❌ Mismatch at row 714: expected 'ASTRA', found 'AAGRY'
# ✔ Match at row 715: ACC
# ❌ Mismatch at row 716: expected 'FCT', found 'BFC'
# ✔ Match at row 717: DALBHARA
# ✔ Match at row 718: 3M
# ✔ Match at row 719: UPLL
# ❌ Mismatch at row 720: expected 'FLUOROCH', found 'GFLC'
# ❌ Mismatch at row 721: expected 'CRIN', found 'ACRI'
# ❌ Mismatch at row 722: expected 'JKCE', found 'DJKC'
# ✔ Match at row 723: LLOYDSME
# ✔ Match at row 724: DN
# ❌ Mismatch at row 725: expected 'NACL', found '8353'
# ✔ Match at row 726: TTCH
# ✔ Match at row 727: HCP
# ✔ Match at row 728: ARTO
# ✔ Match at row 729: CU
# ✔ Match at row 730: KIOCL
# ✔ Match at row 731: BYRCS
# ✔ Match at row 732: KNPL
# ✔ Match at row 733: GWN
# ❌ Mismatch at row 734: expected 'RMT', found 'ARMT34'
# ✔ Match at row 735: TRCL
# ✔ Match at row 736: CSTRL
# ❌ Mismatch at row 737: expected 'CENT', found 'C21'
# ✔ Match at row 738: SUMICHEM
# ❌ Mismatch at row 739: expected 'ATLP', found 'ATP'
# ✔ Match at row 740: SHYAMMET
# ❌ Mismatch at row 741: expected 'CELLO', found 'CLL'
# ✔ Match at row 742: NSLNISP
# ❌ Mismatch at row 743: expected 'NFIL', found '6823'
# ✔ Match at row 744: FNXP
# ✔ Match at row 745: VO
# ✔ Match at row 746: JBIL
# ❌ Mismatch at row 747: expected 'HSCH', found 'RLD'
# ✔ Match at row 748: BASF
# ✔ Match at row 749: CPBI
# ❌ Mismatch at row 750: expected 'CLEAN', found 'ACE/F'
# ✔ Match at row 751: CHMB
# ✔ Match at row 752: WLCO
# ✔ Match at row 753: FINEORG
# ❌ Mismatch at row 754: expected 'RHIM', found 'HIMRRA'
# ✔ Match at row 755: ELSC
# ✔ Match at row 756: BCORP
# ✔ Match at row 757: NUVOCO
# ✔ Match at row 758: GMDC
# ✔ Match at row 759: AKZO
# ✔ Match at row 760: PTCIL
# ❌ Mismatch at row 761: expected 'AETHER', found 'ATHR'
# ✔ Match at row 762: GODPI
# ✔ Match at row 763: JKLC
# ✔ Match at row 764: PCBL
# ❌ Mismatch at row 765: expected 'USM', found 'AMG'
# ❌ Mismatch at row 766: expected 'EID', found 'ALEID'
# ✔ Match at row 767: ANURAS
# ✔ Match at row 768: AACL
# ✔ Match at row 769: GNFC
# ✔ Match at row 770: STRCEM
# ✔ Match at row 771: PRSMJ
# ✔ Match at row 772: KHL
# ❌ Mismatch at row 773: expected 'ACI', found 'AAL'
# ✔ Match at row 774: GALSURF
# ✔ Match at row 775: GSFC
# ❌ Mismatch at row 776: expected 'KKF', found 'BAAZEEM'
# ❌ Mismatch at row 777: expected 'RESP', found '9625'
# ✔ Match at row 778: JUBLINGR
# ✔ Match at row 779: SEML
# ✔ Match at row 780: RCF
# ✔ Match at row 781: CHEMPLAS
# ✔ Match at row 782: EBECK
# ❌ Mismatch at row 783: expected 'GRAV', found 'BLGV'
# ✔ Match at row 784: VI
# ❌ Mismatch at row 785: expected 'BLA', found 'BLZE'
# ❌ Mismatch at row 786: expected 'ICEM', found 'BZU'
# ✔ Match at row 787: LXCHEM
# ✔ Match at row 788: DFPC
# ✔ Match at row 789: GRLM
# ✔ Match at row 790: INDIGOPN
# ✔ Match at row 791: SANDUMA
# ✔ Match at row 792: EPLL
# ❌ Mismatch at row 793: expected 'MOIL', found 'JMOIL'
# ❌ Mismatch at row 794: expected 'TIME', found 'ATMCU'
# ❌ Mismatch at row 795: expected 'SYR', found 'FSS'
# ✔ Match at row 796: JKPAPER
# ❌ Mismatch at row 797: expected 'PARADEEP', found 'PPARIVAH'
# ❌ Mismatch at row 798: expected 'KSI', found 'AKGRT'
# ✔ Match at row 799: RINDL
# ✔ Match at row 800: GALK
# ❌ Mismatch at row 801: expected 'RALI', found '5GN'
# ✔ Match at row 802: AGIG
# ✔ Match at row 803: DAGRI
# ❌ Mismatch at row 804: expected 'GALL', found 'AJG'
# ✔ Match at row 805: GOLI
# ✔ Match at row 806: EPIGRAL
# ❌ Mismatch at row 807: expected 'HEIM', found 'D2B'
# ✔ Match at row 808: JPA
# ❌ Mismatch at row 809: expected 'NFL', found 'CFLT'
# ✔ Match at row 810: GHCL
# ❌ Mismatch at row 811: expected 'SCHI', found 'BDSN'
# ✔ Match at row 812: NOCIL
# ✔ Match at row 813: KKIL
# ✔ Match at row 814: BLCL
# ✔ Match at row 815: FTXC
# ✔ Match at row 816: GRWRHITE
# ✔ Match at row 817: ORCMNT
# ✔ Match at row 818: GW
# ✔ Match at row 819: WCPM
# ✔ Match at row 820: ADVENZY
# ✔ Match at row 821: PRIVISCL
# ✔ Match at row 822: GREENP
# ✔ Match at row 823: KS
# ✔ Match at row 824: ROSSARI
# ✔ Match at row 825: OMDC
# ✔ Match at row 826: BRSN
# ✔ Match at row 827: LLOYDSET
# ✔ Match at row 828: IMFA
# ✔ Match at row 829: ASMN
# ❌ Mismatch at row 830: expected 'FISCHER', found 'FCH'
# ❌ Mismatch at row 831: expected 'SUNF', found '5488'
# ❌ Mismatch at row 832: expected 'LOG', found 'YQ'
# ✔ Match at row 833: JTLIND
# ✔ Match at row 834: KSCL
# ❌ Mismatch at row 835: expected 'STEC', found 'ATEC'
# ✔ Match at row 836: NEOGEN
# ✔ Match at row 837: PKI
# ❌ Mismatch at row 838: expected 'RGW', found 'BWA'
# ✔ Match at row 839: UFLX
# ✔ Match at row 840: SHCR
# ✔ Match at row 841: MTLM
# ❌ Mismatch at row 842: expected 'MAIT', found 'LMAT'
# ✔ Match at row 843: SHKL
# ✔ Match at row 844: HLEGLAS
# ❌ Mismatch at row 845: expected 'GLIN', found 'ANG'
# ✔ Match at row 846: SGC
# ✔ Match at row 847: SYIL
# ✔ Match at row 848: ISMT
# ✔ Match at row 849: MTEP
# ❌ Mismatch at row 850: expected 'AREAL', found 'ARL'
# ✔ Match at row 851: TATVA
# ✔ Match at row 852: APOLP
# ❌ Mismatch at row 853: expected 'XPRO', found 'JMACU'
# ✔ Match at row 854: PPC
# ❌ Mismatch at row 855: expected 'TMC', found 'PTMCD'
# ❌ Mismatch at row 856: expected 'KINGFA', found '600143'
# ❌ Mismatch at row 857: expected 'HOE', found 'AXL'
# ✔ Match at row 858: IGLY
# ❌ Mismatch at row 859: expected 'IPL', found 'APN'
# ✔ Match at row 860: SNGI
# ✔ Match at row 861: APCO
# ❌ Mismatch at row 862: expected 'HUIN', found '8049'
# ✔ Match at row 863: GOCL
# ✔ Match at row 864: KCPL
# ✔ Match at row 865: BEPL
# ✔ Match at row 866: RASTL
# ❌ Mismatch at row 867: expected 'MUK', found 'MASTERPL'
# ❌ Mismatch at row 868: expected 'HITECH', found 'AH'
# ✔ Match at row 869: VCL
# ✔ Match at row 870: ASTEL
# ✔ Match at row 871: TCPL
# ❌ Mismatch at row 872: expected 'MOL', found 'FDMT'
# ❌ Mismatch at row 873: expected 'MGC', found 'MGCXD'
# ✔ Match at row 874: PNPC
# ✔ Match at row 875: JDPF
# ❌ Mismatch at row 876: expected 'HIL', found '5142'
# ✔ Match at row 877: TANF
# ✔ Match at row 878: IFGLRF
# ✔ Match at row 879: ANHPR
# ✔ Match at row 880: UDAICEME
# ✔ Match at row 881: DLFU
# ✔ Match at row 882: LODHA
# ❌ Mismatch at row 883: expected 'GPL', found 'CNT'
# ❌ Mismatch at row 884: expected 'OBER', found 'HUTT'
# ✔ Match at row 885: PHNX
# ✔ Match at row 886: PEPL
# ✔ Match at row 887: BRGD
# ❌ Mismatch at row 888: expected 'SIGNATUR', found 'GSS'
# ✔ Match at row 889: CHALET
# ✔ Match at row 890: SOBHA
# ✔ Match at row 891: ARCP
# ✔ Match at row 892: DBREALTY
# ✔ Match at row 893: NTSD
# ✔ Match at row 894: MAHLIFE
# ✔ Match at row 895: RUSTOMJE
# ✔ Match at row 896: EMBDL
# ✔ Match at row 897: GHFC
# ❌ Mismatch at row 898: expected 'NSE', found 'ACOS'
# ❌ Mismatch at row 899: expected 'SRIN', found 'SNNP'
# ✔ Match at row 900: HEMIPROP
# ✔ Match at row 901: PURVA
# ✔ Match at row 902: SAMHI
# ❌ Mismatch at row 903: expected 'TARC', found 'ANTAR'
# ✔ Match at row 904: MAXESTAT
# ✔ Match at row 905: NIRL
# ✔ Match at row 906: ARVSMART
# ✔ Match at row 907: UT
# ✔ Match at row 908: ASFI
# ✔ Match at row 909: MNRT
# ✔ Match at row 910: SHRIRAMP
# ❌ Mismatch at row 911: expected 'TCS', found 'HLIX'
# ❌ Mismatch at row 912: expected 'INFO', found 'III'
# ✔ Match at row 913: HCLT
# ✔ Match at row 914: WPRO
# ❌ Mismatch at row 915: expected 'LTIM', found 'ARH'
# ❌ Mismatch at row 916: expected 'TECHM', found '603015'
# ✔ Match at row 917: OFSS
# ✔ Match at row 918: PSYS
# ✔ Match at row 919: POLICYBZ
# ✔ Match at row 920: TELX
# ✔ Match at row 921: MPHL
# ✔ Match at row 922: DIXON
# ✔ Match at row 923: TATATECH
# ✔ Match at row 924: COFORGE
# ❌ Mismatch at row 925: expected 'ITI', found 'VCVCU'
# ✔ Match at row 926: BSOFT
# ✔ Match at row 927: SSOF
# ✔ Match at row 928: KAYNES
# ❌ Mismatch at row 929: expected 'REDI', found '2051'
# ❌ Mismatch at row 930: expected 'INDA', found 'BIPP'
# ✔ Match at row 931: FSOL
# ❌ Mismatch at row 932: expected 'ZENT', found 'AEZS'
# ✔ Match at row 933: ECLX
# ✔ Match at row 934: HAPPSTMN
# ✔ Match at row 935: TEJASNET
# ✔ Match at row 936: NEWGEN
# ❌ Mismatch at row 937: expected 'TANLA', found 'ELK'
# ✔ Match at row 938: LATENTVI
# ✔ Match at row 939: MAPMYIND
# ✔ Match at row 940: NETWEB
# ✔ Match at row 941: RATEGAIN
# ❌ Mismatch at row 942: expected 'ZEN', found '603389'
# ❌ Mismatch at row 943: expected 'MAST', found 'ADDC'
# ✔ Match at row 944: EMUDHRA
# ✔ Match at row 945: ASTM
# ✔ Match at row 946: AUPS
# ✔ Match at row 947: MCLOUD
# ❌ Mismatch at row 948: expected 'RSYS', found 'ATHX'
# ✔ Match at row 949: SOTL
# ✔ Match at row 950: AVL
# ✔ Match at row 951: PGEL
# ✔ Match at row 952: PROTEAN
# ✔ Match at row 953: BBOX
# ✔ Match at row 954: BIJL
# ❌ Mismatch at row 955: expected 'CIGN', found 'CI'
# ✔ Match at row 956: HGSL
# ❌ Mismatch at row 957: expected 'AVALON', found 'AVACU'
# ❌ Mismatch at row 958: expected 'NCS', found 'AFBI'
# ❌ Mismatch at row 959: expected 'DATA', found '3260'
# ✔ Match at row 960: IDEAFORG
# ✔ Match at row 961: BCG
# ❌ Mismatch at row 962: expected 'SAK', found 'AAYANRE'
# ✔ Match at row 963: QUICKHEA
# ✔ Match at row 964: ACCELYA
# ✔ Match at row 965: AVTS
# ❌ Mismatch at row 966: expected 'GENE', found 'ADAG'
# ✔ Match at row 967: SASKEN
# ❌ Mismatch at row 968: expected 'CTE', found 'ABE'
# ✔ Match at row 969: RPTECH
# ✔ Match at row 970: RPSGVENT
# ✔ Match at row 971: PRMC
# ✔ Match at row 972: EXPLEOSO
# ❌ Mismatch at row 973: expected 'NTPC', found 'NTPCGREE'
# ✔ Match at row 974: ADANIGR
# ✔ Match at row 975: PWGR
# ❌ Mismatch at row 976: expected 'ADANI', found 'ADE'
# ✔ Match at row 977: TPWR
# ❌ Mismatch at row 978: expected 'GAIL', found 'ACC/P'
# ✔ Match at row 979: ADANIENS
# ✔ Match at row 980: ATGL
# ✔ Match at row 981: NHPC
# ✔ Match at row 982: JSW
# ✔ Match at row 983: TPW
# ✔ Match at row 984: SJVN
# ✔ Match at row 985: GUJGA
# ✔ Match at row 986: NLC
# ❌ Mismatch at row 987: expected 'IGL', found 'BH/A'
# ✔ Match at row 988: GETD
# ✔ Match at row 989: GUJS
# ❌ Mismatch at row 990: expected 'KECI', found 'BRKC'
# ✔ Match at row 991: CESC
# ✔ Match at row 992: MAHGL
# ❌ Mismatch at row 993: expected 'IEX', found 'CDX'
# ✔ Match at row 994: RPWR
# ❌ Mismatch at row 995: expected 'RELI', found 'ACC'
# ✔ Match at row 996: JPVL
# ❌ Mismatch at row 997: expected 'RATI', found 'TWLV'
# ❌ Mismatch at row 998: expected 'NAVA', found 'BONAVB'
# ✔ Match at row 999: PTCIN
# ✔ Match at row 1000: RTPOW
# ❌ Mismatch at row 1001: expected 'GIP', found 'BGIP3'
#
# ✅ Done. Mismatched rows saved to 'company_sasb_issues_mismatch_highlighted.xlsx'
